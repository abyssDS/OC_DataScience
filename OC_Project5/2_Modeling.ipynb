# %%
from IPython.core.interactiveshell import InteractiveShell
from datetime import datetime

#basic externals
import pandas as pd
import numpy as np
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype
import feather

#visual libs
import matplotlib.pyplot  as plt
import seaborn as sns

# sklearn model imports
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.externals import joblib
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, roc_curve, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.linear_model import LogisticRegressionCV, LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

#local imports
# %run xm_functions

InteractiveShell.ast_node_interactivity = "all"

pd.options.display.max_rows = 20
pd.options.display.max_columns = 50 
pd.set_option('display.float_format', lambda x: '%.3f' % x) #display numbers as decimals instead of scientific value

plt.rcParams["font.size"] = (18)

# %% [markdown]
# ### Quickly import our feather clean dataset

# %%
fast =True
if fast==True:
    df = pd.read_feather('online_retail_clean.feather')

# %% [markdown]
# ## Quick describe

# %% [markdown]
# InvoiceNo: Invoice number. Nominal, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.
# StockCode: Product (item) code. Nominal, a 5-digit integral number uniquely assigned to each distinct product.
# Description: Product (item) name. Nominal.
# Quantity: The quantities of each product (item) per transaction. Numeric.
# InvoiceDate: Invice Date and time. Numeric, the day and time when each transaction was generated.
# UnitPrice: Unit price. Numeric, Product price per unit in sterling.
# CustomerID: Customer number. Nominal, a 5-digit integral number uniquely assigned to each customer.
# Country: Country name. Nominal, the name of the country where each customer resides.

# %%
df.describe(include='all')
df.head(5)
# Out:
#             index InvoiceNo                         Description   Quantity  \
# count  392413.000    392413                              392413 392413.000
# unique        nan     18468                                3876        nan
# top           nan    576339  WHITE HANGING HEART T-LIGHT HOLDER        nan
# freq          nan       542                                2016        nan
# first         nan       NaN                                 NaN        nan
# last          nan       NaN                                 NaN        nan
# mean   196206.000       NaN                                 NaN     13.111
# std    113280.020       NaN                                 NaN    180.518
# min         0.000       NaN                                 NaN      1.000
# 25%     98103.000       NaN                                 NaN      2.000
# 50%    196206.000       NaN                                 NaN      6.000
# 75%    294309.000       NaN                                 NaN     12.000
# max    392412.000       NaN                                 NaN  80995.000
#
#                 InvoiceDate  UnitPrice  CustomerID         Country      Month  \
# count                392413 392413.000  392413.000          392413 392413.000
# unique                17228        nan         nan              37        nan
# top     2011-11-14 15:27:00        nan         nan  United Kingdom        nan
# freq                    542        nan         nan          348960        nan
# first   2010-12-01 08:26:00        nan         nan             NaN        nan
# last    2011-12-09 12:50:00        nan         nan             NaN        nan
# mean                    NaN      3.001   15287.749             NaN      6.818
# std                     NaN     15.046    1713.420             NaN      3.682
# min                     NaN      0.001   12346.000             NaN      0.000
# 25%                     NaN      1.250   13955.000             NaN      4.000
# 50%                     NaN      1.950   15150.000             NaN      7.000
# 75%                     NaN      3.750   16791.000             NaN     10.000
# max                     NaN   8142.750   18287.000             NaN     12.000
#
#              Week       Time  TotalPrice     ItemID  Country_GPD CountryUK  \
# count  392413.000 392413.000  392413.000 392413.000   392413.000    392413
# unique        nan        nan         nan        nan          nan         2
# top           nan        nan         nan        nan          nan      True
# freq          nan        nan         nan        nan          nan    348960
# first         nan        nan         nan        nan          nan       NaN
# last          nan        nan         nan        nan          nan       NaN
# mean       27.522     13.228      22.511   1921.992    44477.591       NaN
# std        16.095      2.260     310.780   1042.693     4784.577       NaN
# min        -4.000      6.333       0.001      0.000    15500.000       NaN
# 25%        14.000     11.683       4.950   1101.000    43620.000       NaN
# 50%        30.000     13.150      12.450   1886.000    43620.000       NaN
# 75%        42.000     14.833      19.800   2786.000    43620.000       NaN
# max        49.000     20.300  168469.600   3875.000    90531.000       NaN
#
#            Client
# count  392413.000
# unique        nan
# top           nan
# freq          nan
# first         nan
# last          nan
# mean     3334.017
# std      1009.830
# min         0.000
# 25%      2799.000
# 50%      3692.000
# 75%      4136.000
# max      4334.000
#    index InvoiceNo                          Description  Quantity  \
# 0      0    536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      1    536365                  WHITE METAL LANTERN         6
# 2      2    536365       CREAM CUPID HEARTS COAT HANGER         8
# 3      3    536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      4    536365       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Month  Week  \
# 0 2010-12-01 08:26:00      2.550   17850.000  United Kingdom      0    -4
# 1 2010-12-01 08:26:00      3.390   17850.000  United Kingdom      0    -4
# 2 2010-12-01 08:26:00      2.750   17850.000  United Kingdom      0    -4
# 3 2010-12-01 08:26:00      3.390   17850.000  United Kingdom      0    -4
# 4 2010-12-01 08:26:00      3.390   17850.000  United Kingdom      0    -4
#
#    Time  TotalPrice  ItemID  Country_GPD  CountryUK  Client
# 0 8.433      15.300    2448    43620.000       True    4089
# 1 8.433      20.340    2763    43620.000       True    4089
# 2 8.433      22.000    2890    43620.000       True    4089
# 3 8.433      20.340    2943    43620.000       True    4089
# 4 8.433      20.340    2952    43620.000       True    4089

# %% [markdown]
# # Transforming DATA to one-row orders

# %%
#Not finished
#df_items= df.groupby('ItemID').agg({'Description': 'first', 'Quantity': ['mean', 'sum'], 'TotalPrice': 'sum', 'Quantity' :'sum', 'UnitPrice' : 'mean', 'InvoiceDate' :'first', 'Month': 'first', 'Week': 'first', 'ItemID' :'unique'})

# %%
df_orders = df.groupby('InvoiceNo').agg({'CustomerID': 'first', 'CountryUK': 'first','Country_GPD': 'first', 'TotalPrice': 'sum', 'Quantity' :'sum', 'UnitPrice' : ['mean', 'max'],'Week': 'first', 'Time':'first', 'ItemID' :'count'})

# %%
#Flattening multi level index
df_orders.columns = df_orders.columns.get_level_values(0)

df_orders.columns =['CustomerID', 'CountryUK', 'Country_GPD', 'TotalPrice', 'Quantity',
       'UnitPrice_avg', 'UnitPrice_max',  'Week', 'Time',
       'Distinct_items_count']

df_orders.head()
df_orders.shape
# Out:
#            CustomerID  CountryUK  Country_GPD  TotalPrice  Quantity  \
# InvoiceNo
# 536365      17850.000       True    43620.000     139.120        40
# 536366      17850.000       True    43620.000      22.200        12
# 536367      13047.000       True    43620.000     278.730        83
# 536368      13047.000       True    43620.000      70.050        15
# 536369      13047.000       True    43620.000      17.850         3
#
#            UnitPrice_avg  UnitPrice_max  Week  Time  Distinct_items_count
# InvoiceNo
# 536365             3.910          7.650    -4 8.433                     7
# 536366             1.850          1.850    -4 8.467                     2
# 536367             4.853          9.950    -4 8.567                    12
# 536368             4.775          4.950    -4 8.567                     4
# 536369             5.950          5.950    -4 8.583                     1
# (18468, 10)

# %%
df_orders.columns
# Out:
# Index(['CustomerID', 'CountryUK', 'Country_GPD', 'TotalPrice', 'Quantity',
#        'UnitPrice_avg', 'UnitPrice_max', 'Week', 'Time',
#        'Distinct_items_count'],
#       dtype='object')

# %% [markdown]
# ### Df First orders only

# %%
if 'FirstInvoice' not in df_orders.columns:
    df_first_order = df_orders.reset_index().groupby('CustomerID').first()['InvoiceNo'].rename('FirstInvoice')
    df_orders = df_orders.join(df_first_order , on='CustomerID')

df_first_order = df_orders[df_orders['FirstInvoice'] == df_orders.index].copy()
df_first_order['CustomerID'] = df_first_order['CustomerID'].astype(object)

# %%
df_first_order.shape
df_first_order.info()
# Out:
# (4335, 11)
# <class 'pandas.core.frame.DataFrame'>
# Index: 4335 entries, 536365 to 581578
# Data columns (total 11 columns):
# CustomerID              4335 non-null object
# CountryUK               4335 non-null bool
# Country_GPD             4335 non-null float64
# TotalPrice              4335 non-null float64
# Quantity                4335 non-null int64
# UnitPrice_avg           4335 non-null float64
# UnitPrice_max           4335 non-null float64
# Week                    4335 non-null int64
# Time                    4335 non-null float64
# Distinct_items_count    4335 non-null int64
# FirstInvoice            4335 non-null object
# dtypes: bool(1), float64(5), int64(3), object(2)
# memory usage: 376.8+ KB

# %%
df_first_order.describe()
# Out:
#        Country_GPD  TotalPrice  Quantity  UnitPrice_avg  UnitPrice_max  \
# count     4335.000    4335.000  4335.000       4335.000       4335.000
# mean     43868.688     423.862   260.556          3.785         12.281
# std       2851.165    1290.280  1182.169          9.112         18.697
# min      15500.000       0.850     1.000          0.060          0.060
# 25%      43620.000     165.780    82.000          2.126          5.450
# 50%      43620.000     300.460   155.000          2.917          9.950
# 75%      43620.000     447.230   281.000          3.946         12.750
# max      90531.000   77183.600 74215.000        295.000        300.000
#
#           Week     Time  Distinct_items_count
# count 4335.000 4335.000              4335.000
# mean    17.368   13.058                23.642
# std     16.832    2.347                22.948
# min     -4.000    7.617                 1.000
# 25%      3.000   11.367                 9.000
# 50%     14.000   13.000                17.000
# 75%     33.000   14.767                30.000
# max     49.000   20.200               274.000

# %% [markdown]
# ## Dummy variables

# %%
df.shape
df.head(1)
# Out:
# (392413, 16)
#    index InvoiceNo                         Description  Quantity  \
# 0      0    536365  WHITE HANGING HEART T-LIGHT HOLDER         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Month  Week  \
# 0 2010-12-01 08:26:00      2.550   17850.000  United Kingdom      0    -4
#
#    Time  TotalPrice  ItemID  Country_GPD  CountryUK  Client
# 0 8.433      15.300    2448    43620.000       True    4089

# %%
df_first_order.head()
# Out:
#           CustomerID  CountryUK  Country_GPD  TotalPrice  Quantity  \
# InvoiceNo
# 536365     17850.000       True    43620.000     139.120        40
# 536367     13047.000       True    43620.000     278.730        83
# 536370     12583.000      False    43550.000     855.860       449
# 536371     13748.000       True    43620.000     204.000        80
# 536374     15100.000       True    43620.000     350.400        32
#
#            UnitPrice_avg  UnitPrice_max  Week  Time  Distinct_items_count  \
# InvoiceNo
# 536365             3.910          7.650    -4 8.433                     7
# 536367             4.853          9.950    -4 8.567                    12
# 536370             2.764         18.000    -4 8.750                    20
# 536371             2.550          2.550    -4 9.000                     1
# 536374            10.950         10.950    -4 9.150                     1
#
#           FirstInvoice
# InvoiceNo
# 536365          536365
# 536367          536367
# 536370          536370
# 536371          536371
# 536374          536374

# %%
df_firsts= df[df['InvoiceNo'].isin(df_first_order.index)]
df_firsts.shape
# Out:
# (102487, 16)

# %% [markdown]
# ### pivot on item quantities

# %%
df_firsts_pivot=df_first_order[['CustomerID']].copy()

# %%
fast =True
if fast==True:
    df_firsts_pivot = pd.read_feather('df_firsts_pivot.feather')
if fast==False:
    for index, row in df_firsts.iterrows():
        item_name = row['Description']
        invoice = row['InvoiceNo']
        df_firsts_pivot.loc[invoice, item_name]=row['Quantity']
    df_firsts_pivot = df_firsts_pivot.fillna(0)
    df_firsts_pivot.reset_index().to_feather('df_firsts_pivot.feather')
    
df_firsts_pivot.index=df_firsts_pivot['InvoiceNo']

# %%
df_firsts_pivot.head(10)
# Out:
#           InvoiceNo  CustomerID FirstInvoice  Quantity  TotalPrice  \
# InvoiceNo
# 536365       536365   17850.000       536365        40     139.120
# 536367       536367   13047.000       536367        83     278.730
# 536370       536370   12583.000       536370       449     855.860
# 536371       536371   13748.000       536371        80     204.000
# 536374       536374   15100.000       536374        32     350.400
# 536376       536376   15291.000       536376       112     328.800
# 536378       536378   14688.000       536378       454     444.980
# 536380       536380   17809.000       536380        24      34.800
# 536381       536381   15311.000       536381       198     449.980
# 536382       536382   16098.000       536382       134     430.600
#
#                   InvoiceDate  Week         Country  \
# InvoiceNo
# 536365    2010-12-01 08:26:00    -4  United Kingdom
# 536367    2010-12-01 08:34:00    -4  United Kingdom
# 536370    2010-12-01 08:45:00    -4          France
# 536371    2010-12-01 09:00:00    -4  United Kingdom
# 536374    2010-12-01 09:09:00    -4  United Kingdom
# 536376    2010-12-01 09:32:00    -4  United Kingdom
# 536378    2010-12-01 09:37:00    -4  United Kingdom
# 536380    2010-12-01 09:41:00    -4  United Kingdom
# 536381    2010-12-01 09:41:00    -4  United Kingdom
# 536382    2010-12-01 09:45:00    -4  United Kingdom
#
#            WHITE HANGING HEART T-LIGHT HOLDER  WHITE METAL LANTERN  \
# InvoiceNo
# 536365                                  6.000                6.000
# 536367                                  0.000                0.000
# 536370                                  0.000                0.000
# 536371                                  0.000                0.000
# 536374                                  0.000                0.000
# 536376                                  0.000                0.000
# 536378                                  0.000                0.000
# 536380                                  0.000                0.000
# 536381                                  0.000                0.000
# 536382                                  0.000                0.000
#
#            CREAM CUPID HEARTS COAT HANGER  \
# InvoiceNo
# 536365                              8.000
# 536367                              0.000
# 536370                              0.000
# 536371                              0.000
# 536374                              0.000
# 536376                              0.000
# 536378                              0.000
# 536380                              0.000
# 536381                              0.000
# 536382                              0.000
#
#            KNITTED UNION FLAG HOT WATER BOTTLE  \
# InvoiceNo
# 536365                                   6.000
# 536367                                   0.000
# 536370                                   0.000
# 536371                                   0.000
# 536374                                   0.000
# 536376                                   0.000
# 536378                                   0.000
# 536380                                   0.000
# 536381                                   0.000
# 536382                                   0.000
#
#            RED WOOLLY HOTTIE WHITE HEART.  SET 7 BABUSHKA NESTING BOXES  \
# InvoiceNo
# 536365                              6.000                         2.000
# 536367                              0.000                         0.000
# 536370                              0.000                         0.000
# 536371                              0.000                         0.000
# 536374                              0.000                         0.000
# 536376                              0.000                         0.000
# 536378                              0.000                         0.000
# 536380                              0.000                         0.000
# 536381                              0.000                         0.000
# 536382                              0.000                         0.000
#
#            GLASS STAR FROSTED T-LIGHT HOLDER  ASSORTED COLOUR BIRD ORNAMENT  \
# InvoiceNo
# 536365                                 6.000                          0.000
# 536367                                 0.000                         32.000
# 536370                                 0.000                          0.000
# 536371                                 0.000                          0.000
# 536374                                 0.000                          0.000
# 536376                                 0.000                          0.000
# 536378                                 0.000                          0.000
# 536380                                 0.000                          0.000
# 536381                                 0.000                          0.000
# 536382                                 0.000                          0.000
#
#            POPPY'S PLAYHOUSE BEDROOM   POPPY'S PLAYHOUSE KITCHEN  \
# InvoiceNo
# 536365                          0.000                      0.000
# 536367                          6.000                      6.000
# 536370                          0.000                      0.000
# 536371                          0.000                      0.000
# 536374                          0.000                      0.000
# 536376                          0.000                      0.000
# 536378                          0.000                      0.000
# 536380                          0.000                      0.000
# 536381                          0.000                      0.000
# 536382                          0.000                      0.000
#
#            FELTCRAFT PRINCESS CHARLOTTE DOLL  IVORY KNITTED MUG COSY   \
# InvoiceNo
# 536365                                 0.000                    0.000
# 536367                                 8.000                    6.000
# 536370                                 0.000                    0.000
# 536371                                 0.000                    0.000
# 536374                                 0.000                    0.000
# 536376                                 0.000                    0.000
# 536378                                 0.000                    0.000
# 536380                                 0.000                    0.000
# 536381                                 0.000                    0.000
# 536382                                 0.000                    0.000
#
#            BOX OF 6 ASSORTED COLOUR TEASPOONS  BOX OF VINTAGE JIGSAW BLOCKS   \
# InvoiceNo
# 536365                                  0.000                          0.000
# 536367                                  6.000                          3.000
# 536370                                  0.000                          0.000
# 536371                                  0.000                          0.000
# 536374                                  0.000                          0.000
# 536376                                  0.000                          0.000
# 536378                                  0.000                          0.000
# 536380                                  0.000                          0.000
# 536381                                  0.000                          0.000
# 536382                                  0.000                          0.000
#
#            BOX OF VINTAGE ALPHABET BLOCKS  HOME BUILDING BLOCK WORD  \
# InvoiceNo
# 536365                              0.000                     0.000
# 536367                              2.000                     3.000
# 536370                              0.000                     0.000
# 536371                              0.000                     0.000
# 536374                              0.000                     0.000
# 536376                              0.000                     0.000
# 536378                              0.000                     0.000
# 536380                              0.000                     0.000
# 536381                              0.000                     0.000
# 536382                              0.000                     0.000
#
#            LOVE BUILDING BLOCK WORD             ...               \
# InvoiceNo                                       ...
# 536365                        0.000             ...
# 536367                        3.000             ...
# 536370                        0.000             ...
# 536371                        0.000             ...
# 536374                        0.000             ...
# 536376                        0.000             ...
# 536378                        0.000             ...
# 536380                        0.000             ...
# 536381                        0.000             ...
# 536382                        0.000             ...
#
#            LETTER "L" BLING KEY RING  LETTER "A" BLING KEY RING  \
# InvoiceNo
# 536365                         0.000                      0.000
# 536367                         0.000                      0.000
# 536370                         0.000                      0.000
# 536371                         0.000                      0.000
# 536374                         0.000                      0.000
# 536376                         0.000                      0.000
# 536378                         0.000                      0.000
# 536380                         0.000                      0.000
# 536381                         0.000                      0.000
# 536382                         0.000                      0.000
#
#            LETTER "B" BLING KEY RING  LETTER "C" BLING KEY RING  \
# InvoiceNo
# 536365                         0.000                      0.000
# 536367                         0.000                      0.000
# 536370                         0.000                      0.000
# 536371                         0.000                      0.000
# 536374                         0.000                      0.000
# 536376                         0.000                      0.000
# 536378                         0.000                      0.000
# 536380                         0.000                      0.000
# 536381                         0.000                      0.000
# 536382                         0.000                      0.000
#
#            LETTER "D" BLING KEY RING  LETTER "E" BLING KEY RING  \
# InvoiceNo
# 536365                         0.000                      0.000
# 536367                         0.000                      0.000
# 536370                         0.000                      0.000
# 536371                         0.000                      0.000
# 536374                         0.000                      0.000
# 536376                         0.000                      0.000
# 536378                         0.000                      0.000
# 536380                         0.000                      0.000
# 536381                         0.000                      0.000
# 536382                         0.000                      0.000
#
#            LETTER "G" BLING KEY RING  LETTER "H" BLING KEY RING  \
# InvoiceNo
# 536365                         0.000                      0.000
# 536367                         0.000                      0.000
# 536370                         0.000                      0.000
# 536371                         0.000                      0.000
# 536374                         0.000                      0.000
# 536376                         0.000                      0.000
# 536378                         0.000                      0.000
# 536380                         0.000                      0.000
# 536381                         0.000                      0.000
# 536382                         0.000                      0.000
#
#            LETTER "K" BLING KEY RING  LETTER "F" BLING KEY RING  \
# InvoiceNo
# 536365                         0.000                      0.000
# 536367                         0.000                      0.000
# 536370                         0.000                      0.000
# 536371                         0.000                      0.000
# 536374                         0.000                      0.000
# 536376                         0.000                      0.000
# 536378                         0.000                      0.000
# 536380                         0.000                      0.000
# 536381                         0.000                      0.000
# 536382                         0.000                      0.000
#
#            LETTER "I" BLING KEY RING  LETTER "N" BLING KEY RING  \
# InvoiceNo
# 536365                         0.000                      0.000
# 536367                         0.000                      0.000
# 536370                         0.000                      0.000
# 536371                         0.000                      0.000
# 536374                         0.000                      0.000
# 536376                         0.000                      0.000
# 536378                         0.000                      0.000
# 536380                         0.000                      0.000
# 536381                         0.000                      0.000
# 536382                         0.000                      0.000
#
#            LETTER "O" BLING KEY RING  LETTER "P" BLING KEY RING  \
# InvoiceNo
# 536365                         0.000                      0.000
# 536367                         0.000                      0.000
# 536370                         0.000                      0.000
# 536371                         0.000                      0.000
# 536374                         0.000                      0.000
# 536376                         0.000                      0.000
# 536378                         0.000                      0.000
# 536380                         0.000                      0.000
# 536381                         0.000                      0.000
# 536382                         0.000                      0.000
#
#            LETTER "R" BLING KEY RING  LETTER "T" BLING KEY RING  \
# InvoiceNo
# 536365                         0.000                      0.000
# 536367                         0.000                      0.000
# 536370                         0.000                      0.000
# 536371                         0.000                      0.000
# 536374                         0.000                      0.000
# 536376                         0.000                      0.000
# 536378                         0.000                      0.000
# 536380                         0.000                      0.000
# 536381                         0.000                      0.000
# 536382                         0.000                      0.000
#
#            LETTER "U" BLING KEY RING  LETTER "W" BLING KEY RING  \
# InvoiceNo
# 536365                         0.000                      0.000
# 536367                         0.000                      0.000
# 536370                         0.000                      0.000
# 536371                         0.000                      0.000
# 536374                         0.000                      0.000
# 536376                         0.000                      0.000
# 536378                         0.000                      0.000
# 536380                         0.000                      0.000
# 536381                         0.000                      0.000
# 536382                         0.000                      0.000
#
#            LETTER "Y" BLING KEY RING  LETTER "Z" BLING KEY RING  \
# InvoiceNo
# 536365                         0.000                      0.000
# 536367                         0.000                      0.000
# 536370                         0.000                      0.000
# 536371                         0.000                      0.000
# 536374                         0.000                      0.000
# 536376                         0.000                      0.000
# 536378                         0.000                      0.000
# 536380                         0.000                      0.000
# 536381                         0.000                      0.000
# 536382                         0.000                      0.000
#
#            CRYSTAL CZECH CROSS PHONE CHARM  PINK CRYSTAL SKULL PHONE CHARM  \
# InvoiceNo
# 536365                               0.000                           0.000
# 536367                               0.000                           0.000
# 536370                               0.000                           0.000
# 536371                               0.000                           0.000
# 536374                               0.000                           0.000
# 536376                               0.000                           0.000
# 536378                               0.000                           0.000
# 536380                               0.000                           0.000
# 536381                               0.000                           0.000
# 536382                               0.000                           0.000
#
#            CLEAR CRYSTAL STAR PHONE CHARM  WHITE MOROCCAN METAL LANTERN  \
# InvoiceNo
# 536365                              0.000                         0.000
# 536367                              0.000                         0.000
# 536370                              0.000                         0.000
# 536371                              0.000                         0.000
# 536374                              0.000                         0.000
# 536376                              0.000                         0.000
# 536378                              0.000                         0.000
# 536380                              0.000                         0.000
# 536381                              0.000                         0.000
# 536382                              0.000                         0.000
#
#            SMALL PARLOUR PICTURE FRAME
# InvoiceNo
# 536365                           0.000
# 536367                           0.000
# 536370                           0.000
# 536371                           0.000
# 536374                           0.000
# 536376                           0.000
# 536378                           0.000
# 536380                           0.000
# 536381                           0.000
# 536382                           0.000
#
# [10 rows x 3604 columns]

# %%
#clipping (to get dummy variables )
#df_firsts_pivot.iloc[:, 8:] = df_firsts_pivot.iloc[:, 8:].clip(0,1)

# %%
df_firsts_pivot.shape
print( df_firsts_pivot.shape[1], " features. Let's reduce it a bit by removing all features with less than 10 entries")
# Out:
# (4335, 3604)
# 3604  features. Let's reduce it a bit by removing all features with less than 10 entries

# %%
min_entries = 10
df_firsts_pivot = df_firsts_pivot[df_firsts_pivot.columns[df_firsts_pivot.replace(0, np.nan).count() >min_entries]]
print( df_firsts_pivot.shape[1], " features left")
# Out:
# 2062  features left

# %%
df_first_items = df_firsts_pivot.iloc[:, 8:]

# %% [markdown]
# # Customers Dataframe

# %%
latest_order = df['InvoiceDate'].max()
def days_since_last_order(x):
    return (latest_order - x.max()).days
def days_since_first_order(x):
    return (latest_order - x.min()).days

# %%
df_customers = df.groupby('CustomerID').agg({'InvoiceNo': ['first', 'nunique']
                                             , 'TotalPrice': ['sum','mean']
                                             , 'Quantity' : 'sum'
                                             , 'ItemID':'nunique'
                                             , 'InvoiceDate' :['first', 'last',days_since_last_order , days_since_first_order]
                                             , 'Month': 'first'
                                             , 'Week': 'first'
                                             , 'Time': 'first'
                                             , 'Country' :'first'
                                             , 'Client':'first'
                                             , 'CountryUK':'first'})

#Flattening multi level indexes
if 'InvoiceNo first' not in df_customers.columns:
    df_customers.columns = [' '.join(col).replace(' first', '').strip() for col in df_customers.columns.values]
    #df_customers.columns = [' '.join(col).strip() for col in df_customers.columns.values]
    
df_customers['days_active'] = df_customers['InvoiceDate days_since_first_order'] - df_customers['InvoiceDate days_since_last_order']
df_customers.shape
# Out:
# (4335, 17)

# %%
df_customers = df_customers.join(df_first_order.add_prefix('firstorder_'), on='InvoiceNo')

# %%
df_customers['Order_value'] = df_customers['TotalPrice sum']
df_customers['Order_value_avg'] = df_customers['Order_value'] / (df_customers['InvoiceDate days_since_first_order'])

# %%
df_customers_country= pd.get_dummies(df_customers['Country'])

# %%
df_customers.head(1)
# Out:
#            InvoiceNo  InvoiceNo nunique  TotalPrice sum  TotalPrice mean  \
# CustomerID
# 12346.000     541431                  1       77183.600        77183.600
#
#             Quantity sum  ItemID nunique         InvoiceDate  \
# CustomerID
# 12346.000          74215               1 2011-01-18 10:01:00
#
#               InvoiceDate last  InvoiceDate days_since_last_order  \
# CustomerID
# 12346.000  2011-01-18 10:01:00                                325
#
#             InvoiceDate days_since_first_order  Month  Week   Time  \
# CustomerID
# 12346.000                                  325      1     3 10.017
#
#                    Country  Client  CountryUK  days_active  \
# CustomerID
# 12346.000   United Kingdom    4325       True            0
#
#            firstorder_CustomerID  firstorder_CountryUK  \
# CustomerID
# 12346.000              12346.000                  True
#
#             firstorder_Country_GPD  firstorder_TotalPrice  \
# CustomerID
# 12346.000                43620.000              77183.600
#
#             firstorder_Quantity  firstorder_UnitPrice_avg  \
# CustomerID
# 12346.000                 74215                     1.040
#
#             firstorder_UnitPrice_max  firstorder_Week  firstorder_Time  \
# CustomerID
# 12346.000                      1.040                3           10.017
#
#             firstorder_Distinct_items_count firstorder_FirstInvoice  \
# CustomerID
# 12346.000                                 1                  541431
#
#             Order_value  Order_value_avg
# CustomerID
# 12346.000     77183.600          237.488

# %% [markdown]
# ### Customers graphs & stats

# %%
df_plot = df_customers[["Country", "InvoiceNo"]].groupby("Country").count()
df_plot.shape

df_plt_results = pd.DataFrame({'Clients': [df_plot.loc['United Kingdom'].values[0], df_plot.loc[~df_plot.index.isin(['United Kingdom'])].sum()[0]]},
                  index=['United Kingdom', 'Autres'])
plot = df_plt_results.plot.pie(y='Clients'
                               , figsize=(5, 5)
                               , autopct='%1.1f%%'
                                , title = 'Clients par pays'
                               , fontsize=15 
                               , legend = False)
plot = plt.ylabel('')
# Out:
# (37, 1)

# %%
df_plot = df_customers[["Country", 'InvoiceNo', "TotalPrice sum"]].groupby("Country").agg({'InvoiceNo': 'count', 'TotalPrice sum':'sum'})
df_plot['Average spent'] = df_plot['TotalPrice sum']/df_plot['InvoiceNo']
df_plot[df_plot.InvoiceNo > 10].sort_values('Average spent')
# Out:
#                 InvoiceNo  TotalPrice sum  Average spent
# Country
# Italy                  14       17483.240       1248.803
# Portugal               19       29151.900       1534.311
# Belgium                24       41551.260       1731.303
# Finland                12       21994.880       1832.907
# United Kingdom       3917     7265185.704       1854.783
# Spain                  28       60354.300       2155.511
# France                 87      199441.940       2292.436
# Germany                94      226382.150       2408.321
# Switzerland            20       56419.290       2820.965

# %%
df_plot = df_customers.groupby("CountryUK").agg(
    {'InvoiceNo': 'count'
     ,'InvoiceNo nunique':['mean', 'median']
     , 'TotalPrice sum':['sum', 'mean', 'median']
     , 'Quantity sum' : ['mean', 'median']
    })
df_plot
# Out:
#           InvoiceNo InvoiceNo nunique        TotalPrice sum                    \
#               count              mean median            sum     mean   median
# CountryUK
# False           418             4.452      2    1568603.260 3752.639 1025.700
# True           3917             4.240      2    7265185.704 1854.783  645.650
#
#           Quantity sum
#                   mean  median
# CountryUK
# False         2178.608 524.500
# True          1081.034 365.000

# %%
df_customers['TotalPrice sum'].describe()
# Out:
# count     4335.000
# mean      2037.783
# std       8966.233
# min          3.750
# 25%        306.290
# 50%        668.560
# 75%       1651.605
# max     280206.020
# Name: TotalPrice sum, dtype: float64

# %% [markdown]
# ### Items graphs & stats

# %%
plt.rcParams["figure.figsize"] = (12,5)
#GRaph group repartition
nb_groups=2

df_plot = df_customers['TotalPrice sum'].values.round().round(0).astype(int)
df_plot = pd.DataFrame(df_plot, columns = ['Nb Clients'])
df_plot.plot.hist( bins =np.linspace(1, 10000, 50) ,histtype='bar', alpha =0.5)

plt.yscale('log')

legend(plt, 'Répartition des clients par dépenses', 'Dépenses', 'Nb Clients' )
plt.show()

# %% [markdown]
# ## Quantile groups

# %%
def quantile_group(x,col,quantile_dict,reverse):
    quantile_dict = quantile_dict[col]
    if reverse == False:
        order = 0
    elif reverse == True:
        order = len(quantile_dict)+2
        
    group_num = 1
    for quant, val in quantile_dict.items():
        if x <= val:
            return abs(group_num-order)
        group_num+=1
        
    return abs(group_num-order)

# %%
nb_groups=4
#q = (11-np.logspace(1,0, nb_groups+1, base =10 )[1:-1])/10
q = np.linspace(0,1, nb_groups+1)[1:-1]
quantiles = df_customers[['Order_value_avg']].quantile(q=q).to_dict()
quantiles
df_customers['Group']  = df_customers['Order_value_avg'].apply(quantile_group, args=('Order_value_avg',quantiles,True))
# Out:
# {'Order_value_avg': {0.25: 1.8221334172435495,
#   0.5: 4.385270270270271,
#   0.75: 9.884016409845907}}

# %%
#GRaph group repartition
plt.rcParams["figure.figsize"] = (15,4)

df_plot=pd.DataFrame( np.ones((df_customers.groupby('Group').agg('count').values.max(),nb_groups)), columns=['Importance 1','Importance 2','Importance 3','Importance 4'])
for Group in range (1,5):
    vals = df_customers[df_customers['Group'] == Group]['Order_value_avg'].values.round().round(0).astype(int)
    df_plot.iloc[:len(vals),Group-1] = vals
    
df_plot.plot.hist( bins =np.linspace(1, 50, 50) ,histtype='bar', stacked=True, alpha=0.5)

legend(plt, 'Répartition des '+str(nb_groups)+' quantiles', 'Dépenses / jours d\'ancienneté', 'Nb clients')
plt.show()

# %%
nb_groups=4
#q = (11-np.logspace(1,0, nb_groups+1, base =10 )[1:-1])/10
q = np.linspace(0,1, nb_groups+1)[1:-1]
quantiles = df_customers[['Order_value']].quantile(q=q).to_dict()
quantiles
df_customers['Quantile_CA']  = df_customers['Order_value'].apply(quantile_group, args=('Order_value',quantiles,True))

plt.rcParams["figure.figsize"] = (12,5)

df_plot=pd.DataFrame( np.ones((df_customers.groupby('Quantile_CA').agg('count').values.max(),nb_groups)), columns=['Quantile 1','Quantile 2','Quantile 3','Quantile 4'])
for Group in range (1,5):
    vals = df_customers[df_customers['Quantile_CA'] == Group]['Order_value'].values.round().round(0).astype(int)
    df_plot.iloc[:len(vals),Group-1] = vals
    

df_plot.plot.hist( bins =np.linspace(1, 10000, 40) ,histtype='bar',stacked=True, alpha =0.5)
plt.yscale('log')

legend(plt, 'Répartition des clients par dépenses', 'Dépenses', 'Nb Clients (Log)' )
plt.show()
# Out:
# {'Order_value': {0.25: 306.29, 0.5: 668.5600000000002, 0.75: 1651.605}}

# %%
df_customers = df_customers[df_customers['Month']<12]

# %%
plt.rcParams["figure.figsize"] = (15,6)
f, axes = plt.subplots(1, 1)

df_plot = df_customers.groupby(['Quantile_CA', 'Month'] ).count().reset_index()
ax = sns.lineplot(x="Month", y='InvoiceNo', hue="Quantile_CA", data=df_plot)
silent = ax.set_title('Number of new customers per group around the year')

legend(plt, 'Répartition des '+str(nb_groups)+' quantiles', 'week', 'Nb utilisateurs')

# %%
plt.rcParams["figure.figsize"] = (15,5)
f, axes = plt.subplots(1, 1)

df_plot = df_customers.groupby(['Group', 'Week'] ).count().reset_index()
df_plot['Importance'] = df_plot['Group'].apply(lambda x: 'Groupe '+str(x))
ax = sns.lineplot(x="Week", y='InvoiceNo', hue="Importance", data=df_plot)
silent = ax.set_title('Number of new customers per group around the year')

legend(plt, 'Répartition des nouveaux clients', 'Semaine de l\'année', 'Nb nouveaux clients')
plt.plot([35, 35], [-5,100], linewidth=2, linestyle='--' )

# %% [markdown]
# Week 35 (month 9) is starting to show growing gap between groups

# %%
df_customers = df_customers[df_customers['Month']<9]

# %% [markdown]
# ## Reset quantile group over smaller group

# %%
nb_groups=4
#q = (11-np.logspace(1,0, nb_groups+1, base =10 )[1:-1])/10
q = np.linspace(0,1, nb_groups+1)[1:-1]
quantiles = df_customers[['Order_value_avg']].quantile(q=q).to_dict()
quantiles
df_customers['Group']  = df_customers['Order_value_avg'].apply(quantile_group, args=('Order_value_avg',quantiles,True))
# Out:
# {'Order_value_avg': {0.25: 1.4244251308900522,
#   0.5: 3.322912912912912,
#   0.75: 7.5668657078215915}}

# %%
#GRaph group repartition
plt.rcParams["figure.figsize"] = (15,4)

df_plot=pd.DataFrame( np.ones((df_customers.groupby('Group').agg('count').values.max(),nb_groups)), columns=['1','2','3','4'])
for Group in range (1,5):
    vals = df_customers[df_customers['Group'] == Group]['Order_value_avg'].values.round().round(0).astype(int)
    df_plot.iloc[:len(vals),Group-1] = vals
    
df_plot.plot.hist( bins =np.linspace(1, 50, 50) ,histtype='bar', stacked=True, alpha=0.5)

legend(plt, 'Répartition des '+str(nb_groups)+' quantiles', 'Dépenses / jours d\'ancienneté', 'Nb utilisateurs')
plt.show()

# %%
plt.rcParams["figure.figsize"] = (15,5)
f, axes = plt.subplots(1, 1)

df_plot = df_customers.groupby(['Group', 'Week'] ).count().reset_index()
df_plot['Importance'] = df_plot['Group'].apply(lambda x: 'Groupe '+str(x))
ax = sns.lineplot(x="Week", y='InvoiceNo', hue="Importance", data=df_plot)
legend(plt, 'Répartition des nouveaux clients', 'Semaine de l\'année', 'Nb nouveaux clients')
plt.plot([35, 35], [-5,100], linewidth=2, linestyle='--' )

# %%
#23

# %% [markdown]
# ##### Note :bias for customers who arrived late in the year!
# Should do something related to month

# %%
#24

# %%
plt.rcParams["figure.figsize"] = (8,3)
f, axes = plt.subplots(1, 1)

df_plot = df_customers.groupby(['Group', 'CountryUK'] ).count().reset_index()
ax = sns.barplot(x="Group", y='InvoiceNo', hue="CountryUK", data=df_plot)
silent = ax.set_title('Number of customers per group')

# %%
plt.rcParams["figure.figsize"] = (8,3)
f, axes = plt.subplots(1, 1)

df_plot = df_customers[['Group', 'Order_value', 'CountryUK']].groupby(['Group', 'CountryUK'] ).sum().reset_index()
ax = sns.barplot(x="Group", y='Order_value', hue="CountryUK", data=df_plot)
silent = ax.set_title('Value spent per group')

# %% [markdown]
# ## Testing models

# %% [markdown]
#  setting X and y

# %%
df_customers.head(1)
# Out:
#            InvoiceNo  InvoiceNo nunique  TotalPrice sum  TotalPrice mean  \
# CustomerID
# 12346.000     541431                  1       77183.600        77183.600
#
#             Quantity sum  ItemID nunique         InvoiceDate  \
# CustomerID
# 12346.000          74215               1 2011-01-18 10:01:00
#
#               InvoiceDate last  InvoiceDate days_since_last_order  \
# CustomerID
# 12346.000  2011-01-18 10:01:00                                325
#
#             InvoiceDate days_since_first_order  Month  Week   Time  \
# CustomerID
# 12346.000                                  325      1     3 10.017
#
#                    Country  Client  CountryUK  days_active  \
# CustomerID
# 12346.000   United Kingdom    4325       True            0
#
#            firstorder_CustomerID  firstorder_CountryUK  \
# CustomerID
# 12346.000              12346.000                  True
#
#             firstorder_Country_GPD  firstorder_TotalPrice  \
# CustomerID
# 12346.000                43620.000              77183.600
#
#             firstorder_Quantity  firstorder_UnitPrice_avg  \
# CustomerID
# 12346.000                 74215                     1.040
#
#             firstorder_UnitPrice_max  firstorder_Week  firstorder_Time  \
# CustomerID
# 12346.000                      1.040                3           10.017
#
#             firstorder_Distinct_items_count firstorder_FirstInvoice  \
# CustomerID
# 12346.000                                 1                  541431
#
#             Order_value  Order_value_avg  Group  Quantile_CA
# CustomerID
# 12346.000     77183.600          237.488      1            1

# %%
df_customers_country.index=df_customers_country.index.astype('int')

# %%
X = df_first_order[df_first_order['CustomerID'].isin(df_customers.index)].sort_values(by='CustomerID')
X.index = X.CustomerID
X = X.join(df_customers_country)
#X = X.join(df_first_items, on ='FirstInvoice')
X = X[[  'TotalPrice', 'Quantity', 'UnitPrice_avg',
       'Week',  'Distinct_items_count']]
# old : X = df_customers[['firstorder_TotalPrice', 'firstorder_Quantity', 'firstorder_UnitPrice' ,'firstorder_Week', 'CountryUK']]
#X = df_customers[['firstorder_TotalPrice', 'firstorder_Quantity', 'firstorder_UnitPrice' ,'firstorder_Week', 'CountryUK']]
y = df_customers.sort_values(by='CustomerID')['Group']
X.shape
y.shape
# Out:
# (3315, 5)
# (3315,)

# %%
X.columns
# Out:
# Index(['TotalPrice', 'Quantity', 'UnitPrice_avg', 'Week',
#        'Distinct_items_count'],
#       dtype='object')

# %% [markdown]
# #### Dividing between Test set and Train set

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=42, stratify=y )

# %%
X_train.size
# Out:
# 12430

# %% [markdown]
# #### Cross correlations

# %%
if len(X.columns) < 20 :
    plt.rcParams["figure.figsize"] = (7,7)
    xy = pd.concat([X, y], axis=1, join='inner')
    fig = sns.heatmap(xy.corr(), annot = True,fmt = ".2f",square=True, cmap='RdYlGn')
    plt.title('Tableau de Correlation')
else:
    print('Too many columns for corr display')
# Out:
# Text(0.5,1,'Tableau de Correlation')

# %% [markdown]
# ### KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 45)

# %%
knn.n_neighbors = int(round(hyper_param(knn, X, y)))
# Out:
# Highest score is 0.43346932563528534 Hyperparam  n_neighbors : 14
# 14
# Highest score is 0.43316821151303303 Hyperparam  n_neighbors : 28
# 28
# Highest score is 0.42954175012764617 Hyperparam  n_neighbors : 29
# 29
# Highest score is 0.4325717109828103 Hyperparam  n_neighbors : 12
# 12

# %%
# %timeit for _ in range(10):silent = knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
print('Score of :',knn.score(X_test, y_test))

print(classification_report(y_test, y_pred))
# Out:
# 15 ms ± 141 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Score of : 0.4330518697225573
#              precision    recall  f1-score   support
#
#           1       0.48      0.58      0.53       207
#           2       0.34      0.33      0.33       207
#           3       0.35      0.27      0.31       207
#           4       0.52      0.55      0.54       208
#
# avg / total       0.42      0.43      0.43       829

# %% [markdown]
# ## Logistic Regression

# %%
logreg = LogisticRegression(penalty  = 'l1')
# %timeit for _ in range(10):silent = logreg.fit(X_train,y_train)
y_pred = logreg.predict(X_test)

print('Score of :',logreg.score(X_test, y_test))
print(classification_report(y_test, y_pred))
# Out:
# 154 ms ± 847 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# Score of : 0.4632086851628468
#              precision    recall  f1-score   support
#
#           1       0.51      0.61      0.56       207
#           2       0.40      0.20      0.27       207
#           3       0.38      0.29      0.33       207
#           4       0.49      0.75      0.59       208
#
# avg / total       0.45      0.46      0.44       829

# %% [markdown]
# ### DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.max_depth = hyper_param(model, X, y, 'max_depth')
model.min_samples_split = hyper_param(model, X, y, 'min_samples_split')
model.min_samples_leaf = hyper_param(model, X, y, 'min_samples_leaf')
# Out:
# Highest score is 0.4461300289331396 Hyperparam  max_depth : 4
# 4
# Highest score is 0.4461300289331396 Hyperparam  max_depth : 4
# 4
# Highest score is 0.4461300289331396 Hyperparam  min_samples_split : 2
# 2
# Highest score is 0.4461300289331396 Hyperparam  min_samples_split : 2
# 2
# Highest score is 0.4515599020724507 Hyperparam  min_samples_leaf : 31
# 31
# Highest score is 0.45095603733815115 Hyperparam  min_samples_leaf : 25
# 25

# %%
# %timeit for _ in range(10):silent = model.fit(X_train,y_train)
y_pred = model.predict(X_test)

print('Score of :',model.score(X_test, y_test))
print(classification_report(y_test, y_pred))
# Out:
# 30.4 ms ± 409 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# Score of : 0.44752714113389624
#              precision    recall  f1-score   support
#
#           1       0.56      0.54      0.55       207
#           2       0.31      0.35      0.33       207
#           3       0.46      0.06      0.10       207
#           4       0.48      0.84      0.61       208
#
# avg / total       0.45      0.45      0.40       829

# %% [markdown]
# # Random forests

# %%
rf = RandomForestClassifier()

# %%
rf.n_estimators = hyper_param(rf, X, y, 'n_estimators')
rf.max_depth = hyper_param(rf, X, y, 'max_depth')
# Out:
# Highest score is 0.43951288244766507 Hyperparam  n_estimators : 41
# 41
# Highest score is 0.44465064215859545 Hyperparam  n_estimators : 33
# 33
# Highest score is 0.4576124595787021 Hyperparam  max_depth : 8
# 8
# Highest score is 0.4560962517837739 Hyperparam  max_depth : 7
# 7

# %%
rf.min_samples_split = hyper_param(rf, X, y, 'min_samples_split')
rf.min_samples_leaf = hyper_param(rf, X, y, 'min_samples_leaf')
# Out:
# Highest score is 0.46242128484086775 Hyperparam  min_samples_split : 15
# 15
# Highest score is 0.45670093476297086 Hyperparam  min_samples_split : 20
# 20
# Highest score is 0.4639424021051804 Hyperparam  min_samples_split : 14
# 14
# Highest score is 0.46423860675804823 Hyperparam  min_samples_leaf : 4
# 4
# Highest score is 0.4630316955343467 Hyperparam  min_samples_leaf : 4
# 4

# %%
rf.max_features  = 'sqrt'

# %%
# %timeit for _ in range(10):silent = rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)

print('Score of :',rf.score(X_test, y_test))
print(classification_report(y_test, y_pred))
# Out:
# 693 ms ± 6.21 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Score of : 0.45476477683956573
#              precision    recall  f1-score   support
#
#           1       0.55      0.55      0.55       207
#           2       0.34      0.33      0.33       207
#           3       0.39      0.31      0.35       207
#           4       0.51      0.63      0.57       208
#
# avg / total       0.45      0.45      0.45       829

# %%
nb_features_to_keep = 7
df_features_importance = pd.DataFrame(rf.feature_importances_, index =X.columns, columns =['Importance'])

#df_features_importance.loc['United Kingdom']
df_features_importance.sort_values(by='Importance', ascending=False).head(10)
# Out:
#                       Importance
# TotalPrice                 0.519
# Quantity                   0.289
# Distinct_items_count       0.097
# Week                       0.049
# UnitPrice_avg              0.046

# %%
#Reducing dimensions
#return
##X=X[df_features_importance.sort_values(by=0, ascending=False).head(nb_features_to_keep).index]
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=42, stratify=y )

# %%
rf.estimators_[1]
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=4,
#             max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=4, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False,
#             random_state=931208158, splitter='best')

# %%
joblib.dump(rf, 'exported_rf_model.joblib')
# Out:
# ['exported_rf_model.joblib']

# %% [markdown]
# ## Visualize tree

# %%
# Extract single tree
estimator = rf.estimators_[1]

from sklearn.tree import export_graphviz
# Export as dot file
export_graphviz(estimator, out_file='tree.dot', 
                feature_names = X.columns,
                class_names = '1234',
                rounded = True, proportion = False, 
                precision = 2, filled = True
               )

# %%
##! Not working. did it manually :
# cd C:\Users\Maly-Fenix\OC_Project5;dot -Tpng tree.dot -o tree.png -Gdpi=400

# Convert to png using system command (requires Graphviz)
from subprocess import call
call(['dot', '-Tpng', 'tree.dot', '-o', 'tree.png', '-Gdpi=400'],  shell=True)
# Out:
# 0

# %% [markdown]
# ### Display the tree

# %%
# Display in jupyter notebook
from IPython.display import Image
#Image(filename = 'tree.png')

# %% [markdown]
# ## Visualize results

# %%
df_results =pd.DataFrame(X_test, columns =X.columns )
df_results['Predicted'] = y_pred
df_results['Group'] = y_test.values

# %%
df_results.head(3)
# Out:
#             TotalPrice  Quantity  UnitPrice_avg  Week  Distinct_items_count  \
# CustomerID
# 12394.000      381.080       182          3.015    18                    21
# 17193.000      299.040        96          3.115    24                     4
# 17758.000      583.790       407          2.052    13                    68
#
#             Predicted  Group
# CustomerID
# 12394.000           2      2
# 17193.000           3      1
# 17758.000           1      1

# %%
from sklearn.metrics import confusion_matrix

# %%
y_test.shape
# Out:
# (829,)

# %%
price_col = 'Quantity'

for Group in range (1,5):
    silent = sns.kdeplot(df_results[df_results['Group']==Group][price_col], bw = 10, label = 'Goup '+str(Group))

plt.xscale('log')
legend(plt, 'Répartition des groupes par prix', 'Prix première commande', 'Quantile')
plt.show()


for Predicted in range (1,5):
    silent = sns.kdeplot(df_results[df_results['Predicted']==Predicted][price_col], bw = 10, label = 'Goup '+str(Predicted))

plt.xscale('log')
legend(plt, 'Répartition des prédictions par prix', 'Prix première commande', 'Quantile')
plt.show()

for Predicted in range (1,5):
    silent = sns.kdeplot(df_results[df_results['Predicted']==Predicted]['Group'], bw = .48, label = 'Goup '+str(Predicted))
    
legend(plt, 'Répartition des prédictions par groupes', 'Groupes réels', 'Quantile')
plt.gca().invert_xaxis()
plt.show()

# %%
df_plot=pd.DataFrame( np.ones((df_results.groupby('Predicted').agg('count').values.max(),nb_groups)), columns=['1','2','3','4'])
for Predicted in range (1,5):
    vals = df_results[df_results['Predicted'] == Predicted]['Group'].values.round().round(0).astype(int)
    df_plot.iloc[:len(vals),Predicted-1] = vals
    
df_plot.plot.hist( histtype='bar', stacked=True, alpha=0.5, align='mid')

#legend(plt, 'Répartition des '+str(nb_groups)+' quantiles', 'Dépenses / ancienneté', 'Nb utilisateurs')
plt.show()

# %% [markdown]
# ## Analyze results

# %%
df_detail_results = df_results.join(df_customers, rsuffix ='customer')

# %%
cm = confusion_matrix(y_test, y_pred, labels =[1,2,3,4])

# %%
plt.rcParams["figure.figsize"] = (6,6)
silent =plot_confusion_matrix(cm, [1,2,3,4], True)
# Out:
# Normalized confusion matrix
# [[0.54589372 0.20289855 0.14009662 0.11111111]
#  [0.30917874 0.32850242 0.14975845 0.21256039]
#  [0.11111111 0.29951691 0.30917874 0.28019324]
#  [0.02884615 0.14423077 0.19230769 0.63461538]]

# %% [markdown]
# #### Small clients predicted as big

# %%
df_analyze = df_detail_results.query('Group ==4 and Predicted ==1')#['InvoiceDate days_since_first_order', 'InvoiceNo nunique']
df_analyze
df_analyze.describe(include='all')
# Out:
#             CountryUK  TotalPrice  Quantity  UnitPrice_avg  UnitPrice_max  \
# CustomerID
# 13506.000        True     301.120       232          2.835          9.950
# 16125.000        True     289.350       124          3.209          7.950
# 14142.000        True     311.810       313          1.770          8.500
# 17226.000        True     393.490       406          2.575         12.750
# 17978.000        True     300.920       499          2.363          7.950
# 15326.000        True     311.710       386          1.452          4.950
# 17525.000        True     422.700        82          6.006          7.950
#
#             Week   Time  Distinct_items_count  Predicted  Group InvoiceNo  \
# CustomerID
# 13506.000     -4 12.250                    17          1      4    537129
# 16125.000     -3 15.800                    13          1      4    537650
# 14142.000     -4 16.550                    22          1      4    536587
# 17226.000      5 11.867                    21          1      4    543190
# 17978.000     -3 14.083                    12          1      4    538068
# 15326.000      2 11.633                    29          1      4    540604
# 17525.000     -2 12.083                     9          1      4    538994
#
#             InvoiceNo nunique  TotalPrice sum  TotalPrice mean  Quantity sum  \
# CustomerID
# 13506.000                   2         458.520           17.635           324
# 16125.000                   1         289.350           22.258           124
# 14142.000                   1         311.810           14.173           313
# 17226.000                   1         393.490           18.738           406
# 17978.000                   1         300.920           25.077           499
# 15326.000                   1         311.710           10.749           386
# 17525.000                   1         422.700           46.967            82
#
#             ItemID nunique         InvoiceDate    InvoiceDate last  \
# CustomerID
# 13506.000               26 2010-12-05 12:15:00 2011-01-27 13:53:00
# 16125.000               13 2010-12-07 15:48:00 2010-12-07 15:48:00
# 14142.000               22 2010-12-01 16:33:00 2010-12-01 16:33:00
# 17226.000               21 2011-02-04 11:52:00 2011-02-04 11:52:00
# 17978.000               12 2010-12-09 14:05:00 2010-12-09 14:05:00
# 15326.000               29 2011-01-10 11:38:00 2011-01-10 11:38:00
# 17525.000                9 2010-12-15 12:05:00 2010-12-15 12:05:00
#
#             InvoiceDate days_since_last_order  \
# CustomerID
# 13506.000                                 315
# 16125.000                                 366
# 14142.000                                 372
# 17226.000                                 308
# 17978.000                                 364
# 15326.000                                 333
# 17525.000                                 359
#
#             InvoiceDate days_since_first_order  Month  Weekcustomer  \
# CustomerID
# 13506.000                                  369      0            -4
# 16125.000                                  366      0            -3
# 14142.000                                  372      0            -4
# 17226.000                                  308      2             5
# 17978.000                                  364      0            -3
# 15326.000                                  333      1             2
# 17525.000                                  359      0            -2
#
#             Timecustomer         Country  Client  CountryUKcustomer  \
# CustomerID
# 13506.000         12.250  United Kingdom    1660               True
# 16125.000         15.800  United Kingdom    1003               True
# 14142.000         16.550  United Kingdom    1128               True
# 17226.000         11.867  United Kingdom    1468               True
# 17978.000         14.083  United Kingdom    1051               True
# 15326.000         11.633  United Kingdom    1127               True
# 17525.000         12.083  United Kingdom    1573               True
#
#             CountrySwitz  days_active firstorder_CustomerID  \
# CustomerID
# 13506.000          False           54             13506.000
# 16125.000          False            0             16125.000
# 14142.000          False            0             14142.000
# 17226.000          False            0             17226.000
# 17978.000          False            0             17978.000
# 15326.000          False            0             15326.000
# 17525.000          False            0             17525.000
#
#             firstorder_CountryUK  firstorder_TotalPrice  firstorder_Quantity  \
# CustomerID
# 13506.000                   True                301.120                  232
# 16125.000                   True                289.350                  124
# 14142.000                   True                311.810                  313
# 17226.000                   True                393.490                  406
# 17978.000                   True                300.920                  499
# 15326.000                   True                311.710                  386
# 17525.000                   True                422.700                   82
#
#             firstorder_UnitPrice_avg  firstorder_UnitPrice_max  \
# CustomerID
# 13506.000                      2.835                     9.950
# 16125.000                      3.209                     7.950
# 14142.000                      1.770                     8.500
# 17226.000                      2.575                    12.750
# 17978.000                      2.363                     7.950
# 15326.000                      1.452                     4.950
# 17525.000                      6.006                     7.950
#
#             firstorder_Week  firstorder_Time  firstorder_Distinct_items_count  \
# CustomerID
# 13506.000                -4           12.250                               17
# 16125.000                -3           15.800                               13
# 14142.000                -4           16.550                               22
# 17226.000                 5           11.867                               21
# 17978.000                -3           14.083                               12
# 15326.000                 2           11.633                               29
# 17525.000                -2           12.083                                9
#
#            firstorder_FirstInvoice  Order_value  Order_value_avg  \
# CustomerID
# 13506.000                   537129      458.520            1.243
# 16125.000                   537650      289.350            0.791
# 14142.000                   536587      311.810            0.838
# 17226.000                   543190      393.490            1.278
# 17978.000                   538068      300.920            0.827
# 15326.000                   540604      311.710            0.936
# 17525.000                   538994      422.700            1.177
#
#             Groupcustomer  Quantile_CA
# CustomerID
# 13506.000               4            3
# 16125.000               4            4
# 14142.000               4            3
# 17226.000               4            3
# 17978.000               4            4
# 15326.000               4            3
# 17525.000               4            3
#        CountryUK  TotalPrice  Quantity  UnitPrice_avg  UnitPrice_max   Week  \
# count          7       7.000     7.000          7.000          7.000  7.000
# unique         1         nan       nan            nan            nan    nan
# top         True         nan       nan            nan            nan    nan
# freq           7         nan       nan            nan            nan    nan
# first        NaN         nan       nan            nan            nan    nan
# last         NaN         nan       nan            nan            nan    nan
# mean         NaN     333.014   291.714          2.887          8.571 -1.286
# std          NaN      52.533   153.322          1.501          2.368  3.450
# min          NaN     289.350    82.000          1.452          4.950 -4.000
# 25%          NaN     301.020   178.000          2.067          7.950 -3.500
# 50%          NaN     311.710   313.000          2.575          7.950 -3.000
# 75%          NaN     352.650   396.000          3.022          9.225  0.000
# max          NaN     422.700   499.000          6.006         12.750  5.000
#
#          Time  Distinct_items_count  Predicted  Group InvoiceNo  \
# count   7.000                 7.000      7.000  7.000         7
# unique    nan                   nan        nan    nan         7
# top       nan                   nan        nan    nan    538994
# freq      nan                   nan        nan    nan         1
# first     nan                   nan        nan    nan       NaN
# last      nan                   nan        nan    nan       NaN
# mean   13.467                17.571      1.000  4.000       NaN
# std     2.027                 6.925      0.000  0.000       NaN
# min    11.633                 9.000      1.000  4.000       NaN
# 25%    11.975                12.500      1.000  4.000       NaN
# 50%    12.250                17.000      1.000  4.000       NaN
# 75%    14.942                21.500      1.000  4.000       NaN
# max    16.550                29.000      1.000  4.000       NaN
#
#         InvoiceNo nunique  TotalPrice sum  TotalPrice mean  Quantity sum  \
# count               7.000           7.000            7.000         7.000
# unique                nan             nan              nan           nan
# top                   nan             nan              nan           nan
# freq                  nan             nan              nan           nan
# first                 nan             nan              nan           nan
# last                  nan             nan              nan           nan
# mean                1.143         355.500           22.228       304.857
# std                 0.378          68.011           11.903       151.279
# min                 1.000         289.350           10.749        82.000
# 25%                 1.000         306.315           15.904       218.500
# 50%                 1.000         311.810           18.738       324.000
# 75%                 1.000         408.095           23.667       396.000
# max                 2.000         458.520           46.967       499.000
#
#         ItemID nunique          InvoiceDate     InvoiceDate last  \
# count            7.000                    7                    7
# unique             nan                    7                    7
# top                nan  2010-12-07 15:48:00  2010-12-07 15:48:00
# freq               nan                    1                    1
# first              nan  2010-12-01 16:33:00  2010-12-01 16:33:00
# last               nan  2011-02-04 11:52:00  2011-02-04 11:52:00
# mean            18.857                  NaN                  NaN
# std              7.603                  NaN                  NaN
# min              9.000                  NaN                  NaN
# 25%             12.500                  NaN                  NaN
# 50%             21.000                  NaN                  NaN
# 75%             24.000                  NaN                  NaN
# max             29.000                  NaN                  NaN
#
#         InvoiceDate days_since_last_order  InvoiceDate days_since_first_order  \
# count                               7.000                               7.000
# unique                                nan                                 nan
# top                                   nan                                 nan
# freq                                  nan                                 nan
# first                                 nan                                 nan
# last                                  nan                                 nan
# mean                              345.286                             353.000
# std                                26.266                              23.692
# min                               308.000                             308.000
# 25%                               324.000                             346.000
# 50%                               359.000                             364.000
# 75%                               365.000                             367.500
# max                               372.000                             372.000
#
#         Month  Weekcustomer  Timecustomer         Country   Client  \
# count   7.000         7.000         7.000               7    7.000
# unique    nan           nan           nan               1      nan
# top       nan           nan           nan  United Kingdom      nan
# freq      nan           nan           nan               7      nan
# first     nan           nan           nan             NaN      nan
# last      nan           nan           nan             NaN      nan
# mean    0.429        -1.286        13.467             NaN 1287.143
# std     0.787         3.450         2.027             NaN  271.084
# min     0.000        -4.000        11.633             NaN 1003.000
# 25%     0.000        -3.500        11.975             NaN 1089.000
# 50%     0.000        -3.000        12.250             NaN 1128.000
# 75%     0.500         0.000        14.942             NaN 1520.500
# max     2.000         5.000        16.550             NaN 1660.000
#
#        CountryUKcustomer CountrySwitz  days_active  firstorder_CustomerID  \
# count                  7            7        7.000                  7.000
# unique                 1            1          nan                  7.000
# top                 True        False          nan              15326.000
# freq                   7            7          nan                  1.000
# first                NaN          NaN          nan                    nan
# last                 NaN          NaN          nan                    nan
# mean                 NaN          NaN        7.714                    nan
# std                  NaN          NaN       20.410                    nan
# min                  NaN          NaN        0.000                    nan
# 25%                  NaN          NaN        0.000                    nan
# 50%                  NaN          NaN        0.000                    nan
# 75%                  NaN          NaN        0.000                    nan
# max                  NaN          NaN       54.000                    nan
#
#        firstorder_CountryUK  firstorder_TotalPrice  firstorder_Quantity  \
# count                     7                  7.000                7.000
# unique                    1                    nan                  nan
# top                    True                    nan                  nan
# freq                      7                    nan                  nan
# first                   NaN                    nan                  nan
# last                    NaN                    nan                  nan
# mean                    NaN                333.014              291.714
# std                     NaN                 52.533              153.322
# min                     NaN                289.350               82.000
# 25%                     NaN                301.020              178.000
# 50%                     NaN                311.710              313.000
# 75%                     NaN                352.650              396.000
# max                     NaN                422.700              499.000
#
#         firstorder_UnitPrice_avg  firstorder_UnitPrice_max  firstorder_Week  \
# count                      7.000                     7.000            7.000
# unique                       nan                       nan              nan
# top                          nan                       nan              nan
# freq                         nan                       nan              nan
# first                        nan                       nan              nan
# last                         nan                       nan              nan
# mean                       2.887                     8.571           -1.286
# std                        1.501                     2.368            3.450
# min                        1.452                     4.950           -4.000
# 25%                        2.067                     7.950           -3.500
# 50%                        2.575                     7.950           -3.000
# 75%                        3.022                     9.225            0.000
# max                        6.006                    12.750            5.000
#
#         firstorder_Time  firstorder_Distinct_items_count  \
# count             7.000                            7.000
# unique              nan                              nan
# top                 nan                              nan
# freq                nan                              nan
# first               nan                              nan
# last                nan                              nan
# mean             13.467                           17.571
# std               2.027                            6.925
# min              11.633                            9.000
# 25%              11.975                           12.500
# 50%              12.250                           17.000
# 75%              14.942                           21.500
# max              16.550                           29.000
#
#        firstorder_FirstInvoice  Order_value  Order_value_avg  Groupcustomer  \
# count                        7        7.000            7.000          7.000
# unique                       7          nan              nan            nan
# top                     538994          nan              nan            nan
# freq                         1          nan              nan            nan
# first                      NaN          nan              nan            nan
# last                       NaN          nan              nan            nan
# mean                       NaN      355.500            1.013          4.000
# std                        NaN       68.011            0.212          0.000
# min                        NaN      289.350            0.791          4.000
# 25%                        NaN      306.315            0.832          4.000
# 50%                        NaN      311.810            0.936          4.000
# 75%                        NaN      408.095            1.210          4.000
# max                        NaN      458.520            1.278          4.000
#
#         Quantile_CA
# count         7.000
# unique          nan
# top             nan
# freq            nan
# first           nan
# last            nan
# mean          3.286
# std           0.488
# min           3.000
# 25%           3.000
# 50%           3.000
# 75%           3.500
# max           4.000

# %% [markdown]
# Conclusion : They have very low amount of invoices. (1 or 2) <br> Big first order. <br> Old clients with no new orders

# %% [markdown]
# #### Big clients predicted as small

# %%
df_analyze = df_detail_results.query('Group ==1 and Predicted ==4')
df_analyze.head(5)
df_analyze.describe(include='all')
# Out:
#             CountryUK  TotalPrice  Quantity  UnitPrice_avg  UnitPrice_max  \
# CustomerID
# 12712.000       False     175.530        60          5.182         18.000
# 14397.000        True     165.440       184          2.001          7.950
# 17809.000        True      34.800        24          1.450          1.450
# 18225.000        True      30.000        16          2.500          3.750
# 15555.000        True     198.430       293          0.821          1.690
#
#             Week   Time  Distinct_items_count  Predicted  Group InvoiceNo  \
# CustomerID
# 12712.000     -4 14.500                     9          4      1    536983
# 14397.000     19 12.417                    11          4      1    552575
# 17809.000     -4  9.683                     1          4      1    536380
# 18225.000     -3 15.767                     2          4      1    538125
# 15555.000     -4 14.750                    32          4      1    537204
#
#             InvoiceNo nunique  TotalPrice sum  TotalPrice mean  Quantity sum  \
# CustomerID
# 12712.000                  13        4396.130           33.054          1062
# 14397.000                  19        2612.960           30.034          1890
# 17809.000                  12        5411.910           88.720          2057
# 18225.000                  12        5504.960           20.465          3242
# 15555.000                  16        4791.870            5.415          4397
#
#             ItemID nunique         InvoiceDate    InvoiceDate last  \
# CustomerID
# 12712.000               58 2010-12-03 14:30:00 2011-11-11 08:19:00
# 14397.000               18 2011-05-10 12:25:00 2011-12-07 09:22:00
# 17809.000               48 2010-12-01 09:41:00 2011-11-23 12:59:00
# 18225.000              152 2010-12-09 15:46:00 2011-12-06 13:27:00
# 15555.000              405 2010-12-05 14:45:00 2011-11-27 16:19:00
#
#             InvoiceDate days_since_last_order  \
# CustomerID
# 12712.000                                  28
# 14397.000                                   2
# 17809.000                                  15
# 18225.000                                   2
# 15555.000                                  11
#
#             InvoiceDate days_since_first_order  Month  Weekcustomer  \
# CustomerID
# 12712.000                                  370      0            -4
# 14397.000                                  213      5            19
# 17809.000                                  373      0            -4
# 18225.000                                  364      0            -3
# 15555.000                                  368      0            -4
#
#             Timecustomer         Country  Client  CountryUKcustomer  \
# CustomerID
# 12712.000         14.500         Germany    4012              False
# 14397.000         12.417  United Kingdom    3674               True
# 17809.000          9.683  United Kingdom    4092               True
# 18225.000         15.767  United Kingdom    4099               True
# 15555.000         14.750  United Kingdom    4047               True
#
#             CountrySwitz  days_active firstorder_CustomerID  \
# CustomerID
# 12712.000          False          342             12712.000
# 14397.000          False          211             14397.000
# 17809.000          False          358             17809.000
# 18225.000          False          362             18225.000
# 15555.000          False          357             15555.000
#
#             firstorder_CountryUK  firstorder_TotalPrice  firstorder_Quantity  \
# CustomerID
# 12712.000                  False                175.530                   60
# 14397.000                   True                165.440                  184
# 17809.000                   True                 34.800                   24
# 18225.000                   True                 30.000                   16
# 15555.000                   True                198.430                  293
#
#             firstorder_UnitPrice_avg  firstorder_UnitPrice_max  \
# CustomerID
# 12712.000                      5.182                    18.000
# 14397.000                      2.001                     7.950
# 17809.000                      1.450                     1.450
# 18225.000                      2.500                     3.750
# 15555.000                      0.821                     1.690
#
#             firstorder_Week  firstorder_Time  firstorder_Distinct_items_count  \
# CustomerID
# 12712.000                -4           14.500                                9
# 14397.000                19           12.417                               11
# 17809.000                -4            9.683                                1
# 18225.000                -3           15.767                                2
# 15555.000                -4           14.750                               32
#
#            firstorder_FirstInvoice  Order_value  Order_value_avg  \
# CustomerID
# 12712.000                   536983     4396.130           11.881
# 14397.000                   552575     2612.960           12.267
# 17809.000                   536380     5411.910           14.509
# 18225.000                   538125     5504.960           15.124
# 15555.000                   537204     4791.870           13.021
#
#             Groupcustomer  Quantile_CA
# CustomerID
# 12712.000               1            1
# 14397.000               1            1
# 17809.000               1            1
# 18225.000               1            1
# 15555.000               1            1
#        CountryUK  TotalPrice  Quantity  UnitPrice_avg  UnitPrice_max   Week  \
# count         35      35.000    35.000         35.000         35.000 35.000
# unique         2         nan       nan            nan            nan    nan
# top         True         nan       nan            nan            nan    nan
# freq          30         nan       nan            nan            nan    nan
# first        NaN         nan       nan            nan            nan    nan
# last         NaN         nan       nan            nan            nan    nan
# mean         NaN     161.017    79.543          7.910         18.195  3.000
# std          NaN      68.955    58.644         24.868         39.270 10.652
# min          NaN       5.900     1.000          0.821          1.450 -4.000
# 25%          NaN     126.425    46.000          2.308          4.600 -4.000
# 50%          NaN     165.440    74.000          2.801          8.500 -2.000
# 75%          NaN     216.490   104.500          4.946         12.750  5.500
# max          NaN     254.390   293.000        150.000        195.000 33.000
#
#          Time  Distinct_items_count  Predicted  Group InvoiceNo  \
# count  35.000                35.000     35.000 35.000        35
# unique    nan                   nan        nan    nan        35
# top       nan                   nan        nan    nan    563372
# freq      nan                   nan        nan    nan         1
# first     nan                   nan        nan    nan       NaN
# last      nan                   nan        nan    nan       NaN
# mean   13.069                17.486      4.000  1.000       NaN
# std     2.112                15.382      0.000  0.000       NaN
# min     7.800                 1.000      4.000  1.000       NaN
# 25%    11.925                 4.500      4.000  1.000       NaN
# 50%    13.167                12.000      4.000  1.000       NaN
# 75%    14.575                27.000      4.000  1.000       NaN
# max    16.950                52.000      4.000  1.000       NaN
#
#         InvoiceNo nunique  TotalPrice sum  TotalPrice mean  Quantity sum  \
# count              35.000          35.000           35.000        35.000
# unique                nan             nan              nan           nan
# top                   nan             nan              nan           nan
# freq                  nan             nan              nan           nan
# first                 nan             nan              nan           nan
# last                  nan             nan              nan           nan
# mean               16.486        5784.758           33.166      2804.714
# std                15.732        5606.143           37.797      2127.984
# min                 2.000         877.440            4.507       315.000
# 25%                 9.500        3019.315            8.580      1659.500
# 50%                12.000        4396.130           18.984      2133.000
# 75%                17.500        6543.785           36.609      3595.500
# max                92.000       31833.680          149.454     10923.000
#
#         ItemID nunique          InvoiceDate     InvoiceDate last  \
# count           35.000                   35                   35
# unique             nan                   35                   35
# top                nan  2011-08-19 13:33:00  2011-11-23 14:52:00
# freq               nan                    1                    1
# first              nan  2010-12-01 09:41:00  2011-09-04 13:48:00
# last               nan  2011-08-19 13:33:00  2011-12-09 09:38:00
# mean           189.657                  NaN                  NaN
# std            172.023                  NaN                  NaN
# min              4.000                  NaN                  NaN
# 25%             76.000                  NaN                  NaN
# 50%            145.000                  NaN                  NaN
# 75%            268.000                  NaN                  NaN
# max            825.000                  NaN                  NaN
#
#         InvoiceDate days_since_last_order  InvoiceDate days_since_first_order  \
# count                              35.000                              35.000
# unique                                nan                                 nan
# top                                   nan                                 nan
# freq                                  nan                                 nan
# first                                 nan                                 nan
# last                                  nan                                 nan
# mean                               15.886                             322.914
# std                                22.244                              74.470
# min                                 0.000                             111.000
# 25%                                 3.000                             303.500
# 50%                                10.000                             360.000
# 75%                                15.500                             369.500
# max                                95.000                             373.000
#
#         Month  Weekcustomer  Timecustomer         Country   Client  \
# count  35.000        35.000        35.000              35   35.000
# unique    nan           nan           nan               3      nan
# top       nan           nan           nan  United Kingdom      nan
# freq      nan           nan           nan              30      nan
# first     nan           nan           nan             NaN      nan
# last      nan           nan           nan             NaN      nan
# mean    1.343         3.000        13.069             NaN 3889.629
# std     2.351        10.652         2.112             NaN  401.994
# min     0.000        -4.000         7.800             NaN 2524.000
# 25%     0.000        -4.000        11.925             NaN 3787.500
# 50%     0.000        -2.000        13.167             NaN 4012.000
# 75%     2.000         5.500        14.575             NaN 4151.000
# max     8.000        33.000        16.950             NaN 4305.000
#
#        CountryUKcustomer CountrySwitz  days_active  firstorder_CustomerID  \
# count                 35           35       35.000                 35.000
# unique                 2            1          nan                 35.000
# top                 True        False          nan              17811.000
# freq                  30           35          nan                  1.000
# first                NaN          NaN          nan                    nan
# last                 NaN          NaN          nan                    nan
# mean                 NaN          NaN      307.029                    nan
# std                  NaN          NaN       85.449                    nan
# min                  NaN          NaN       23.000                    nan
# 25%                  NaN          NaN      285.500                    nan
# 50%                  NaN          NaN      349.000                    nan
# 75%                  NaN          NaN      361.500                    nan
# max                  NaN          NaN      372.000                    nan
#
#        firstorder_CountryUK  firstorder_TotalPrice  firstorder_Quantity  \
# count                    35                 35.000               35.000
# unique                    2                    nan                  nan
# top                    True                    nan                  nan
# freq                     30                    nan                  nan
# first                   NaN                    nan                  nan
# last                    NaN                    nan                  nan
# mean                    NaN                161.017               79.543
# std                     NaN                 68.955               58.644
# min                     NaN                  5.900                1.000
# 25%                     NaN                126.425               46.000
# 50%                     NaN                165.440               74.000
# 75%                     NaN                216.490              104.500
# max                     NaN                254.390              293.000
#
#         firstorder_UnitPrice_avg  firstorder_UnitPrice_max  firstorder_Week  \
# count                     35.000                    35.000           35.000
# unique                       nan                       nan              nan
# top                          nan                       nan              nan
# freq                         nan                       nan              nan
# first                        nan                       nan              nan
# last                         nan                       nan              nan
# mean                       7.910                    18.195            3.000
# std                       24.868                    39.270           10.652
# min                        0.821                     1.450           -4.000
# 25%                        2.308                     4.600           -4.000
# 50%                        2.801                     8.500           -2.000
# 75%                        4.946                    12.750            5.500
# max                      150.000                   195.000           33.000
#
#         firstorder_Time  firstorder_Distinct_items_count  \
# count            35.000                           35.000
# unique              nan                              nan
# top                 nan                              nan
# freq                nan                              nan
# first               nan                              nan
# last                nan                              nan
# mean             13.069                           17.486
# std               2.112                           15.382
# min               7.800                            1.000
# 25%              11.925                            4.500
# 50%              13.167                           12.000
# 75%              14.575                           27.000
# max              16.950                           52.000
#
#        firstorder_FirstInvoice  Order_value  Order_value_avg  Groupcustomer  \
# count                       35       35.000           35.000         35.000
# unique                      35          nan              nan            nan
# top                     563372          nan              nan            nan
# freq                         1          nan              nan            nan
# first                      NaN          nan              nan            nan
# last                       NaN          nan              nan            nan
# mean                       NaN     5784.758           17.397          1.000
# std                        NaN     5606.143           16.212          0.000
# min                        NaN      877.440            7.577          1.000
# 25%                        NaN     3019.315            9.599          1.000
# 50%                        NaN     4396.130           12.387          1.000
# 75%                        NaN     6543.785           20.114          1.000
# max                        NaN    31833.680           96.466          1.000
#
#         Quantile_CA
# count        35.000
# unique          nan
# top             nan
# freq            nan
# first           nan
# last            nan
# mean          1.057
# std           0.236
# min           1.000
# 25%           1.000
# 50%           1.000
# 75%           1.000
# max           2.000

# %% [markdown]
# Lots of orders (10 to 100)

# %% [markdown]
# ## Gradient boosting

# %%
model = GradientBoostingClassifier()

# %%
model.n_estimators = hyper_param(model, X, y, 'n_estimators')
# Out:
# Highest score is 0.4563900017019494 Hyperparam  n_estimators : 28
# 28

# %%
model.learning_rate  = hyper_param(model, X, y, 'learning_rate')
# Out:
# Highest score is 0.4563900017019494 Hyperparam  learning_rate : 0.1
# 0.1
# Highest score is 0.45548011337601296 Hyperparam  learning_rate : 0.09444444444444444
# 0.09444444444444444
# Highest score is 0.4542838393359779 Hyperparam  learning_rate : 0.10666666666666667
# 0.10666666666666667

# %%
# %timeit for _ in range(10):silent = model.fit(X_train,y_train)
y_pred = model.predict(X_test)

print(model.__class__.__name__,'score of :',round(model.score(X_test, y_test)*1000)/1000)
print(classification_report(y_test, y_pred))
# Out:
# 1.49 s ± 18.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# GradientBoostingClassifier score of : 0.445
#              precision    recall  f1-score   support
#
#           1       0.52      0.57      0.54       207
#           2       0.31      0.22      0.25       207
#           3       0.38      0.31      0.34       207
#           4       0.49      0.68      0.57       208
#
# avg / total       0.43      0.45      0.43       829

# %% [markdown]
# ## Retry with Scaler (no changes)

# %%
std_s = StandardScaler()
X_transformed = std_s.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_transformed, y, test_size = 0.2, random_state=42, stratify=y )

# %%
knn = KNeighborsClassifier()
knn.n_neighbors = int(round(hyper_param(knn, X, y)))

# %%
silent = knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)

print('Score of :',knn.score(X_test, y_test))
print(classification_report(y_test, y_pred))
