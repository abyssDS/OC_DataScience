# %% [markdown]
# # Building content-based filtering
#
# ### Creating several categories

# %%
import pandas as pd
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype
import matplotlib.pyplot  as plt
import numpy as np
import feather

from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.spatial.distance import pdist,squareform 
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

from scipy.sparse import csr_matrix




from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

pd.options.display.max_rows = 500
pd.options.display.max_columns = 200 
pd.set_option('display.float_format', lambda x: '%.3f' % x) #display numbers as decimals instead of scientific value

data_filepath = 'movie_metadata_cleaned_v1.feather'

# %%
df = feather.read_dataframe(data_filepath)
movies_count = df.shape[0]
print (   movies_count ,'movies imported')

df_movies = df.copy()
df_movies['movie_id'] = df_movies.index
df_movies = df_movies.set_index(df['movie_title'])
movies_list = list(df['movie_title'])
# Out:
# 4916 movies imported

# %%
df.describe(include='all')
# Out:
#        movie_title  title_year  imdb_score country language genres  \
# count         4916    4916.000    4916.000    4916     4916   4916
# unique        4916         nan         nan      66       48    914
# top       Faithful         nan         nan     USA  English  Drama
# freq             1         nan         nan    3710     4582    232
# mean           NaN    2002.453       6.437     NaN      NaN    NaN
# std            NaN      12.315       1.128     NaN      NaN    NaN
# min            NaN    1916.000       1.600     NaN      NaN    NaN
# 25%            NaN    1999.000       5.800     NaN      NaN    NaN
# 50%            NaN    2005.000       6.600     NaN      NaN    NaN
# 75%            NaN    2010.000       7.200     NaN      NaN    NaN
# max            NaN    2016.000       9.500     NaN      NaN    NaN
#
#        plot_keywords director_name  director_facebook_likes    actor_1_name  \
# count           4916          4916                 4916.000            4916
# unique          4757          2398                      nan            2096
# top                                                     nan  Robert De Niro
# freq             152           102                      nan              48
# mean             NaN           NaN                  676.677             NaN
# std              NaN           NaN                 2805.134             NaN
# min              NaN           NaN                    0.000             NaN
# 25%              NaN           NaN                    6.000             NaN
# 50%              NaN           NaN                   44.000             NaN
# 75%              NaN           NaN                  188.000             NaN
# max              NaN           NaN                23000.000             NaN
#
#           actor_2_name actor_3_name  actor_1_facebook_likes  \
# count             4916         4916                4916.000
# unique            3031         3520                     nan
# top     Morgan Freeman                                  nan
# freq                18           23                     nan
# mean               NaN          NaN                6485.200
# std                NaN          NaN               15098.229
# min                NaN          NaN                   0.000
# 25%                NaN          NaN                 606.000
# 50%                NaN          NaN                 981.500
# 75%                NaN          NaN               11000.000
# max                NaN          NaN              640000.000
#
#         actor_2_facebook_likes  actor_3_facebook_likes  \
# count                 4916.000                4916.000
# unique                     nan                     nan
# top                        nan                     nan
# freq                       nan                     nan
# mean                  1617.624                 628.313
# std                   4006.861                1622.642
# min                      0.000                   0.000
# 25%                    275.000                 129.000
# 50%                    592.000                 362.000
# 75%                    912.000                 631.000
# max                 137000.000               23000.000
#
#         cast_total_facebook_likes  movie_facebook_likes  num_user_for_reviews  \
# count                    4916.000              4916.000              4916.000
# unique                        nan                   nan                   nan
# top                           nan                   nan                   nan
# freq                          nan                   nan                   nan
# mean                     9579.733              7348.296               266.525
# std                     18164.359             19206.016               372.547
# min                         0.000                 0.000                 0.000
# 25%                      1394.750                 0.000                62.000
# 50%                      3049.000               159.000               152.000
# 75%                     13616.750              2000.000               319.250
# max                    656730.000            349000.000              5060.000
#
#         num_critic_for_reviews  num_voted_users         gross        budget  \
# count                 4916.000         4916.000      4916.000      4916.000
# unique                     nan              nan           nan           nan
# top                        nan              nan           nan           nan
# freq                       nan              nan           nan           nan
# mean                   136.617        82645.242  47779121.547  33576517.195
# std                    120.418       138322.057  61184608.962  38653472.075
# min                      0.000            5.000       162.000       218.000
# 25%                     47.000         8361.750   8052632.500   7000000.000
# 50%                    106.500        33132.500  36948242.000  23000000.000
# 75%                    191.000        93772.750  50875351.250  40000000.000
# max                    813.000      1689764.000 760505847.000 300000000.000
#
#        content_rating  color  duration  aspect_ratio
# count            4916   4916  4916.000      4916.000
# unique             18      2       nan           nan
# top                 R  Color       nan           nan
# freq             2367   4712       nan           nan
# mean              NaN    NaN   107.092         2.096
# std               NaN    NaN    25.247         0.289
# min               NaN    NaN     7.000         1.180
# 25%               NaN    NaN    93.000         1.850
# 50%               NaN    NaN   103.000         2.220
# 75%               NaN    NaN   118.000         2.350
# max               NaN    NaN   511.000         4.000

# %%
def replace_spaces(feature):
    feature = feature.str.replace(' ', '_')
    feature = feature.str.replace('.', '')
    feature = feature.str.replace('|', ' ')
    return feature

df_2 = df.copy()
df_2 = df_2.set_index(df_2['movie_title'])
object_only = df_2.select_dtypes(include=['object'])
df_2[object_only.columns] = object_only.apply(replace_spaces, axis=1)

# %%
df_2.head()
# Out:
#                          movie_title  title_year  imdb_score country language  \
# movie_title
# Gods and Monsters  Gods_and_Monsters    1998.000       7.500     USA  English
# Runner Runner          Runner_Runner    2013.000       5.600     USA  English
# Antitrust                  Antitrust    2001.000       6.100     USA  English
# Lady in White          Lady_in_White    1988.000       6.700     USA  English
# Dead Man Down          Dead_Man_Down    2013.000       6.500     USA  English
#
#                                             genres  \
# movie_title
# Gods and Monsters                  Biography Drama
# Runner Runner                       Crime Thriller
# Antitrust              Action Crime Drama Thriller
# Lady in White      Fantasy Horror Mystery Thriller
# Dead Man Down          Action Crime Drama Thriller
#
#                                                        plot_keywords  \
# movie_title
# Gods and Monsters  friendship gardener gay_interest homosexual me...
# Runner Runner      costa_rica fbi_agent gambling money online_gam...
# Antitrust                    boss communications computer genius job
# Lady in White                      1960s boy ghost murder small_town
# Dead Man Down      crime_lord dead_body dead_body_in_a_freezer ne...
#
#                        director_name  director_facebook_likes  \
# movie_title
# Gods and Monsters        Bill_Condon                  386.000
# Runner Runner            Brad_Furman                   65.000
# Antitrust               Peter_Howitt                   29.000
# Lady in White         Frank_LaLoggia                    7.000
# Dead Man Down      Niels_Arden_Oplev                   76.000
#
#                         actor_1_name       actor_2_name       actor_3_name  \
# movie_title
# Gods and Monsters     Brendan_Fraser      Lynn_Redgrave   Kevin_J_O'Connor
# Runner Runner      Justin_Timberlake         John_Heard    David_Costabile
# Antitrust               Tyler_Labine  Richard_Roundtree        Ned_Bellamy
# Lady in White             Alex_Rocco         Lukas_Haas  Katherine_Helmond
# Dead Man Down         Dominic_Cooper   Isabelle_Huppert       James_Biberi
#
#                    actor_1_facebook_likes  actor_2_facebook_likes  \
# movie_title
# Gods and Monsters                3000.000                 258.000
# Runner Runner                    3000.000                 697.000
# Antitrust                         779.000                 240.000
# Lady in White                     968.000                 733.000
# Dead Man Down                    3000.000                 678.000
#
#                    actor_3_facebook_likes  cast_total_facebook_likes  \
# movie_title
# Gods and Monsters                 248.000                       4238
# Runner Runner                     681.000                       5706
# Antitrust                          91.000                       1297
# Lady in White                     339.000                       2545
# Dead Man Down                     174.000                       4253
#
#                    movie_facebook_likes  num_user_for_reviews  \
# movie_title
# Gods and Monsters                     0               229.000
# Runner Runner                         0                95.000
# Antitrust                             0               221.000
# Lady in White                         0                69.000
# Dead Man Down                         0               127.000
#
#                    num_critic_for_reviews  num_voted_users        gross  \
# movie_title
# Gods and Monsters                 127.000            24977  6390032.000
# Runner Runner                     184.000            52069 19316646.000
# Antitrust                         123.000            25558 10965209.000
# Lady in White                     130.000             4695  1705139.000
# Dead Man Down                     217.000            54147 10880926.000
#
#                         budget content_rating             color  duration  \
# movie_title
# Gods and Monsters  3500000.000              R  _Black_and_White   105.000
# Runner Runner     30000000.000              R             Color    88.000
# Antitrust         30000000.000          PG-13             Color   109.000
# Lady in White      4700000.000              R             Color   118.000
# Dead Man Down     30000000.000              R             Color   118.000
#
#                    aspect_ratio
# movie_title
# Gods and Monsters         2.350
# Runner Runner             2.350
# Antitrust                 2.350
# Lady in White             1.850
# Dead Man Down             2.350

# %%
def calculate_dist(df_, min_words_freq = 1):
    df = df_.copy()
    ######### Words columns ############
    df_words_cols = df.select_dtypes(include=['object']).copy()
    df.loc[:,'words']=''
    for column in df_words_cols.columns:
        df.loc[:,'words'] +=df.loc[:,column]+' ' #.T.head(1).T+' '
        if column in ['actor_1_name', 'director_name', 'genres']:
            df.loc[:,'words'] +=df.loc[:,column]+' '
        
    if df_words_cols.shape[1]>0 :
        vectorizer  = TfidfVectorizer(min_df = min_words_freq+1)
        words_freq_csrm = vectorizer.fit_transform(list(df['words']))
        #df_freq = pd.DataFrame(words_freq_csrm.toarray(),index=movies_list, columns=vectorizer.get_feature_names())
        #words_frequencies = pd.Series(df_freq.astype(bool).sum(axis=0))
        #keep_words_i = list(np.where(words_frequencies>min_words_freq))[0]
        #words_freq_csrm= words_freq_csrm[:,keep_words_i]
        words_features = words_freq_csrm.toarray()

    ###### Numeric columns #########
    df_numeric_cols = df.select_dtypes(include=['float64']).copy()
    
    if df_numeric_cols.shape[1]>0 :
        scaler = MinMaxScaler((0.5,2))
        numeric_features = scaler.fit_transform(df_numeric_cols)
        if df_words_cols.shape[1]>0 :
            all_features = np.hstack((words_features, numeric_features))
            n_components = int(round(words_features.shape[1]/3, 0))+numeric_features.shape[1]
        else:
            all_features = numeric_features
            n_components = numeric_features.shape[1]
    else:
        all_features = words_features
        n_components = int(round(words_features.shape[1]/3, 0))
        
    
    print('Reducing to',n_components,'principal components out of',all_features.shape[1],'features')
    ## => indiquer la variance
    pca = PCA(n_components=n_components) # We keep 1/3
    pca_features = pca.fit_transform(all_features)
    ####### Dist matrix ############
    pdist_matrix = pdist(pca_features)
    pdist_square = squareform(pdist_matrix)
    df_pdist = pd.DataFrame(pdist_square, index = movies_list, columns =movies_list )
    
    return df_pdist

# %%
def display_closest(movie_name, columns_names, df_pdist, n=5, min_words_freq = 1, recalc=False):
    if (recalc or df_pdist.shape[0]==0):
        df_pdist = calculate_dist(df_2[columns_names], min_words_freq=min_words_freq)
    df_display = df_2[columns_names].copy()
    df_display['distance'] = df_pdist[movie_name].copy()
    display(df_display.loc[df_display['distance'].sort_values().iloc[1:n+1].index, :])
    return df_pdist
    
df_pdist_overall = pd.DataFrame()
df_pdist_genres = pd.DataFrame()
df_pdist_cast = pd.DataFrame()
df_pdist_success= pd.DataFrame()
df_pdist_pict= pd.DataFrame()
def display_categories(movie_name, n=5):
    global df_pdist_overall
    global df_pdist_genres
    global df_pdist_cast
    global df_pdist_success
    global df_pdist_pict

    print('Similar overall')
    df_pdist_overall = display_closest(movie_name, n=n, min_words_freq=2
                                      , df_pdist = df_pdist_overall
                                      , columns_names = ['genres', 'director_name', 'actor_1_name','title_year', 'country', 'language', 'imdb_score', 'content_rating', 'color'])
    
    print('Similar genre')
    df_pdist_genres = display_closest(movie_name, n=n, min_words_freq=5
                                      , df_pdist = df_pdist_genres
                                      , columns_names = ['genres', 'plot_keywords'])
    print('Similar picture')
    df_pdist_pict = display_closest(movie_name, n=n
                                      , df_pdist = df_pdist_pict
                                      , columns_names = ['director_name', 'color', 'title_year', 'aspect_ratio', 'duration', 'country', 'language'])
    
    print('Similar cast')
    df_pdist_cast = display_closest(movie_name, n=n
                                      , df_pdist = df_pdist_cast
                                      , columns_names = ['actor_1_name', 'actor_2_name', 'actor_3_name', 'title_year'])
    print('Similar success')
    df_pdist_success = display_closest(movie_name, n=n
                                      , df_pdist = df_pdist_success
                                      , columns_names = ['imdb_score', 'imdb_score', 'gross', 'num_user_for_reviews', 'movie_facebook_likes',  'num_critic_for_reviews', 'num_voted_users'])

# %%
df.columns
# Out:
# Index(['movie_title', 'title_year', 'imdb_score', 'country', 'language',
#        'genres', 'plot_keywords', 'director_name', 'director_facebook_likes',
#        'actor_1_name', 'actor_2_name', 'actor_3_name',
#        'actor_1_facebook_likes', 'actor_2_facebook_likes',
#        'actor_3_facebook_likes', 'cast_total_facebook_likes',
#        'movie_facebook_likes', 'num_user_for_reviews',
#        'num_critic_for_reviews', 'num_voted_users', 'gross', 'budget',
#        'content_rating', 'color', 'duration', 'aspect_ratio'],
#       dtype='object')

# %%
display_categories('Fight Club')
# Out:
# Similar overall
# Reducing to 354 principal components out of 1058 features
#                                                            genres  \
# movie_title
# The Curious Case of Benjamin Button         Drama Fantasy Romance
# The Social Network                                Biography Drama
# The Game                                   Drama Mystery Thriller
# Gone Girl                            Crime Drama Mystery Thriller
# The Tree of Life                                    Drama Fantasy
#
#                                        director_name        actor_1_name  \
# movie_title
# The Curious Case of Benjamin Button    David_Fincher           Brad_Pitt
# The Social Network                     David_Fincher     Andrew_Garfield
# The Game                               David_Fincher  Deborah_Kara_Unger
# Gone Girl                              David_Fincher       Patrick_Fugit
# The Tree of Life                     Terrence_Malick           Brad_Pitt
#
#                                      title_year country language  imdb_score  \
# movie_title
# The Curious Case of Benjamin Button    2008.000     USA  English       7.800
# The Social Network                     2010.000     USA  English       7.700
# The Game                               1997.000     USA  English       7.800
# Gone Girl                              2014.000     USA  English       8.100
# The Tree of Life                       2011.000     USA  English       6.700
#
#                                     content_rating  color  distance
# movie_title
# The Curious Case of Benjamin Button          PG-13  Color     0.466
# The Social Network                           PG-13  Color     0.826
# The Game                                         R  Color     0.832
# Gone Girl                                        R  Color     0.833
# The Tree of Life                             PG-13  Color     0.899
# Similar genre
# Reducing to 271 principal components out of 813 features
#                     genres                                      plot_keywords  \
# movie_title
# The Emperor's Club   Drama    classroom fund_raising headmaster reunion roman
# Lost in Translation  Drama  fish_out_of_water japanese loneliness older_ma...
# Requiem for a Dream  Drama  addiction diet_pill drug_addiction fast_motion...
# Frost/Nixon          Drama  american_president political_drama scandal us_...
# The Master           Drama  drifter past_life_regression psychological_tes...
#
#                      distance
# movie_title
# The Emperor's Club      0.452
# Lost in Translation     0.467
# Requiem for a Dream     0.474
# Frost/Nixon             0.479
# The Master              0.497
# Similar picture
# Reducing to 322 principal components out of 960 features
#              director_name  color  title_year  aspect_ratio  duration country  \
# movie_title
# The Game     David_Fincher  Color    1997.000         2.350   129.000     USA
# Se7en        David_Fincher  Color    1995.000         2.350   127.000     USA
# Alien 3      David_Fincher  Color    1992.000         2.350   145.000     USA
# Panic Room   David_Fincher  Color    2002.000         2.350   112.000     USA
# Zodiac       David_Fincher  Color    2007.000         2.350   162.000     USA
#
#             language  distance
# movie_title
# The Game     English     0.071
# Se7en        English     0.092
# Alien 3      English     0.106
# Panic Room   English     0.122
# Zodiac       English     0.124
# Similar cast
# Reducing to 790 principal components out of 2367 features
#                                  actor_1_name      actor_2_name  \
# movie_title
# Sinbad: Legend of the Seven Seas    Brad_Pitt  Adriano_Giannini
# Babel                               Brad_Pitt    Harriet_Walter
# Johnny Suede                        Brad_Pitt       Tina_Louise
# The Tree of Life                    Brad_Pitt      Tye_Sheridan
# Ocean's Twelve                      Brad_Pitt     Julia_Roberts
#
#                                     actor_3_name  title_year  distance
# movie_title
# Sinbad: Legend of the Seven Seas    Timothy_West    2003.000     0.537
# Babel                             Dermot_Crowley    2006.000     0.544
# Johnny Suede                           Nick_Cave    1991.000     0.546
# The Tree of Life                      Fiona_Shaw    2011.000     0.570
# Ocean's Twelve                        Mini_Anden    2004.000     0.657
# Similar success
# Reducing to 5 principal components out of 5 features
#                    imdb_score  imdb_score         gross  num_user_for_reviews  \
# movie_title
# Memento                 8.500       8.500  25530884.000              2067.000
# Pulp Fiction            8.900       8.900 107930000.000              2195.000
# Donnie Darko            8.100       8.100    727883.000              2110.000
# Kill Bill: Vol. 1       8.100       8.100  70098138.000              2105.000
# The Matrix              8.700       8.700 171383253.000              3646.000
#
#                    movie_facebook_likes  num_critic_for_reviews  \
# movie_title
# Memento                           40000                 274.000
# Pulp Fiction                      45000                 215.000
# Donnie Darko                      33000                 283.000
# Kill Bill: Vol. 1                 13000                 354.000
# The Matrix                        25000                 313.000
#
#                    num_voted_users  distance
# movie_title
# Memento                     845580     0.290
# Pulp Fiction               1324680     0.327
# Donnie Darko                580999     0.330
# Kill Bill: Vol. 1           735784     0.332
# The Matrix                 1217752     0.334

# %%
display_categories('Django Unchained')
# Out:
# Similar overall
#                                                  genres         director_name  \
# movie_title
# The Hateful Eight  Crime Drama Mystery Thriller Western     Quentin_Tarantino
# The Revenant           Adventure Drama Thriller Western  Alejandro_G_Iñárritu
# Kill Bill: Vol. 1                                Action     Quentin_Tarantino
# Reservoir Dogs                     Crime Drama Thriller     Quentin_Tarantino
# The Great Gatsby                          Drama Romance          Baz_Luhrmann
#
#                         actor_1_name  title_year    country language  \
# movie_title
# The Hateful Eight        Craig_Stark    2015.000        USA  English
# The Revenant       Leonardo_DiCaprio    2015.000        USA  English
# Kill Bill: Vol. 1    David_Carradine    2003.000        USA  English
# Reservoir Dogs     Quentin_Tarantino    1992.000        USA  English
# The Great Gatsby   Leonardo_DiCaprio    2013.000  Australia  English
#
#                    imdb_score content_rating             color  distance
# movie_title
# The Hateful Eight       7.900              R             Color     0.765
# The Revenant            8.100              R             Color     0.794
# Kill Bill: Vol. 1       8.100              R  _Black_and_White     0.832
# Reservoir Dogs          8.400              R             Color     0.881
# The Great Gatsby        7.300          PG-13             Color     0.911
# Similar genre
#                                                  genres  \
# movie_title
# Forsaken                                  Drama Western
# Unforgiven                                Drama Western
# The Work and the Glory II: American Zion  Drama Western
# Doc Holliday's Revenge                          Western
# The Ballad of Gregorio Cortez                   Western
#
#                                                                               plot_keywords  \
# movie_title
# Forsaken
# Unforgiven                                englishman leaving_flowers_on_a_grave one_last...
# The Work and the Glory II: American Zion  estrangement missouri mormon mormon_church mor...
# Doc Holliday's Revenge                     1880s cowboy low_budget_film shoot_out wild_west
# The Ballad of Gregorio Cortez
#
#                                           distance
# movie_title
# Forsaken                                     0.198
# Unforgiven                                   0.198
# The Work and the Glory II: American Zion     0.250
# Doc Holliday's Revenge                       0.335
# The Ballad of Gregorio Cortez                0.350
# Similar picture
#                           director_name             color  title_year  \
# movie_title
# Inglourious Basterds  Quentin_Tarantino             Color    2009.000
# The Hateful Eight     Quentin_Tarantino             Color    2015.000
# Pulp Fiction          Quentin_Tarantino             Color    1994.000
# Kill Bill: Vol. 2     Quentin_Tarantino  _Black_and_White    2004.000
# Jackie Brown          Quentin_Tarantino             Color    1997.000
#
#                       aspect_ratio  duration country language  distance
# movie_title
# Inglourious Basterds         2.350   153.000     USA  English     0.057
# The Hateful Eight            2.760   187.000     USA  English     0.231
# Pulp Fiction                 2.350   178.000     USA  English     0.271
# Kill Bill: Vol. 2            2.350   137.000     USA  English     0.319
# Jackie Brown                 1.850   154.000     USA  English     0.349
# Similar cast
#                              actor_1_name       actor_2_name  \
# movie_title
# Shutter Island          Leonardo_DiCaprio      Joseph_Sikora
# The Great Gatsby        Leonardo_DiCaprio  Elizabeth_Debicki
# Body of Lies            Leonardo_DiCaprio     Simon_McBurney
# The Beach               Leonardo_DiCaprio   Virginie_Ledoyen
# The Quick and the Dead  Leonardo_DiCaprio         Pat_Hingle
#
#                                   actor_3_name  title_year  distance
# movie_title
# Shutter Island                  Nellie_Sciutto    2010.000     0.467
# The Great Gatsby                  Steve_Bisley    2013.000     0.471
# Body of Lies                    Michael_Gaston    2008.000     0.474
# The Beach               Peter_Youngblood_Hills    2000.000     0.503
# The Quick and the Dead         Roberts_Blossom    1995.000     0.544
# Similar success
#                          imdb_score  imdb_score         gross  \
# movie_title
# Mad Max: Fury Road            8.100       8.100 153629485.000
# Black Swan                    8.000       8.000 106952327.000
# The Wolf of Wall Street       8.200       8.200 116866727.000
# Argo                          7.700       7.700 136019448.000
# Skyfall                       7.800       7.800 304360277.000
#
#                          num_user_for_reviews  movie_facebook_likes  \
# movie_title
# Mad Max: Fury Road                   1588.000                191000
# Black Swan                           1140.000                106000
# The Wolf of Wall Street              1138.000                138000
# Argo                                  695.000                 89000
# Skyfall                              1498.000                 80000
#
#                          num_critic_for_reviews  num_voted_users  distance
# movie_title
# Mad Max: Fury Road                      739.000           552503     0.167
# Black Swan                              669.000           551363     0.249
# The Wolf of Wall Street                 606.000           780588     0.318
# Argo                                    656.000           452465     0.333
# Skyfall                                 750.000           522030     0.350

# %%
df_2.sort_values('movie_facebook_likes').tail(100).index
# Out:
# Index(['Independence Day: Resurgence', 'The Wolverine',
#        'The Secret Life of Walter Mitty', 'Evil Dead', 'Minions', 'Creed',
#        'Lincoln', 'Noah', '300: Rise of an Empire', 'Oblivion',
#        'Moonrise Kingdom', 'Room', 'Captain America: Civil War',
#        'Pride and Prejudice and Zombies', 'Ted', 'The Social Network',
#        'The Help', 'Looper', 'Into the Wild', 'Straight Outta Compton',
#        'Edge of Tomorrow', 'Warrior', 'Midnight in Paris', 'Idiocracy',
#        'Spotlight', 'Suicide Squad', 'Skyfall', 'Warm Bodies', 'Drive', 'Fury',
#        'Dark Shadows', 'The Hunger Games: Catching Fire',
#        'X-Men: Days of Future Past', 'Terminator Genisys', 'Pacific Rim',
#        '12 Years a Slave', 'Lucy', 'The Hobbit: The Desolation of Smaug',
#        'Rush', 'Spectre', 'Prisoners', 'Warcraft', 'Maleficent', 'Argo',
#        'Into the Woods', 'The Theory of Everything', 'Boyhood',
#        'Star Trek Into Darkness', 'Sharknado', 'The Fault in Our Stars',
#        'Furious 7', 'Iron Man 3', 'Guardians of the Galaxy', 'This Is the End',
#        'Prometheus', 'Abraham Lincoln: Vampire Hunter', 'The Big Short',
#        'Fifty Shades of Grey', 'About Time', 'Now You See Me', 'Black Swan',
#        'The Expendables 2', 'The Shawshank Redemption', 'Ex Machina',
#        'American Sniper', 'The Hateful Eight',
#        'Birdman or (The Unexpected Virtue of Ignorance)', 'The Great Gatsby',
#        'Hachi: A Dog's Tale', 'Deadpool', 'Silver Linings Playbook',
#        'Man of Steel', 'Avengers: Age of Ultron', 'Inside Out', 'Life of Pi',
#        'The Avengers', 'Ender's Game', 'Cloud Atlas', 'Whiplash',
#        'World War Z', 'The Perks of Being a Wallflower', 'The Conjuring',
#        'The Wolf of Wall Street', 'The Hunger Games', 'Les Misérables',
#        'Gone Girl', 'Gravity', 'Her', 'The Grand Budapest Hotel',
#        'Jurassic World', 'The Martian', 'The Dark Knight Rises',
#        'The Imitation Game', 'The Hobbit: An Unexpected Journey', 'Inception',
#        'The Revenant', 'Mad Max: Fury Road',
#        'Batman v Superman: Dawn of Justice', 'Django Unchained',
#        'Interstellar'],
#       dtype='object', name='movie_title')

# %% [markdown]
# ##### Prepare export of all our reco

# %%
def closest_n(df_pdist, i, n=5, np_already_shown=np.full((movies_count,1), -1)):
    movie_distances = df_pdist[df.loc[i, 'movie_title']]
    np_closest = movie_distances.sort_values()[:n*5]
    # remove movie indexes which have already been suggested(from np_already_shown)
    np_closest = df_movies.loc[np_closest.index, 'movie_id']
    np_closest = np_closest[np.isin(np_closest, np_already_shown[i], invert=True)][:n]
    return (np_closest)

#initiate the list of movies to ignore with each movie's own name
np_already_shown =np.reshape(range(movies_count), (movies_count, 1))
closest_overall = np.array([closest_n(df_pdist_overall,i
                                     ,np_already_shown = np_already_shown
                                     ) for i in range(movies_count)])

np_already_shown = np.hstack((np_already_shown, closest_overall))
closest_genres = np.array([closest_n(df_pdist_genres,i
                                     ,np_already_shown = np_already_shown
                                     ) for i in range(movies_count)])

np_already_shown = np.hstack((np_already_shown, closest_genres))
closest_cast = np.array([closest_n(df_pdist_cast,i
                                     ,np_already_shown = np_already_shown
                                     ) for i in range(movies_count)])


np_already_shown = np.hstack((np_already_shown, closest_cast))
closest_pict = np.array([closest_n(df_pdist_pict,i
                                     ,np_already_shown = np_already_shown
                                     ) for i in range(movies_count)])

np_already_shown = np.hstack((np_already_shown, closest_pict))
closest_success = np.array([closest_n(df_pdist_success,i
                                     ,np_already_shown = np_already_shown
                                     ) for i in range(movies_count)])

# %% [markdown]
# ### Trying to evaluate results

# %% [markdown]
# Calculate percent of chances for movies with same director to end up in our recommendation of either overall or similar pict.

# %%
add_percents_reco_same_director =0
nb_movies = 0
for i in range(movies_count):
    nb_common_directors = df[(df['director_name'] == df.loc[i, 'director_name'] ) & (df['director_name'] != '') ].count().max()-1
    if nb_common_directors > 0:
        nb_movies+=1
        df_close_movies =  df.loc[closest_overall[i]].append(df.loc[closest_pict[i]])
        nb_directors_in_reco = df_close_movies[df_close_movies['director_name'] == df.loc[i, 'director_name']].count().max()
        percent_reco_same_director= (nb_directors_in_reco/nb_common_directors)*100
        add_percents_reco_same_director += percent_reco_same_director
        
        
chance_reco_same_director =  add_percents_reco_same_director/nb_movies #77.6

print(chance_reco_same_director, 'chances to find same director movies')
# Out:
# 77.67371232899231

# %% [markdown]
# Same test with actor_1

# %%
add_percents_reco_same_actor =0
nb_movies = 0
for i in range(movies_count):
    nb_common_actors = df[(df['actor_1_name'] == df.loc[i, 'actor_1_name'] ) & (df['actor_1_name'] != '') ].count().max()-1
    if nb_common_actors > 0:
        nb_movies+=1
        df_close_movies =  df.loc[closest_overall[i]].append(df.loc[closest_cast[i]])
        nb_actors_in_reco = df_close_movies[df_close_movies['actor_1_name'] == df.loc[i, 'actor_1_name']].count().max()
        percent_reco_same_actor= (nb_actors_in_reco/nb_common_actors)*100
        add_percents_reco_same_actor += percent_reco_same_actor
        
        
chance_reco_same_actor =  add_percents_reco_same_actor/nb_movies #

print(chance_reco_same_actor, 'chances to find same actor1 movies')
# Out:
# 81.31536153012554 chances to find same actor1 movies

# %%
print('Average variance of imdb_score in our dataset', df['imdb_score'].var())
# Out:
# Average variance of imdb_score in our dataset 1.271970623049137

# %%
sum_variances =0

for i in range(movies_count):
    closect_ids = np.insert(closest_success[i],0,i)
    df_close_movies = df.loc[closect_ids ]
    sum_variances+=df_close_movies['imdb_score'].var()
    
avg_variance = sum_variances/movies_count
print('Average variance of imdb_score in similar success categ:', avg_variance)
# Out:
# Average variance of imdb_score in similar success categ: 0.010970979115812298

# %%
sum_variances =0

for i in range(movies_count):
    closect_ids = np.insert(closest_overall[i],0,i)
    df_close_movies = df.loc[closect_ids ]
    sum_variances+=df_close_movies['imdb_score'].var()
    
avg_variance = sum_variances/movies_count
print('Average variance of imdb_score in similar overall:', avg_variance)
# Out:
# Average variance of imdb_score in similar overall: 0.44534384323297943

# %% [markdown]
# #### Export

# %%
methods_list = ('closest_overall', 'closest_genres', 'closest_cast', 'closest_pict', 'closest_success')
methods={}
for i in methods_list:
    methods[i] = locals()[i]

# %%
for method in methods:
    np.save(method, methods[method])

# %%
for i in methods_list:
    locals()[i] = np.load(i+'.npy')

df_movies[['movie_id', 'movie_title']].to_csv('movies_titles_list.csv')

# %% [markdown]
# ### Online API URL : http://xmontamat.pythonanywhere.com/
