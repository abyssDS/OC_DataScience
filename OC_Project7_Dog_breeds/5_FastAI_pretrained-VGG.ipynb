# %%
from IPython.core.interactiveshell import InteractiveShell
from datetime import datetime

#basic externals
import pandas as pd
import numpy as np
import os
import matplotlib as plt 

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2


InteractiveShell.ast_node_interactivity = "all"

pd.options.display.max_rows = 20
pd.options.display.max_columns = 50 
pd.set_option(
    "display.float_format", lambda x: "%.3f" % x
    )  # display numbers as decimals instead of scientific value

plt.rcParams["font.size"] = (18)

# %%
import torch
torch.cuda.get_device_name(0)
# Out:
# 'GeForce GTX 970'

# %%
from fastai.vision import *
from fastai.metrics import error_rate

bs = 16

# %%
path_img = os.path.normpath('fastai')
#not working

# %%
fnames = get_image_files(path_img)
fnames[:5]
# Out:
# []

# %%
data = ImageDataBunch.from_folder(path_img, ds_tfms=get_transforms(),valid_pct=0.2, size=224, bs=bs).normalize(imagenet_stats)

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['n02085620-Chihuahua', 'n02085782-Japanese_spaniel', 'n02085936-Maltese_dog', 'n02086079-Pekinese', 'n02086240-Shih-Tzu', 'n02086646-Blenheim_spaniel', 'n02086910-papillon', 'n02087046-toy_terrier', 'n02087394-Rhodesian_ridgeback', 'n02088094-Afghan_hound', 'n02088238-basset', 'n02088364-beagle', 'n02088466-bloodhound', 'n02088632-bluetick', 'n02089078-black-and-tan_coonhound', 'n02089867-Walker_hound', 'n02089973-English_foxhound', 'n02090379-redbone', 'n02090622-borzoi', 'n02090721-Irish_wolfhound', 'n02091032-Italian_greyhound', 'n02091134-whippet', 'n02091244-Ibizan_hound', 'n02091467-Norwegian_elkhound', 'n02091635-otterhound', 'n02091831-Saluki', 'n02092002-Scottish_deerhound', 'n02092339-Weimaraner', 'n02093256-Staffordshire_bullterrier', 'n02093428-American_Staffordshire_terrier', 'n02093647-Bedlington_terrier', 'n02093754-Border_terrier', 'n02093859-Kerry_blue_terrier', 'n02093991-Irish_terrier', 'n02094114-Norfolk_terrier', 'n02094258-Norwich_terrier', 'n02094433-Yorkshire_terrier', 'n02095314-wire-haired_fox_terrier', 'n02095570-Lakeland_terrier', 'n02095889-Sealyham_terrier', 'n02096051-Airedale', 'n02096177-cairn', 'n02096294-Australian_terrier', 'n02096437-Dandie_Dinmont', 'n02096585-Boston_bull', 'n02097047-miniature_schnauzer', 'n02097130-giant_schnauzer', 'n02097209-standard_schnauzer', 'n02097298-Scotch_terrier', 'n02097474-Tibetan_terrier', 'n02097658-silky_terrier', 'n02098105-soft-coated_wheaten_terrier', 'n02098286-West_Highland_white_terrier', 'n02098413-Lhasa', 'n02099267-flat-coated_retriever', 'n02099429-curly-coated_retriever', 'n02099601-golden_retriever', 'n02099712-Labrador_retriever', 'n02099849-Chesapeake_Bay_retriever', 'n02100236-German_short-haired_pointer', 'n02100583-vizsla', 'n02100735-English_setter', 'n02100877-Irish_setter', 'n02101006-Gordon_setter', 'n02101388-Brittany_spaniel', 'n02101556-clumber', 'n02102040-English_springer', 'n02102177-Welsh_springer_spaniel', 'n02102318-cocker_spaniel', 'n02102480-Sussex_spaniel', 'n02102973-Irish_water_spaniel', 'n02104029-kuvasz', 'n02104365-schipperke', 'n02105056-groenendael', 'n02105162-malinois', 'n02105251-briard', 'n02105412-kelpie', 'n02105505-komondor', 'n02105641-Old_English_sheepdog', 'n02105855-Shetland_sheepdog', 'n02106030-collie', 'n02106166-Border_collie', 'n02106382-Bouvier_des_Flandres', 'n02106550-Rottweiler', 'n02106662-German_shepherd', 'n02107142-Doberman', 'n02107312-miniature_pinscher', 'n02107574-Greater_Swiss_Mountain_dog', 'n02107683-Bernese_mountain_dog', 'n02107908-Appenzeller', 'n02108000-EntleBucher', 'n02108089-boxer', 'n02108422-bull_mastiff', 'n02108551-Tibetan_mastiff', 'n02108915-French_bulldog', 'n02109047-Great_Dane', 'n02109525-Saint_Bernard', 'n02109961-Eskimo_dog', 'n02110063-malamute', 'n02110185-Siberian_husky', 'n02110627-affenpinscher', 'n02110806-basenji', 'n02110958-pug', 'n02111129-Leonberg', 'n02111277-Newfoundland', 'n02111500-Great_Pyrenees', 'n02111889-Samoyed', 'n02112018-Pomeranian', 'n02112137-chow', 'n02112350-keeshond', 'n02112706-Brabancon_griffon', 'n02113023-Pembroke', 'n02113186-Cardigan', 'n02113624-toy_poodle', 'n02113712-miniature_poodle', 'n02113799-standard_poodle', 'n02113978-Mexican_hairless', 'n02115641-dingo', 'n02115913-dhole', 'n02116738-African_hunting_dog']
# (120, 120)

# %%
data.show_batch(rows=3, figsize=(7,6))

# %% [markdown]
# ### Training: vgg16

# %%
## This is a workaround as learn_cnn gets stuck
def get_model(pretrained=True, model_name='resnet34' , **kwargs ):
    if model_name == 'resnet18':
        arch = models.resnet18(pretrained, **kwargs )
    if model_name == 'resnet34':
        arch = models.resnet34(pretrained, **kwargs )
    if model_name == 'resnet50':
        arch = models.resnet50(pretrained, **kwargs )
    if model_name == 'vgg16':
        arch = models.vgg16(pretrained, **kwargs )
    return arch
learn = Learner(data, get_model('vgg16'), metrics=[accuracy])

# %%
learn.model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
learn.fit_one_cycle(8)
# Out:
# Total time: 31:18 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.285065</td>
#       <td>3.766439</td>
#       <td>0.179300</td>
#       <td>03:58</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.323572</td>
#       <td>3.947093</td>
#       <td>0.135811</td>
#       <td>03:56</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.731878</td>
#       <td>2.881233</td>
#       <td>0.269193</td>
#       <td>03:54</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.141057</td>
#       <td>2.163445</td>
#       <td>0.405734</td>
#       <td>03:55</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.832841</td>
#       <td>1.656697</td>
#       <td>0.528669</td>
#       <td>03:54</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.414645</td>
#       <td>1.286009</td>
#       <td>0.622449</td>
#       <td>03:54</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.076228</td>
#       <td>1.131973</td>
#       <td>0.667638</td>
#       <td>03:52</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.944165</td>
#       <td>1.081315</td>
#       <td>0.678571</td>
#       <td>03:51</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('n02098413-Lhasa', 'n02086240-Shih-Tzu', 18),
#  ('n02097209-standard_schnauzer', 'n02097047-miniature_schnauzer', 10),
#  ('n02109961-Eskimo_dog', 'n02110063-malamute', 10),
#  ('n02109961-Eskimo_dog', 'n02110185-Siberian_husky', 10),
#  ('n02090721-Irish_wolfhound', 'n02092002-Scottish_deerhound', 9),
#  ('n02106030-collie', 'n02105855-Shetland_sheepdog', 9),
#  ('n02106662-German_shepherd', 'n02105162-malinois', 9),
#  ('n02094433-Yorkshire_terrier', 'n02097658-silky_terrier', 8),
#  ('n02096294-Australian_terrier', 'n02097658-silky_terrier', 8),
#  ('n02098413-Lhasa', 'n02085936-Maltese_dog', 8),
#  ('n02113624-toy_poodle', 'n02113712-miniature_poodle', 8),
#  ('n02087394-Rhodesian_ridgeback', 'n02100583-vizsla', 7),
#  ('n02088364-beagle', 'n02088238-basset', 7),
#  ('n02093428-American_Staffordshire_terrier',
#   'n02093256-Staffordshire_bullterrier',
#   7),
#  ('n02095570-Lakeland_terrier', 'n02095314-wire-haired_fox_terrier', 7),
#  ('n02097047-miniature_schnauzer', 'n02097209-standard_schnauzer', 7),
#  ('n02097658-silky_terrier', 'n02096294-Australian_terrier', 7),
#  ('n02102177-Welsh_springer_spaniel', 'n02101388-Brittany_spaniel', 7),
#  ('n02113023-Pembroke', 'n02113186-Cardigan', 7),
#  ('n02113186-Cardigan', 'n02113023-Pembroke', 7),
#  ('n02087394-Rhodesian_ridgeback', 'n02090379-redbone', 6),
#  ('n02096177-cairn', 'n02094258-Norwich_terrier', 6),
#  ('n02106030-collie', 'n02106166-Border_collie', 6),
#  ('n02108000-EntleBucher', 'n02107574-Greater_Swiss_Mountain_dog', 6),
#  ('n02110185-Siberian_husky', 'n02109961-Eskimo_dog', 6),
#  ('n02110185-Siberian_husky', 'n02110063-malamute', 6),
#  ('n02113712-miniature_poodle', 'n02113624-toy_poodle', 6),
#  ('n02113799-standard_poodle', 'n02102973-Irish_water_spaniel', 6),
#  ('n02089867-Walker_hound', 'n02089973-English_foxhound', 5),
#  ('n02089973-English_foxhound', 'n02089867-Walker_hound', 5),
#  ('n02090379-redbone', 'n02100583-vizsla', 5),
#  ('n02093256-Staffordshire_bullterrier',
#   'n02093428-American_Staffordshire_terrier',
#   5),
#  ('n02095314-wire-haired_fox_terrier', 'n02095570-Lakeland_terrier', 5),
#  ('n02099849-Chesapeake_Bay_retriever', 'n02092339-Weimaraner', 5),
#  ('n02104029-kuvasz', 'n02111500-Great_Pyrenees', 5),
#  ('n02106382-Bouvier_des_Flandres', 'n02093859-Kerry_blue_terrier', 5),
#  ('n02107574-Greater_Swiss_Mountain_dog', 'n02108000-EntleBucher', 5),
#  ('n02111889-Samoyed', 'n02111500-Great_Pyrenees', 5),
#  ('n02085936-Maltese_dog', 'n02098286-West_Highland_white_terrier', 4),
#  ('n02086079-Pekinese', 'n02086240-Shih-Tzu', 4),
#  ('n02088238-basset', 'n02088632-bluetick', 4),
#  ('n02089867-Walker_hound', 'n02088238-basset', 4),
#  ('n02090379-redbone', 'n02087394-Rhodesian_ridgeback', 4),
#  ('n02090379-redbone', 'n02088466-bloodhound', 4),
#  ('n02091134-whippet', 'n02091831-Saluki', 4),
#  ('n02092002-Scottish_deerhound', 'n02090721-Irish_wolfhound', 4),
#  ('n02094258-Norwich_terrier', 'n02096177-cairn', 4),
#  ('n02096585-Boston_bull', 'n02108915-French_bulldog', 4),
#  ('n02097658-silky_terrier', 'n02094433-Yorkshire_terrier', 4),
#  ('n02099429-curly-coated_retriever', 'n02102973-Irish_water_spaniel', 4),
#  ('n02107142-Doberman', 'n02107312-miniature_pinscher', 4),
#  ('n02107908-Appenzeller', 'n02108000-EntleBucher', 4),
#  ('n02110063-malamute', 'n02110185-Siberian_husky', 4),
#  ('n02110958-pug', 'n02108422-bull_mastiff', 4),
#  ('n02111277-Newfoundland', 'n02099267-flat-coated_retriever', 4),
#  ('n02111500-Great_Pyrenees', 'n02104029-kuvasz', 4),
#  ('n02111500-Great_Pyrenees', 'n02111889-Samoyed', 4),
#  ('n02085620-Chihuahua', 'n02086910-papillon', 3),
#  ('n02085936-Maltese_dog', 'n02096437-Dandie_Dinmont', 3),
#  ('n02085936-Maltese_dog', 'n02113624-toy_poodle', 3),
#  ('n02086910-papillon', 'n02085782-Japanese_spaniel', 3),
#  ('n02088238-basset', 'n02088364-beagle', 3),
#  ('n02088364-beagle', 'n02089867-Walker_hound', 3),
#  ('n02091244-Ibizan_hound', 'n02110806-basenji', 3),
#  ('n02091831-Saluki', 'n02090622-borzoi', 3),
#  ('n02092339-Weimaraner', 'n02099849-Chesapeake_Bay_retriever', 3),
#  ('n02093859-Kerry_blue_terrier', 'n02097130-giant_schnauzer', 3),
#  ('n02093991-Irish_terrier', 'n02096051-Airedale', 3),
#  ('n02094433-Yorkshire_terrier', 'n02096294-Australian_terrier', 3),
#  ('n02095570-Lakeland_terrier', 'n02093991-Irish_terrier', 3),
#  ('n02095570-Lakeland_terrier', 'n02096051-Airedale', 3),
#  ('n02095889-Sealyham_terrier', 'n02098286-West_Highland_white_terrier', 3),
#  ('n02096177-cairn', 'n02098286-West_Highland_white_terrier', 3),
#  ('n02097130-giant_schnauzer', 'n02097298-Scotch_terrier', 3),
#  ('n02097209-standard_schnauzer', 'n02092002-Scottish_deerhound', 3),
#  ('n02098105-soft-coated_wheaten_terrier', 'n02096177-cairn', 3),
#  ('n02099712-Labrador_retriever', 'n02099267-flat-coated_retriever', 3),
#  ('n02100583-vizsla', 'n02087394-Rhodesian_ridgeback', 3),
#  ('n02101006-Gordon_setter', 'n02099267-flat-coated_retriever', 3),
#  ('n02101388-Brittany_spaniel', 'n02102177-Welsh_springer_spaniel', 3),
#  ('n02101556-clumber', 'n02100735-English_setter', 3),
#  ('n02102318-cocker_spaniel', 'n02086646-Blenheim_spaniel', 3),
#  ('n02105056-groenendael', 'n02104365-schipperke', 3),
#  ('n02105505-komondor', 'n02105641-Old_English_sheepdog', 3),
#  ('n02105855-Shetland_sheepdog', 'n02106030-collie', 3),
#  ('n02106550-Rottweiler', 'n02089078-black-and-tan_coonhound', 3),
#  ('n02107142-Doberman', 'n02089078-black-and-tan_coonhound', 3),
#  ('n02107908-Appenzeller', 'n02107683-Bernese_mountain_dog', 3),
#  ('n02108000-EntleBucher', 'n02107683-Bernese_mountain_dog', 3),
#  ('n02108551-Tibetan_mastiff', 'n02111277-Newfoundland', 3),
#  ('n02108915-French_bulldog', 'n02085620-Chihuahua', 3),
#  ('n02109047-Great_Dane', 'n02091134-whippet', 3),
#  ('n02112018-Pomeranian', 'n02113023-Pembroke', 3),
#  ('n02113186-Cardigan', 'n02110806-basenji', 3),
#  ('n02113712-miniature_poodle', 'n02093647-Bedlington_terrier', 3),
#  ('n02113712-miniature_poodle', 'n02106382-Bouvier_des_Flandres', 3),
#  ('n02115913-dhole', 'n02115641-dingo', 3),
#  ('n02086240-Shih-Tzu', 'n02086079-Pekinese', 2),
#  ('n02086240-Shih-Tzu', 'n02096437-Dandie_Dinmont', 2),
#  ('n02086240-Shih-Tzu', 'n02097474-Tibetan_terrier', 2),
#  ('n02086646-Blenheim_spaniel', 'n02102177-Welsh_springer_spaniel', 2),
#  ('n02087046-toy_terrier', 'n02107312-miniature_pinscher', 2),
#  ('n02087046-toy_terrier', 'n02113186-Cardigan', 2),
#  ('n02087394-Rhodesian_ridgeback', 'n02110806-basenji', 2),
#  ('n02088238-basset', 'n02089867-Walker_hound', 2),
#  ('n02088364-beagle', 'n02089973-English_foxhound', 2),
#  ('n02088364-beagle', 'n02101388-Brittany_spaniel', 2),
#  ('n02088466-bloodhound', 'n02090379-redbone', 2),
#  ('n02088466-bloodhound', 'n02100877-Irish_setter', 2),
#  ('n02089078-black-and-tan_coonhound', 'n02106550-Rottweiler', 2),
#  ('n02090379-redbone', 'n02088364-beagle', 2),
#  ('n02090622-borzoi', 'n02092002-Scottish_deerhound', 2),
#  ('n02090622-borzoi', 'n02106166-Border_collie', 2),
#  ('n02090622-borzoi', 'n02111500-Great_Pyrenees', 2),
#  ('n02090721-Irish_wolfhound', 'n02098105-soft-coated_wheaten_terrier', 2),
#  ('n02090721-Irish_wolfhound', 'n02111129-Leonberg', 2),
#  ('n02091032-Italian_greyhound', 'n02091134-whippet', 2),
#  ('n02091032-Italian_greyhound', 'n02110806-basenji', 2),
#  ('n02091134-whippet', 'n02090721-Irish_wolfhound', 2),
#  ('n02091134-whippet', 'n02091032-Italian_greyhound', 2),
#  ('n02091635-otterhound', 'n02105641-Old_English_sheepdog', 2),
#  ('n02091831-Saluki', 'n02088094-Afghan_hound', 2),
#  ('n02091831-Saluki', 'n02091134-whippet', 2),
#  ('n02091831-Saluki', 'n02099601-golden_retriever', 2),
#  ('n02092002-Scottish_deerhound', 'n02090622-borzoi', 2),
#  ('n02092002-Scottish_deerhound', 'n02097209-standard_schnauzer', 2),
#  ('n02092339-Weimaraner', 'n02100583-vizsla', 2),
#  ('n02093256-Staffordshire_bullterrier', 'n02099712-Labrador_retriever', 2),
#  ('n02093647-Bedlington_terrier', 'n02095314-wire-haired_fox_terrier', 2),
#  ('n02093754-Border_terrier', 'n02094114-Norfolk_terrier', 2),
#  ('n02093859-Kerry_blue_terrier', 'n02106382-Bouvier_des_Flandres', 2),
#  ('n02094114-Norfolk_terrier', 'n02094258-Norwich_terrier', 2),
#  ('n02094114-Norfolk_terrier', 'n02096177-cairn', 2),
#  ('n02094114-Norfolk_terrier', 'n02097047-miniature_schnauzer', 2),
#  ('n02094258-Norwich_terrier', 'n02094114-Norfolk_terrier', 2),
#  ('n02094433-Yorkshire_terrier', 'n02097047-miniature_schnauzer', 2),
#  ('n02095314-wire-haired_fox_terrier', 'n02095889-Sealyham_terrier', 2),
#  ('n02095314-wire-haired_fox_terrier', 'n02096051-Airedale', 2),
#  ('n02095570-Lakeland_terrier', 'n02090721-Irish_wolfhound', 2),
#  ('n02095570-Lakeland_terrier', 'n02093859-Kerry_blue_terrier', 2),
#  ('n02095570-Lakeland_terrier', 'n02097130-giant_schnauzer', 2),
#  ('n02095570-Lakeland_terrier', 'n02098105-soft-coated_wheaten_terrier', 2),
#  ('n02095889-Sealyham_terrier', 'n02097047-miniature_schnauzer', 2),
#  ('n02096177-cairn', 'n02094114-Norfolk_terrier', 2),
#  ('n02096177-cairn', 'n02105251-briard', 2),
#  ('n02096294-Australian_terrier', 'n02094258-Norwich_terrier', 2),
#  ('n02096437-Dandie_Dinmont', 'n02097474-Tibetan_terrier', 2),
#  ('n02096437-Dandie_Dinmont', 'n02098413-Lhasa', 2),
#  ('n02097047-miniature_schnauzer', 'n02098286-West_Highland_white_terrier', 2),
#  ('n02097130-giant_schnauzer', 'n02106382-Bouvier_des_Flandres', 2),
#  ('n02097209-standard_schnauzer', 'n02093754-Border_terrier', 2),
#  ('n02097298-Scotch_terrier', 'n02098286-West_Highland_white_terrier', 2),
#  ('n02097474-Tibetan_terrier', 'n02085936-Maltese_dog', 2),
#  ('n02097474-Tibetan_terrier', 'n02086240-Shih-Tzu', 2),
#  ('n02098105-soft-coated_wheaten_terrier',
#   'n02105641-Old_English_sheepdog',
#   2),
#  ('n02098286-West_Highland_white_terrier', 'n02085936-Maltese_dog', 2),
#  ('n02098413-Lhasa', 'n02096177-cairn', 2),
#  ('n02098413-Lhasa', 'n02097474-Tibetan_terrier', 2),
#  ('n02099267-flat-coated_retriever', 'n02104365-schipperke', 2),
#  ('n02099429-curly-coated_retriever', 'n02093859-Kerry_blue_terrier', 2),
#  ('n02099429-curly-coated_retriever', 'n02097130-giant_schnauzer', 2),
#  ('n02099429-curly-coated_retriever', 'n02099849-Chesapeake_Bay_retriever', 2),
#  ('n02099601-golden_retriever', 'n02098413-Lhasa', 2),
#  ('n02099849-Chesapeake_Bay_retriever',
#   'n02100236-German_short-haired_pointer',
#   2),
#  ('n02099849-Chesapeake_Bay_retriever', 'n02100583-vizsla', 2),
#  ('n02100236-German_short-haired_pointer',
#   'n02099267-flat-coated_retriever',
#   2),
#  ('n02100236-German_short-haired_pointer',
#   'n02099849-Chesapeake_Bay_retriever',
#   2),
#  ('n02100735-English_setter', 'n02101388-Brittany_spaniel', 2),
#  ('n02101006-Gordon_setter', 'n02106550-Rottweiler', 2),
#  ('n02101388-Brittany_spaniel', 'n02086646-Blenheim_spaniel', 2),
#  ('n02101388-Brittany_spaniel', 'n02088238-basset', 2),
#  ('n02101388-Brittany_spaniel', 'n02102040-English_springer', 2),
#  ('n02102040-English_springer', 'n02106166-Border_collie', 2),
#  ('n02102318-cocker_spaniel', 'n02102040-English_springer', 2),
#  ('n02102318-cocker_spaniel', 'n02113624-toy_poodle', 2),
#  ('n02102480-Sussex_spaniel', 'n02099429-curly-coated_retriever', 2),
#  ('n02102480-Sussex_spaniel', 'n02102318-cocker_spaniel', 2),
#  ('n02102973-Irish_water_spaniel', 'n02093859-Kerry_blue_terrier', 2),
#  ('n02102973-Irish_water_spaniel', 'n02099429-curly-coated_retriever', 2),
#  ('n02104365-schipperke', 'n02105056-groenendael', 2),
#  ('n02105162-malinois', 'n02115641-dingo', 2),
#  ('n02105251-briard', 'n02098105-soft-coated_wheaten_terrier', 2),
#  ('n02105412-kelpie', 'n02113186-Cardigan', 2),
#  ('n02105412-kelpie', 'n02113978-Mexican_hairless', 2),
#  ('n02106030-collie', 'n02107683-Bernese_mountain_dog', 2),
#  ('n02106166-Border_collie', 'n02106030-collie', 2),
#  ('n02106166-Border_collie', 'n02113186-Cardigan', 2),
#  ('n02106382-Bouvier_des_Flandres', 'n02090721-Irish_wolfhound', 2),
#  ('n02106382-Bouvier_des_Flandres', 'n02097130-giant_schnauzer', 2),
#  ('n02106382-Bouvier_des_Flandres', 'n02105251-briard', 2),
#  ('n02106662-German_shepherd', 'n02105412-kelpie', 2),
#  ('n02107142-Doberman', 'n02105412-kelpie', 2),
#  ('n02107142-Doberman', 'n02106550-Rottweiler', 2),
#  ('n02107312-miniature_pinscher', 'n02106550-Rottweiler', 2),
#  ('n02107312-miniature_pinscher', 'n02110806-basenji', 2),
#  ('n02107683-Bernese_mountain_dog', 'n02107574-Greater_Swiss_Mountain_dog', 2),
#  ('n02107683-Bernese_mountain_dog', 'n02107908-Appenzeller', 2),
#  ('n02107908-Appenzeller', 'n02107574-Greater_Swiss_Mountain_dog', 2),
#  ('n02108000-EntleBucher', 'n02107908-Appenzeller', 2),
#  ('n02108422-bull_mastiff', 'n02108089-boxer', 2),
#  ('n02108915-French_bulldog', 'n02096585-Boston_bull', 2),
#  ('n02108915-French_bulldog', 'n02105412-kelpie', 2),
#  ('n02109047-Great_Dane', 'n02087394-Rhodesian_ridgeback', 2),
#  ('n02109047-Great_Dane', 'n02092339-Weimaraner', 2),
#  ('n02110627-affenpinscher', 'n02094433-Yorkshire_terrier', 2),
#  ('n02110806-basenji', 'n02087046-toy_terrier', 2),
#  ('n02110958-pug', 'n02093256-Staffordshire_bullterrier', 2),
#  ('n02110958-pug', 'n02108915-French_bulldog', 2),
#  ('n02111129-Leonberg', 'n02099849-Chesapeake_Bay_retriever', 2),
#  ('n02111500-Great_Pyrenees', 'n02099601-golden_retriever', 2),
#  ('n02111500-Great_Pyrenees', 'n02099712-Labrador_retriever', 2),
#  ('n02112018-Pomeranian', 'n02086910-papillon', 2),
#  ('n02112018-Pomeranian', 'n02111889-Samoyed', 2),
#  ('n02112018-Pomeranian', 'n02112137-chow', 2),
#  ('n02112018-Pomeranian', 'n02112350-keeshond', 2),
#  ('n02112137-chow', 'n02112018-Pomeranian', 2),
#  ('n02113023-Pembroke', 'n02086910-papillon', 2),
#  ('n02113712-miniature_poodle', 'n02093859-Kerry_blue_terrier', 2),
#  ('n02113799-standard_poodle', 'n02093647-Bedlington_terrier', 2),
#  ('n02113799-standard_poodle', 'n02093859-Kerry_blue_terrier', 2),
#  ('n02113799-standard_poodle', 'n02102040-English_springer', 2),
#  ('n02113799-standard_poodle', 'n02113712-miniature_poodle', 2),
#  ('n02115641-dingo', 'n02110806-basenji', 2),
#  ('n02115641-dingo', 'n02113023-Pembroke', 2),
#  ('n02115641-dingo', 'n02115913-dhole', 2)]

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 03:50 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.244010</td>
#       <td>1.198735</td>
#       <td>0.655977</td>
#       <td>03:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage-1');
learn.lr_find()
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (16464 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# n02085620-Chihuahua,n02085620-Chihuahua,n02085620-Chihuahua,n02085620-Chihuahua,n02085620-Chihuahua
# Path: fastai;
#
# Valid: LabelList (4116 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# n02095570-Lakeland_terrier,n02096437-Dandie_Dinmont,n02102177-Welsh_springer_spaniel,n02107683-Bernese_mountain_dog,n02106382-Bouvier_des_Flandres
# Path: fastai;
#
# Test: None, model=ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x000002E4A4CBAC80>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=WindowsPath('fastai'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True)], callbacks=[], layer_groups=[Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU(inplace)
#   (7): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (9): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): ReLU(inplace)
#   (12): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (15): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): ReLU(inplace)
#   (17): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (18): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (19): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (20): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (21): ReLU(inplace)
#   (22): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (23): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (25): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (26): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (27): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (28): ReLU(inplace)
#   (29): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (30): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (31): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (32): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (33): ReLU(inplace)
#   (34): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (35): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (36): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (37): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (38): ReLU(inplace)
#   (39): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (40): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (41): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (42): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (43): ReLU(inplace)
#   (44): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (45): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (46): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (47): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (48): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (49): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (50): ReLU(inplace)
#   (51): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (52): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (53): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (54): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (55): ReLU(inplace)
#   (56): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (57): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (58): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (59): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (60): ReLU(inplace)
#   (61): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (62): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (63): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (64): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (65): ReLU(inplace)
#   (66): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (67): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (68): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (69): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (70): ReLU(inplace)
#   (71): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (72): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (73): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (74): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (75): ReLU(inplace)
#   (76): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (77): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (78): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (79): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (80): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (81): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (82): ReLU(inplace)
#   (83): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (84): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (85): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (86): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (87): ReLU(inplace)
#   (88): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (89): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (90): AdaptiveAvgPool2d(output_size=(1, 1))
#   (91): Linear(in_features=512, out_features=1000, bias=True)
# )], add_time=True)
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(1, max_lr=slice(1e-04))
# Out:
# Total time: 04:22 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.884922</td>
#       <td>1.066632</td>
#       <td>0.684645</td>
#       <td>04:22</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
#  0.68 acc not as good as Xception Keras!
