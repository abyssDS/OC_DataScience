# %% [markdown]
# ## 2 - Design of predictive model

# %% [markdown]
# ### Importing librairies

# %%
import pandas as pd
from pandas.api.types import is_string_dtype, is_numeric_dtype
import matplotlib.pyplot  as plt
import numpy as np
import feather
import seaborn as sns
from datetime import datetime
import pickle
import math

from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.externals import joblib
from sklearn.linear_model import LinearRegression, Lasso, ElasticNet, Ridge
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV

import warnings; warnings.simplefilter('ignore')

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

pd.options.display.max_rows = 500
pd.options.display.max_columns = 200 
pd.set_option('display.float_format', lambda x: '%.3f' % x) #display numbers as decimals instead of scientific value

plt.rcParams["font.size"] = (18)

# %% [markdown]
# Importing the data

# %%
file_path = '2016_clean.csv'
df = pd.read_csv(file_path, low_memory=False)
df = df.drop('Unnamed: 0', axis = 1)
df.shape
# Out:
# (5440148, 10)

# %% [markdown]
# Adding columns to the data

# %%
df['DAY_OF_WEEK'] = df['DAY'].apply(lambda x: round((x-4)%7)+1)

# %%
df.shape
# Out:
# (5440148, 11)

# %%
def myround(x, base):
    return int(base * round(float(x)/base))

df['Heure départ'] = df['CRS_DEP_TIME'].apply(lambda x:myround(x ,5))
df['Heure arrivée'] = df['CRS_ARR_TIME'].apply(lambda x:myround(x ,5))

# %%
df['Temps de vol'] = df['CRS_ELAPSED_TIME'].apply(lambda x:myround(x ,10))

# %%
df['Jour'] = df['DAY']
df['Jour semaine'] = df['DAY_OF_WEEK']
df['Airline']=df['CARRIER']
df['Code Avion'] = df['TAIL_NUM']
df['Aeroport départ'] = df['ORIGIN_AIRPORT_ID']
df['Aeroport arrivée'] =df['DEST_AIRPORT_ID']

# %%
df.columns
# Out:
# Index(['DELAY', 'DAY', 'WEEK', 'CARRIER', 'TAIL_NUM', 'ORIGIN_AIRPORT_ID',
#        'DEST_AIRPORT_ID', 'CRS_DEP_TIME', 'CRS_ARR_TIME', 'CRS_ELAPSED_TIME',
#        'DAY_OF_WEEK', 'Heure départ', 'Heure arrivée', 'Temps de vol', 'Jour',
#        'Jour semaine', 'Airline', 'Code Avion', 'Aeroport départ',
#        'Aeroport arrivée'],
#       dtype='object')

# %% [markdown]
# ### Outliers

# %%
ten_min_delay_count = df[df['DELAY'] >5].shape[0]

quantile_99 = df[df['DELAY'] >5]['DELAY'].quantile(0.99)
outlier_delay_count =df[df['DELAY'] >quantile_99].shape[0]

print( 'Out of',ten_min_delay_count, 'flights delayed of more than 5 min' )
print( '99% are under',quantile_99,'min' )
print( 'Which leaves 1% of very large delays (outliers) : ',outlier_delay_count,'flights' )
print( 'Lowering those delays to',quantile_99,'to not impact mean values too much')

df.loc[df['DELAY'] >quantile_99, 'DELAY'] = quantile_99
# Out:
# Out of 1413917 flights delayed of more than 5 min
# 99% are under 290.0 min
# Which leaves 1% of very large delays (outliers) :  14119 flights
# Lowering those delays to 290.0 to not impact mean values too much

# %%
def fill_feature_with_mean(df, feature_name) :
    print('Filling null',feature_name,'with mean:',round(df[feature_name].mean(),2))
    df[feature_name] = df[feature_name].fillna(round(df[feature_name].mean(),2))

# %% [markdown]
# ### Separate data in 2 sets

# %%
msk = np.random.rand(len(df)) < 0.7
train_set = df[msk]
test_set = df[~msk]
print('Train set has',train_set.shape[0],'rows')
print('Test set has',test_set.shape[0],'rows')
# Out:
# Train set has 3806996 rows
# Test set has 1633152 rows

# %% [markdown]
# ### Testing effects of polynomial transformations
# Ordering first by mean delay on our train set
# Then checking poly transformation scoring effect

# %%
#given X and y single features DFs
def display_poly(X,y):
    plt.rcParams["figure.figsize"] = (15,8)
    col = X.columns[0]
    x_range = np.linspace(X.min().values[0], X.max().values[0], X.nunique().values[0])
    
    y_true= X.join(y).groupby(col).mean().values.flatten()

    X = X.values.flatten()
    y = y.values.flatten()

    # create matrix versions of these arrays
    np_x = X[:, np.newaxis]
    np_x_range = x_range[:, np.newaxis]
    colors = ['green', 'orange', 'red', 'gold', 'purple', 'black']
    plt.plot(x_range, y_true, color='cornflowerblue', linewidth=3,
             label="ground truth")

    for count, degree in enumerate([0,3,6,9]):
        if degree ==0:
            model = make_pipeline(Ridge())
        else:   
            model = make_pipeline(PolynomialFeatures(degree), Ridge())
        silent =  model.fit(np_x, y)
        y_plot = model.predict(np_x_range)
        r2_score = round(model.score(np_x, y)*10000)/10000
        silent = plt.plot(x_range, y_plot, color=colors[count], linewidth=2,  linestyle = '--', alpha = 0.8,
                 label="degree {} (score:{})".format(degree, r2_score))

        silent = plt.legend(loc='bottom right')
        silent = plt.title('Retard moyen par '+col)
        silent = plt.ylabel('Retard moyen (minutes)')
        silent = plt.xlabel(col)

    plt.show()

# %%
X_cols=pd.DataFrame(
    columns=['original_name','reorder','nb_poly_features', 'poly_score']
    , data=[
   ['Jour',True, 9 , 0.0299            ]
    ,['Jour semaine',True, 1, 0.008]
    ,['Airline',True,3,0.005            ]
    ,['Code Avion',True,3,0.01 ]            
    ,['Temps de vol',True,3, 0.001]
    ,['Aeroport départ',True,3,0.0047      ]
    ,['Aeroport arrivée',True,3,0.0056        ]
    ,['Heure départ',False,3,0.0129          ]
    ,['Heure arrivée',False,3,0.0128          ]
     ])

X_cols['new_name']=X_cols['original_name']
X_cols
# Out:
#       original_name  reorder  nb_poly_features  poly_score          new_name
# 0              Jour     True                 9       0.030              Jour
# 1      Jour semaine     True                 1       0.008      Jour semaine
# 2           Airline     True                 3       0.005           Airline
# 3        Code Avion     True                 3       0.010        Code Avion
# 4      Temps de vol     True                 3       0.001      Temps de vol
# 5   Aeroport départ     True                 3       0.005   Aeroport départ
# 6  Aeroport arrivée     True                 3       0.006  Aeroport arrivée
# 7      Heure départ    False                 3       0.013      Heure départ
# 8     Heure arrivée    False                 3       0.013     Heure arrivée

# %%
y_col = 'DELAY'
for index, row in X_cols.iterrows():
    col = row['original_name']
    if row['reorder'] == True:
        X_cols.loc[index, 'new_name'] = col_new_name = col.lower()+' ordonné'
        if col_new_name not in test_set.columns:
            col_ordered =train_set[[col,y_col]].groupby(col).mean().sort_values(y_col).reset_index().reset_index().set_index(col).rename({'index':col_new_name}, axis=1)
            test_set = test_set.join(col_ordered.drop(y_col , axis =1), on=col)
    else:
        X_cols.loc[index, 'new_name'] = col_new_name = col
        
    fill_feature_with_mean(test_set, col_new_name)
    
    X_ = test_set[[col_new_name]]
    y_ = test_set[[y_col]]
    display_poly(X_, y_)
# Out:
# Filling null jour ordonné with mean: 186.06
# Filling null jour semaine ordonné with mean: 3.09
# Filling null airline ordonné with mean: 4.53
# Filling null code avion ordonné with mean: 2390.59
# Filling null temps de vol ordonné with mean: 32.8
# Filling null aeroport départ ordonné with mean: 162.9
# Filling null aeroport arrivée ordonné with mean: 173.88
# Filling null Heure départ with mean: 1330.19
# Filling null Heure arrivée with mean: 1490.54

# %%
X = test_set.loc[:, X_cols['new_name']]
y = test_set['DELAY']
X.shape
y.shape
# Out:
# (1633152, 9)
# (1633152,)

# %%
X.columns
# Out:
# Index(['jour ordonné', 'jour semaine ordonné', 'airline ordonné',
#        'code avion ordonné', 'temps de vol ordonné', 'aeroport départ ordonné',
#        'aeroport arrivée ordonné', 'Heure départ', 'Heure arrivée'],
#       dtype='object')

# %% [markdown]
# ### Displaying correlated features before applying poly transformation

# %%
plt.rcParams["figure.figsize"] = (10,10)
xy = pd.concat([X, y], axis=1, join='inner')
fig = sns.heatmap(xy.corr(), annot = True,fmt = ".2f",square=True, cmap='RdYlGn')
plt.title('Tableau de Correlation')
# Out:
# Text(0.5,1,'Tableau de Correlation')

# %% [markdown]
# ## Polynomial features preprocess

# %%
# Applying poly transformation on our selected features
for index, row in X_cols.iterrows():
    col = row['original_name']
    nb_poly_features = row['nb_poly_features']
    col_new_name = row['new_name']
    
    
    df_col_ordered =  pd.DataFrame(test_set[col_new_name].unique(), columns=[col_new_name]).sort_values(col_new_name)
        
   # df_col_ordered
    if nb_poly_features>0:
        poly = PolynomialFeatures(nb_poly_features, include_bias  =False)
        poly_transfo = poly.fit_transform(df_col_ordered)
        df_poly = pd.DataFrame(poly_transfo, index=df_col_ordered[col_new_name].values).add_prefix(col.lower()+'_poly_')

        X = X.join(df_poly , on =col_new_name, how='left').drop(col_new_name, axis=1)
        print(col,'processed.',X.shape)
# Out:
# Jour processed. (1633152, 17)
# Jour semaine processed. (1633152, 17)
# Airline processed. (1633152, 19)
# Code Avion processed. (1633152, 21)
# Temps de vol processed. (1633152, 23)
# Aeroport départ processed. (1633152, 25)
# Aeroport arrivée processed. (1633152, 27)
# Heure départ processed. (1633152, 29)
# Heure arrivée processed. (1633152, 31)

# %%
X.describe()
# Out:
#        jour_poly_0  jour_poly_1  jour_poly_2     jour_poly_3  \
# count  1633152.000  1633152.000  1633152.000     1633152.000
# mean       186.059    45589.153 12533560.199  3671046292.967
# std        104.743    39908.350 13917706.302  4793241515.746
# min          0.000        0.000        0.000           0.000
# 25%         96.000     9216.000   884736.000    84934656.000
# 50%        187.000    34969.000  6539203.000  1222830961.000
# 75%        277.000    76729.000 21253933.000  5887339441.000
# max        365.000   133225.000 48627125.000 17748900625.000
#
#             jour_poly_4          jour_poly_5            jour_poly_6  \
# count       1633152.000          1633152.000            1633152.000
# mean  1119201893258.323  350792561372460.625 112204329319653456.000
# std   1652167088343.632  571622438497063.125 198599237912217760.000
# min               0.000                0.000                  0.000
# 25%      8153726976.000     782757789696.000     75144747810816.000
# 50%    228669389707.000   42761175875209.000   7996339888664083.000
# 75%   1630793025157.000  451729667968489.000 125129118027271456.000
# max   6478348728125.000 2364597285765625.000 863078009304453120.000
#
#                     jour_poly_7                  jour_poly_8  \
# count               1633152.000                  1633152.000
# mean   36451731045348601856.000  11988421701899112153088.000
# std    69270775887456788480.000  24246476220761034981376.000
# min                       0.000                        0.000
# 25%        7213895789838336.000       692533995824480256.000
# 50%     1495315559180183552.000    279624009566694309888.000
# 75%    34660765693554192384.000   9601032097114510852096.000
# max   315023473396125401088.000 114983567789585766285312.000
#
#        jour semaine_poly_0  airline_poly_0  airline_poly_1  airline_poly_2  \
# count          1633152.000     1633152.000     1633152.000     1633152.000
# mean                 3.091           4.527          26.432         183.982
# std                  1.981           2.437          27.351         280.001
# min                  0.000           0.000           0.000           0.000
# 25%                  1.000           3.000           9.000          27.000
# 50%                  3.000           4.000          16.000          64.000
# 75%                  5.000           6.000          36.000         216.000
# max                  6.000          11.000         121.000        1331.000
#
#        code avion_poly_0  code avion_poly_1  code avion_poly_2  \
# count        1633152.000        1633152.000        1633152.000
# mean            2390.585        7450764.835    26172952367.245
# std             1317.524        6554368.169    29763529640.562
# min                0.000              0.000              0.000
# 25%             1294.000        1674436.000     2166720184.000
# 50%             2353.000        5536609.000    13027640977.000
# 75%             3514.000       12348196.000    43391560744.000
# max             5029.000       25290841.000   127187639389.000
#
#        temps de vol_poly_0  temps de vol_poly_1  temps de vol_poly_2  \
# count          1633152.000          1633152.000          1633152.000
# mean                32.803             1195.761            47292.596
# std                 10.942              750.549            42477.353
# min                  0.000                0.000                0.000
# 25%                 24.000              576.000            13824.000
# 50%                 30.000              900.000            27000.000
# 75%                 42.000             1764.000            74088.000
# max                 68.000             4624.000           314432.000
#
#        aeroport départ_poly_0  aeroport départ_poly_1  aeroport départ_poly_2  \
# count             1633152.000             1633152.000             1633152.000
# mean                  162.895               32176.192             7119007.447
# std                    75.109               25586.739             7516162.960
# min                     1.000                   1.000                   1.000
# 25%                   100.000               10000.000             1000000.000
# 50%                   161.000               25921.000             4173281.000
# 75%                   249.000               62001.000            15438249.000
# max                   309.000               95481.000            29503629.000
#
#        aeroport arrivée_poly_0  aeroport arrivée_poly_1  \
# count              1633152.000              1633152.000
# mean                   173.885                36229.683
# std                     77.419                28233.783
# min                      0.000                    0.000
# 25%                    109.000                11881.000
# 50%                    167.000                27889.000
# 75%                    253.000                64009.000
# max                    307.000                94249.000
#
#        aeroport arrivée_poly_2  heure départ_poly_0  heure départ_poly_1  \
# count              1633152.000          1633152.000          1633152.000
# mean               8449395.512             1330.188          2008969.878
# std                8678453.846              489.459          1338493.316
# min                      0.000                0.000                0.000
# 25%                1295029.000              915.000           837225.000
# 50%                4657463.000             1325.000          1755625.000
# 75%               16194277.000             1735.000          3010225.000
# max               28934443.000             2360.000          5569600.000
#
#        heure départ_poly_2  heure arrivée_poly_0  heure arrivée_poly_1  \
# count          1633152.000           1633152.000           1633152.000
# mean        3317088452.858              1490.544           2488044.163
# std         3044847875.457               516.066           1490246.261
# min                  0.000                 0.000                 0.000
# 25%          766060875.000              1105.000           1221025.000
# 50%         2326203125.000              1520.000           2310400.000
# 75%         5222740375.000              1920.000           3686400.000
# max        13144256000.000              2400.000           5760000.000
#
#        heure arrivée_poly_2
# count           1633152.000
# mean         4459704104.562
# std          3634153274.874
# min                   0.000
# 25%          1349232625.000
# 50%          3511808000.000
# 75%          7077888000.000
# max         13824000000.000

# %% [markdown]
# ## Prediction models

# %% [markdown]
# ## Split data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %% [markdown]
# ## Linear regression

# %%
linear = LinearRegression()
cv_scores = cross_val_score(linear, X, y, cv =5)
print("Average 5-Fold CV Score: {}".format(np.mean(cv_scores)))


linear.fit(X_train, y_train)

y_true, y_pred = y_test, linear.predict(X_test)

print("R squared: {}".format(r2_score(y_true, y_pred)))
print("Mean absolute value : {}".format(mean_absolute_error(y_true, y_pred)))
print("rmse : {}".format(math.sqrt(mean_squared_error(y_true, y_pred))))
# Out:
# Average 5-Fold CV Score: 0.04654322530702946
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# R squared: 0.054233717186997765
# Mean absolute value : 15.967321507539156
# rmse : 31.387535369347034

# %% [markdown]
# ### Hyper param display functions

# %%
def display_plot(cv_scores, cv_scores_std, alpha_space):
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    ax.plot(alpha_space, cv_scores)

    std_error = cv_scores_std / np.sqrt(10)

    ax.fill_between(alpha_space, cv_scores + std_error, cv_scores - std_error, alpha=0.2)
    ax.set_ylabel('CV Score +/- Std Error')
    ax.set_xlabel('Alpha')
    ax.axhline(np.max(cv_scores), linestyle='--', color='.5')
    ax.set_xlim([alpha_space[0], alpha_space[-1]])
    ax.set_xscale('log')
    plt.show()

# %%
def hyper_param(model, X, y):
    alpha_space = np.logspace(-16, 0, 20)
    scores = []
    scores_std = []
    model.normalize = True

    # Compute scores over range of alphas
    for alpha in alpha_space:
        model.alpha = alpha

        # k folds
        cv_scores = cross_val_score(model, X, y, cv =3)

        scores.append(np.mean(cv_scores))
        scores_std.append(np.std(cv_scores))
    
    max_score =  max(scores)
    returned_alpha = alpha_space[scores.index(max_score)]
    print ('Highest score is', max_score, 'alpha :', returned_alpha)
    
    plt.rcParams["figure.figsize"] = (10,4)
    display_plot(scores, scores_std, alpha_space)
    return returned_alpha

# %% [markdown]
# ## Lasso

# %%
lasso = Lasso(normalize = True)
lasso.alpha = hyper_param(Lasso(), X_train, y_train)

# %%
#parameters = {'alpha': np.logspace(-15, 0, 20)}
#gm_cv = GridSearchCV(lasso,param_grid=parameters)
#gm_cv.fit(X_train,y_train)

# %%
plt.rcParams["figure.figsize"] = (10,4)
lasso.fit(X_train,y_train)
lasso_coef = lasso.coef_
print(lasso_coef , 'lasso coeff')

silent = plt.bar(range(len(X.columns)), lasso_coef)
silent = plt.xticks(range(len(X.columns)), X.columns.values, rotation=60)
silent = plt.title('Selecting best alpha')
silent = plt.ylabel('Lasso Coeff')
silent = plt.title('Lasso coefficients')


silent =plt.show()

cv_scores = cross_val_score(lasso,  X, y, cv =5)
print("Average 5-Fold CV Score: {}".format(np.mean(cv_scores)))

y_true, y_pred = y_test, lasso.predict(X_test)

print("Lasso R squared: {}".format(r2_score(y_true, y_pred)))
print("Mean absolute value : {}".format(mean_absolute_error(y_true, y_pred)))
print("rmse : {}".format(math.sqrt(mean_squared_error(y_true, y_pred))))

# %% [markdown]
# ## Ridge Reg (chosen model)

# %%
ridge = Ridge()
ridge.alpha = hyper_param(Ridge(), X_train, y_train)
# Out:
# Highest score is 0.05816272655978808 alpha : 4.8329302385717525e-15

# %%
ridge.fit(X_train, y_train)
y_true, y_pred = y_test, ridge.predict(X_test)

print("r2_score : {}".format(r2_score(y_true, y_pred)))
print("Mean absolute value : {}".format(mean_absolute_error(y_true, y_pred)))
print("rmse : {}".format(math.sqrt(mean_squared_error(y_true, y_pred))))
# Out:
# Ridge(alpha=4.8329302385717525e-15, copy_X=True, fit_intercept=True,
#    max_iter=None, normalize=False, random_state=None, solver='auto',
#    tol=0.001)
# r2_score : 0.05817633486917928
# Mean absolute value : 16.00065923855087
# rmse : 31.32204440612369

# %%
cv_scores = cross_val_score(ridge,  X, y, cv =5)
print("Average 5-Fold CV Score: {}".format(np.mean(cv_scores)))
# Out:
# Average 5-Fold CV Score: 0.04969051238413158

# %%
results = test_set.loc[X_test.index]
results['y_pred'] = y_pred
results['y_true'] = results['DELAY']
results.head(5)
# Out:
#           DELAY  DAY  WEEK CARRIER TAIL_NUM  ORIGIN_AIRPORT_ID  \
# 369758    2.000   13    14      WN   N8641B          13342.000
# 3985177   0.000  260   259      DL   N906AT          10397.000
# 4153626   0.000  277   280      EV   N14977          10469.000
# 131256  110.000   21    21      OO   N955SW          13342.000
# 2580899  39.000  173   175      AA   N669AW          14100.000
#
#          DEST_AIRPORT_ID  CRS_DEP_TIME  CRS_ARR_TIME  CRS_ELAPSED_TIME  \
# 369758         15304.000       715.000      1110.000           175.000
# 3985177        13230.000       954.000      1143.000           109.000
# 4153626        13930.000       635.000       638.000            63.000
# 131256         13930.000      1626.000      1725.000            59.000
# 2580899        14747.000       735.000      1027.000           352.000
#
#          DAY_OF_WEEK  Heure départ  Heure arrivée  Temps de vol  Jour  \
# 369758             3           715           1110           180    13
# 3985177            5           955           1145           110   260
# 4153626            1           635            640            60   277
# 131256             4          1625           1725            60    21
# 2580899            2           735           1025           350   173
#
#          Jour semaine Airline Code Avion  Aeroport départ  Aeroport arrivée  \
# 369758              3      WN     N8641B        13342.000         15304.000
# 3985177             5      DL     N906AT        10397.000         13230.000
# 4153626             1      EV     N14977        10469.000         13930.000
# 131256              4      OO     N955SW        13342.000         13930.000
# 2580899             2      AA     N669AW        14100.000         14747.000
#
#          jour ordonné  jour semaine ordonné  airline ordonné  \
# 369758            158                     1                3
# 3985177            84                     6                2
# 4153626            53                     4                7
# 131256            188                     5                4
# 2580899           314                     2                6
#
#          code avion ordonné  temps de vol ordonné  aeroport départ ordonné  \
# 369758              329.000                    50                      113
# 3985177             239.000                    26                       87
# 4153626            2604.000                    20                      211
# 131256             1969.000                    20                      113
# 2580899            1636.000                    47                      200
#
#          aeroport arrivée ordonné  y_pred  y_true
# 369758                    208.000  -0.697   2.000
# 3985177                   218.000  -1.215   0.000
# 4153626                   268.000   2.084   0.000
# 131256                    268.000  13.315 110.000
# 2580899                    99.000  10.235  39.000

# %%
def compare_result_plot(results, col_name):
    plt.rcParams["figure.figsize"] = (12,6)
    X= results[col_name]
    x_range = np.linspace(X.min(), X.max(), X.nunique())
     
    y_true= results[['y_true', col_name]].groupby(col_name).mean().values
    y_pred= results[['y_pred', col_name]].groupby(col_name).mean().values

    X = X.values
    
    # create matrix versions of these arrays
    np_x = X[:, np.newaxis]
    np_x_range = x_range[:, np.newaxis]

    plt.plot(x_range, y_true, color='cornflowerblue', linewidth=3, alpha=0.5,
        label="true mean")
    plt.plot(x_range, y_pred, color='red', linewidth=3, linestyle = '-', alpha=0.5,
         label="pred mean")

    silent = plt.legend(loc='bottom right')
    silent = plt.title('Retard moyen par '+col_name)
    silent = plt.ylabel('Retard moyen (minutes)')
    silent = plt.xlabel(col_name)
        
    plt.show()

# %%
X_cols
# Out:
#       original_name  reorder  nb_poly_features  poly_score  \
# 0              Jour     True                 9       0.030
# 1      Jour semaine     True                 1       0.008
# 2           Airline     True                 3       0.005
# 3        Code Avion     True                 3       0.010
# 4      Temps de vol     True                 3       0.001
# 5   Aeroport départ     True                 3       0.005
# 6  Aeroport arrivée     True                 3       0.006
# 7      Heure départ    False                 3       0.013
# 8     Heure arrivée    False                 3       0.013
#
#                    new_name
# 0              jour ordonné
# 1      jour semaine ordonné
# 2           airline ordonné
# 3        code avion ordonné
# 4      temps de vol ordonné
# 5   aeroport départ ordonné
# 6  aeroport arrivée ordonné
# 7              Heure départ
# 8             Heure arrivée

# %%
for index, row in X_cols.iterrows():
    col_new_name = row['new_name']
    compare_result_plot(results, col_new_name)
    #compare_result_plot(test_set.loc[X_test.index, [col_new_name]], pd.DataFrame(y_true), pd.DataFrame(y_pred), col_new_name)

# %% [markdown]
# ## Exporting Data

# %%
generate error on full re run

# %%
ressources_folder = 'flask_api_oc4_xm/ressources/'

# %% [markdown]
# ### Loading reference tables csv for Airports and Carrier

# %%
file_path = 'sources/L_UNIQUE_CARRIERS.csv_'
df_carriers = pd.read_csv(file_path, low_memory=False, index_col = 'Code')

df_carriers = df_carriers.join(test_set.groupby('CARRIER').first()['carrier_ordered']).dropna()
df_carriers.head(2)
df_carriers.to_csv(ressources_folder+'df_carriers.csv')
# Out:
#                  Description  carrier_ordered
# Code
# AA    American Airlines Inc.            6.000
# AS      Alaska Airlines Inc.            1.000

# %%
df_airports
# Out:
#                                              Description  \
# Code
# 10135  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...
# 10136                      Abilene, TX: Abilene Regional
# 10140  Albuquerque, NM: Albuquerque International Sun...
# 10141                    Aberdeen, SD: Aberdeen Regional
# 10146             Albany, GA: Southwest Georgia Regional
# 10154                  Nantucket, MA: Nantucket Memorial
# 10155                            Waco, TX: Waco Regional
# 10157  Arcata/Eureka, CA: California Redwood Coast Hu...
# 10158     Atlantic City, NJ: Atlantic City International
# 10165                              Adak Island, AK: Adak
# 10170                         Kodiak, AK: Kodiak Airport
# 10185           Alexandria, LA: Alexandria International
# 10208        Augusta, GA: Augusta Regional at Bush Field
# 10245               King Salmon, AK: King Salmon Airport
# 10257                   Albany, NY: Albany International
# 10279  Amarillo, TX: Rick Husband Amarillo International
# 10299  Anchorage, AK: Ted Stevens Anchorage Internati...
# 10333                 Alpena, MI: Alpena County Regional
# 10372         Aspen, CO: Aspen Pitkin County Sardy Field
# 10397  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 10408               Appleton, WI: Appleton International
# 10423       Austin, TX: Austin - Bergstrom International
# 10431                  Asheville, NC: Asheville Regional
# 10434  Scranton/Wilkes-Barre, PA: Wilkes Barre Scrant...
# 10469  Kalamazoo, MI: Kalamazoo/Battle Creek Internat...
# 10529                Hartford, CT: Bradley International
# 10551                         Bethel, AK: Bethel Airport
# 10561                     Bakersfield, CA: Meadows Field
# 10577  Binghamton, NY: Greater Binghamton/Edwin A. Li...
# 10581                   Bangor, ME: Bangor International
# 10599  Birmingham, AL: Birmingham-Shuttlesworth Inter...
# 10620         Billings, MT: Billings Logan International
# 10627            Bismarck/Mandan, ND: Bismarck Municipal
# 10631                      Bemidji, MN: Bemidji Regional
# 10666           Bellingham, WA: Bellingham International
# 10685  Bloomington/Normal, IL: Central Illinois Regional
# 10693             Nashville, TN: Nashville International
# 10713                      Boise, ID: Boise Air Terminal
# 10721                    Boston, MA: Logan International
# 10728     Beaumont/Port Arthur, TX: Jack Brooks Regional
# 10731              Brunswick, GA: Brunswick Golden Isles
# 10732                    Aguadilla, PR: Rafael Hernandez
# 10739              Brainerd, MN: Brainerd Lakes Regional
# 10747  Brownsville, TX: Brownsville South Padre Islan...
# 10754        Barrow, AK: Wiley Post/Will Rogers Memorial
# 10779                             Butte, MT: Bert Mooney
# 10781  Baton Rouge, LA: Baton Rouge Metropolitan/Ryan...
# 10785           Burlington, VT: Burlington International
# 10792         Buffalo, NY: Buffalo Niagara International
# 10800                              Burbank, CA: Bob Hope
# 10821  Baltimore, MD: Baltimore/Washington Internatio...
# 10849     Bozeman, MT: Bozeman Yellowstone International
# 10868                Columbia, SC: Columbia Metropolitan
# 10874                   Akron, OH: Akron-Canton Regional
# 10918                Cedar City, UT: Cedar City Regional
# 10926                 Cordova, AK: Merle K Mudhole Smith
# 10980                      Chattanooga, TN: Lovell Field
# 10990     Charlottesville, VA: Charlottesville Albemarle
# 10994       Charleston, SC: Charleston AFB/International
# 11003       Cedar Rapids/Iowa City, IA: The Eastern Iowa
# 11013  Sault Ste. Marie, MI: Chippewa County Internat...
# 11042     Cleveland, OH: Cleveland-Hopkins International
# 11049        College Station/Bryan, TX: Easterwood Field
# 11057     Charlotte, NC: Charlotte Douglas International
# 11066    Columbus, OH: John Glenn Columbus International
# 11076     Hancock/Houghton, MI: Houghton County Memorial
# 11097                     Cody, WY: Yellowstone Regional
# 11109  Colorado Springs, CO: City of Colorado Springs...
# 11122    Casper, WY: Casper/Natrona County International
# 11140   Corpus Christi, TX: Corpus Christi International
# 11146                      Charleston/Dunbar, WV: Yeager
# 11150                     Columbus, GA: Columbus Airport
# 11193  Cincinnati, OH: Cincinnati/Northern Kentucky I...
# 11203                     Mosinee, WI: Central Wisconsin
# 11252     Daytona Beach, FL: Daytona Beach International
# 11259                      Dallas, TX: Dallas Love Field
# 11267       Dayton, OH: James M Cox/Dayton International
# 11278  Washington, DC: Ronald Reagan Washington National
# 11292                   Denver, CO: Denver International
# 11298  Dallas/Fort Worth, TX: Dallas/Fort Worth Inter...
# 11308                        Dothan, AL: Dothan Regional
# 11336                 Dillingham, AK: Dillingham Airport
# 11337                   Duluth, MN: Duluth International
# 11413               Durango, CO: Durango La Plata County
# 11423           Des Moines, IA: Des Moines International
# 11433            Detroit, MI: Detroit Metro Wayne County
# 11447              Devils Lake, ND: Devils Lake Regional
# 11471           Eau Claire, WI: Chippewa Valley Regional
# 11481  Panama City, FL: Northwest Florida Beaches Int...
# 11503                   Eagle, CO: Eagle County Regional
# 11525                            Elko, NV: Elko Regional
# 11537        Elmira/Corning, NY: Elmira/Corning Regional
# 11540                 El Paso, TX: El Paso International
# 11577       Erie, PA: Erie International/Tom Ridge Field
# 11587                         Escanaba, MI: Delta County
# 11603                     Eugene, OR: Mahlon Sweet Field
# 11612                Evansville, IN: Evansville Regional
# 11617  New Bern/Morehead/Beaufort, NC: Coastal Caroli...
# 11618           Newark, NJ: Newark Liberty International
# 11624               Key West, FL: Key West International
# 11630             Fairbanks, AK: Fairbanks International
# 11637                    Fargo, ND: Hector International
# 11638          Fresno, CA: Fresno Yosemite International
# 11641  Fayetteville, NC: Fayetteville Regional/Granni...
# 11648          Kalispell, MT: Glacier Park International
# 11695                   Flagstaff, AZ: Flagstaff Pulliam
# 11697  Fort Lauderdale, FL: Fort Lauderdale-Hollywood...
# 11721                    Flint, MI: Bishop International
# 11775                    Sioux Falls, SD: Joe Foss Field
# 11778                Fort Smith, AR: Fort Smith Regional
# 11823           Fort Wayne, IN: Fort Wayne International
# 11865             Gillette, WY: Gillette Campbell County
# 11867              Garden City, KS: Garden City Regional
# 11884                 Spokane, WA: Spokane International
# 11898         Grand Forks, ND: Grand Forks International
# 11905                  Longview, TX: East Texas Regional
# 11921        Grand Junction, CO: Grand Junction Regional
# 11953              Gainesville, FL: Gainesville Regional
# 11973  Gulfport/Biloxi, MS: Gulfport-Biloxi Internati...
# 11977  Green Bay, WI: Green Bay Austin Straubel Inter...
# 11980        Grand Island, NE: Central Nebraska Regional
# 11982                       Killeen, TX: Robert Gray AAF
# 11986     Grand Rapids, MI: Gerald R. Ford International
# 11995  Greensboro/High Point, NC: Piedmont Triad Inte...
# 11996    Greer, SC: Greenville-Spartanburg International
# 11997                     Gustavus, AK: Gustavus Airport
# 12003         Great Falls, MT: Great Falls International
# 12007             Columbus, MS: Golden Triangle Regional
# 12012      Gunnison, CO: Gunnison-Crested Butte Regional
# 12016                       Guam, TT: Guam International
# 12094                           Hayden, CO: Yampa Valley
# 12129                        Hibbing, MN: Range Regional
# 12156                        Helena, MT: Helena Regional
# 12173        Honolulu, HI: Daniel K Inouye International
# 12177                     Hobbs, NM: Lea County Regional
# 12191                       Houston, TX: William P Hobby
# 12197               White Plains, NY: Westchester County
# 12206     Harlingen/San Benito, TX: Valley International
# 12217  Huntsville, AL: Huntsville International-Carl ...
# 12250  Hyannis, MA: Barnstable Municipal-Boardman/Pol...
# 12255                            Hays, KS: Hays Regional
# 12264    Washington, DC: Washington Dulles International
# 12265     Niagara Falls, NY: Niagara Falls International
# 12266  Houston, TX: George Bush Intercontinental/Houston
# 12278  Wichita, KS: Wichita Dwight D Eisenhower National
# 12280              Idaho Falls, ID: Idaho Falls Regional
# 12323           Wilmington, NC: Wilmington International
# 12335                    Iron Mountain/Kingsfd, MI: Ford
# 12339       Indianapolis, IN: Indianapolis International
# 12343  International Falls, MN: Falls International E...
# 12389         Williston, ND: Sloulin Field International
# 12391                   Islip, NY: Long Island MacArthur
# 12397      Ithaca/Cortland, NY: Ithaca Tompkins Regional
# 12402                       Hilo, HI: Hilo International
# 12441                          Jackson, WY: Jackson Hole
# 12448  Jackson/Vicksburg, MS: Jackson Medgar Wiley Ev...
# 12451       Jacksonville, FL: Jacksonville International
# 12478        New York, NY: John F. Kennedy International
# 12511                        Joplin, MO: Joplin Regional
# 12519                  Jamestown, ND: Jamestown Regional
# 12523                   Juneau, AK: Juneau International
# 12758  Kona, HI: Ellison Onizuka Kona International a...
# 12819             Ketchikan, AK: Ketchikan International
# 12884          Lansing, MI: Capital Region International
# 12888                      Laramie, WY: Laramie Regional
# 12889              Las Vegas, NV: McCarran International
# 12891    Lawton/Fort Sill, OK: Lawton-Fort Sill Regional
# 12892         Los Angeles, CA: Los Angeles International
# 12896   Lubbock, TX: Lubbock Preston Smith International
# 12898                Latrobe, PA: Arnold Palmer Regional
# 12915            Lake Charles, LA: Lake Charles Regional
# 12945                          Lexington, KY: Blue Grass
# 12951  Lafayette, LA: Lafayette Regional Paul Fournet...
# 12953                            New York, NY: LaGuardia
# 12954                 Long Beach, CA: Long Beach Airport
# 12982                           Lihue, HI: Lihue Airport
# 12992  Little Rock, AR: Bill and Hillary Clinton Nat ...
# 13029                       Lincoln, NE: Lincoln Airport
# 13061                   Laredo, TX: Laredo International
# 13076                  La Crosse, WI: La Crosse Regional
# 13127            Lewiston, ID: Lewiston Nez Perce County
# 13158  Midland/Odessa, TX: Midland International Air ...
# 13184    Saginaw/Bay City/Midland, MI: MBS International
# 13198         Kansas City, MO: Kansas City International
# 13204                 Orlando, FL: Orlando International
# 13230           Harrisburg, PA: Harrisburg International
# 13232          Chicago, IL: Chicago Midway International
# 13241                            Meridian, MS: Key Field
# 13244                 Memphis, TN: Memphis International
# 13256  Mission/McAllen/Edinburg, TX: McAllen Miller I...
# 13264  Medford, OR: Rogue Valley International - Medford
# 13277                Montgomery, AL: Montgomery Regional
# 13290        Manhattan/Ft. Riley, KS: Manhattan Regional
# 13296         Manchester, NH: Manchester-Boston Regional
# 13303                     Miami, FL: Miami International
# 13342      Milwaukee, WI: General Mitchell International
# 13344                      Muskegon, MI: Muskegon County
# 13360             Melbourne, FL: Melbourne International
# 13367                Moline, IL: Quad City International
# 13377                        Monroe, LA: Monroe Regional
# 13388           Mammoth Lakes, CA: Mammoth Lakes Airport
# 13422                        Mobile, AL: Mobile Regional
# 13433                     Minot, ND: Minot International
# 13459                Marquette, MI: Sawyer International
# 13476                    Monterey, CA: Monterey Regional
# 13485      Madison, WI: Dane County Regional-Truax Field
# 13486               Missoula, MT: Missoula International
# 13487  Minneapolis, MN: Minneapolis-St Paul Internati...
# 13495  New Orleans, LA: Louis Armstrong New Orleans I...
# 13502              Montrose/Delta, CO: Montrose Regional
# 13541   Martha's Vineyard, MA: Martha's Vineyard Airport
# 13577       Myrtle Beach, SC: Myrtle Beach International
# 13795      Jacksonville/Camp Lejeune, NC: Albert J Ellis
# 13796    Oakland, CA: Metropolitan Oakland International
# 13830                       Kahului, HI: Kahului Airport
# 13851               Oklahoma City, OK: Will Rogers World
# 13871                         Omaha, NE: Eppley Airfield
# 13873                             Nome, AK: Nome Airport
# 13891                 Ontario, CA: Ontario International
# 13930          Chicago, IL: Chicago O'Hare International
# 13931                 Norfolk, VA: Norfolk International
# 13933                  Worcester, MA: Worcester Regional
# 13964  North Bend/Coos Bay, OR: Southwest Oregon Regi...
# 13970                  Kotzebue, AK: Ralph Wien Memorial
# 14006                      Paducah, KY: Barkley Regional
# 14025         Plattsburgh, NY: Plattsburgh International
# 14027  West Palm Beach/Palm Beach, FL: Palm Beach Int...
# 14057               Portland, OR: Portland International
# 14082               Punta Gorda, FL: Punta Gorda Airport
# 14098  Newport News/Williamsburg, VA: Newport News/Wi...
# 14100       Philadelphia, PA: Philadelphia International
# 14107      Phoenix, AZ: Phoenix Sky Harbor International
# 14108  Peoria, IL: General Downing - Peoria Internati...
# 14109  Hattiesburg/Laurel, MS: Hattiesburg-Laurel Reg...
# 14113                  Pocatello, ID: Pocatello Regional
# 14122           Pittsburgh, PA: Pittsburgh International
# 14150  Pellston, MI: Pellston Regional Airport of Emm...
# 14193             Pensacola, FL: Pensacola International
# 14222             Pago Pago, TT: Pago Pago International
# 14252           Pasco/Kennewick/Richland, WA: Tri Cities
# 14254                               Ponce, PR: Mercedita
# 14256         Petersburg, AK: Petersburg James A Johnson
# 14262       Palm Springs, CA: Palm Springs International
# 14307       Providence, RI: Theodore Francis Green State
# 14321       Portland, ME: Portland International Jetport
# 14457                Rapid City, SD: Rapid City Regional
# 14487                     Redding, CA: Redding Municipal
# 14489                    Bend/Redmond, OR: Roberts Field
# 14492   Raleigh/Durham, NC: Raleigh-Durham International
# 14520         Rhinelander, WI: Rhinelander/Oneida County
# 14524               Richmond, VA: Richmond International
# 14543   Rock Springs, WY: Rock Springs Sweetwater County
# 14570                 Reno, NV: Reno/Tahoe International
# 14574  Roanoke, VA: Roanoke Blacksburg Regional Woodr...
# 14576     Rochester, NY: Greater Rochester International
# 14588      Roswell, NM: Roswell International Air Center
# 14633             Rochester, MN: Rochester International
# 14635    Fort Myers, FL: Southwest Florida International
# 14674                   Santa Fe, NM: Santa Fe Municipal
# 14679             San Diego, CA: San Diego International
# 14683         San Antonio, TX: San Antonio International
# 14685   Savannah, GA: Savannah/Hilton Head International
# 14689         Santa Barbara, CA: Santa Barbara Municipal
# 14696           South Bend, IN: South Bend International
# 14698      San Luis Obispo, CA: San Luis County Regional
# 14709                   Deadhorse, AK: Deadhorse Airport
# 14711                 State College, PA: University Park
# 14730  Louisville, KY: Louisville International-Stand...
# 14747          Seattle, WA: Seattle/Tacoma International
# 14771     San Francisco, CA: San Francisco International
# 14783      Springfield, MO: Springfield-Branson National
# 14794                 St. George, UT: St George Regional
# 14814                Shreveport, LA: Shreveport Regional
# 14828                   Sitka, AK: Sitka Rocky Gutierrez
# 14831  San Jose, CA: Norman Y. Mineta San Jose Intern...
# 14842   San Angelo, TX: San Angelo Regional/Mathis Field
# 14843       San Juan, PR: Luis Munoz Marin International
# 14869   Salt Lake City, UT: Salt Lake City International
# 14893           Sacramento, CA: Sacramento International
# 14905  Santa Maria, CA: Santa Maria Public/Capt. G. A...
# 14908    Santa Ana, CA: John Wayne Airport-Orange County
# 14952           Springfield, IL: Abraham Lincoln Capital
# 14955  Saipan, TT: Francisco C. Ada Saipan International
# 14960  Wichita Falls, TX: Sheppard AFB/Wichita Falls ...
# 14986  Sarasota/Bradenton, FL: Sarasota/Bradenton Int...
# 15016      St. Louis, MO: St Louis Lambert International
# 15024                 Charlotte Amalie, VI: Cyril E King
# 15027                Christiansted, VI: Henry E. Rohlsen
# 15041   Sun Valley/Hailey/Ketchum, ID: Friedman Memorial
# 15070   Newburgh/Poughkeepsie, NY: Stewart International
# 15096       Syracuse, NY: Syracuse Hancock International
# 15249         Tallahassee, FL: Tallahassee International
# 15304                     Tampa, FL: Tampa International
# 15323     Bristol/Johnson City/Kingsport, TN: Tri Cities
# 15356                        Trenton, NJ: Trenton Mercer
# 15370                     Tulsa, OK: Tulsa International
# 15376                   Tucson, AZ: Tucson International
# 15380                  Traverse City, MI: Cherry Capital
# 15389  Twin Falls, ID: Joslin Field - Magic Valley Re...
# 15401       Texarkana, AR: Texarkana Regional-Webb Field
# 15411                   Tyler, TX: Tyler Pounds Regional
# 15412                        Knoxville, TN: McGhee Tyson
# 15497      St. Augustine, FL: Northeast Florida Regional
# 15607                    Valdosta, GA: Valdosta Regional
# 15624  Valparaiso, FL: Eglin AFB Destin Fort Walton B...
# 15841                     Wrangell, AK: Wrangell Airport
# 15897                  West Yellowstone, MT: Yellowstone
# 15919      Fayetteville, AR: Northwest Arkansas Regional
# 15991                       Yakutat, AK: Yakutat Airport
# 16218             Yuma, AZ: Yuma MCAS/Yuma International
#
#        origin_airport_id_ordered  dest_airport_id_ordered
# Code
# 10135                    207.000                  238.000
# 10136                    288.000                  229.000
# 10140                    121.000                  148.000
# 10141                     80.000                   50.000
# 10146                    178.000                  254.000
# 10154                    297.000                  140.000
# 10155                    217.000                  252.000
# 10157                    290.000                  290.000
# 10158                    283.000                  305.000
# 10165                     61.000                   29.000
# 10170                     12.000                    8.000
# 10185                    231.000                  147.000
# 10208                    197.000                  232.000
# 10245                     44.000                   11.000
# 10257                     73.000                  131.000
# 10279                     37.000                   73.000
# 10299                     13.000                   31.000
# 10333                    245.000                  282.000
# 10372                    289.000                  268.000
# 10397                     81.000                   94.000
# 10408                     95.000                   79.000
# 10423                    119.000                  188.000
# 10431                    264.000                  241.000
# 10434                    167.000                  154.000
# 10469                    209.000                  175.000
# 10529                     77.000                  192.000
# 10551                      1.000                    4.000
# 10561                     90.000                  189.000
# 10577                    247.000                  236.000
# 10581                    263.000                  286.000
# 10599                    125.000                  117.000
# 10620                     18.000                   54.000
# 10627                    143.000                  107.000
# 10631                    128.000                  134.000
# 10666                     50.000                   46.000
# 10685                    156.000                  169.000
# 10693                    152.000                  127.000
# 10713                    118.000                  152.000
# 10721                    182.000                  261.000
# 10728                    308.000                  300.000
# 10731                    218.000                  259.000
# 10732                    224.000                  295.000
# 10739                     94.000                   28.000
# 10747                     85.000                   70.000
# 10754                      7.000                    9.000
# 10779                     29.000                   30.000
# 10781                    285.000                  257.000
# 10785                    278.000                  258.000
# 10792                    115.000                  204.000
# 10800                    107.000                   82.000
# 10821                    116.000                   85.000
# 10849                     78.000                   74.000
# 10868                    236.000                  267.000
# 10874                    154.000                  124.000
# 10918                     15.000                   49.000
# 10926                     14.000                   10.000
# 10980                    268.000                  279.000
# 10990                    277.000                  288.000
# 10994                    174.000                  123.000
# 11003                    184.000                  170.000
# 11013                    235.000                   98.000
# 11042                    176.000                  239.000
# 11049                     57.000                   68.000
# 11057                    157.000                   81.000
# 11066                     84.000                  105.000
# 11076                    302.000                  283.000
# 11097                     92.000                   13.000
# 11109                    230.000                  280.000
# 11122                     32.000                   25.000
# 11140                     38.000                   52.000
# 11146                    279.000                  223.000
# 11150                    146.000                  215.000
# 11193                    173.000                  183.000
# 11203                    141.000                  106.000
# 11252                    100.000                   80.000
# 11259                    185.000                  128.000
# 11267                    153.000                  126.000
# 11278                    190.000                  233.000
# 11292                    163.000                  141.000
# 11298                    253.000                  260.000
# 11308                    258.000                  272.000
# 11336                     34.000                   12.000
# 11337                    239.000                  156.000
# 11413                    229.000                   72.000
# 11423                    135.000                  176.000
# 11433                    158.000                  157.000
# 11447                    145.000                  113.000
# 11471                    120.000                   99.000
# 11481                     41.000                   60.000
# 11503                    198.000                  284.000
# 11525                     31.000                   35.000
# 11537                     63.000                  158.000
# 11540                    101.000                  195.000
# 11577                    271.000                  211.000
# 11587                    189.000                  205.000
# 11603                    282.000                  235.000
# 11612                    248.000                  244.000
# 11617                    194.000                  256.000
# 11618                    275.000                  298.000
# 11624                     75.000                   65.000
# 11630                     21.000                   27.000
# 11637                    179.000                  172.000
# 11638                    214.000                  212.000
# 11641                    111.000                   96.000
# 11648                     45.000                   66.000
# 11695                     52.000                   26.000
# 11697                    252.000                  264.000
# 11721                     40.000                   58.000
# 11775                    181.000                  199.000
# 11778                    108.000                  227.000
# 11823                    204.000                  278.000
# 11865                     23.000                   19.000
# 11867                    305.000                  281.000
# 11884                     39.000                   78.000
# 11898                    127.000                  101.000
# 11905                    301.000                  307.000
# 11921                     16.000                   17.000
# 11953                    187.000                  182.000
# 11973                    139.000                  102.000
# 11977                     88.000                  247.000
# 11980                    296.000                  265.000
# 11982                     76.000                  177.000
# 11986                    132.000                  122.000
# 11995                    191.000                  222.000
# 11996                    172.000                  214.000
# 11997                     42.000                    2.000
# 12003                     49.000                   47.000
# 12007                    205.000                  285.000
# 12012                    216.000                  269.000
# 12016                     60.000                   69.000
# 12094                    183.000                  210.000
# 12129                    262.000                   77.000
# 12156                      6.000                   41.000
# 12173                      9.000                   55.000
# 12177                    134.000                   33.000
# 12191                    148.000                  137.000
# 12197                    287.000                  296.000
# 12206                     43.000                   64.000
# 12217                     48.000                   97.000
# 12250                    237.000                   71.000
# 12255                     89.000                   34.000
# 12264                    171.000                  110.000
# 12265                    165.000                  180.000
# 12266                    142.000                  171.000
# 12278                    105.000                  112.000
# 12280                     46.000                   44.000
# 12323                    166.000                  203.000
# 12335                    150.000                  108.000
# 12339                    114.000                  186.000
# 12343                    259.000                  149.000
# 12389                     98.000                   40.000
# 12391                     51.000                  174.000
# 12397                    255.000                  153.000
# 12402                      4.000                    6.000
# 12441                    267.000                  255.000
# 12448                    122.000                   89.000
# 12451                    103.000                  181.000
# 12478                    280.000                  293.000
# 12511                    206.000                  277.000
# 12519                    168.000                   53.000
# 12523                     28.000                   23.000
# 12758                     17.000                   22.000
# 12819                     35.000                   37.000
# 12884                    215.000                  187.000
# 12888                    104.000                   24.000
# 12889                    188.000                  173.000
# 12891                    254.000                  240.000
# 12892                    241.000                  271.000
# 12896                     71.000                  116.000
# 12898                    234.000                  292.000
# 12915                    131.000                   84.000
# 12945                    233.000                  234.000
# 12951                    164.000                   93.000
# 12953                    284.000                  304.000
# 12954                    212.000                  197.000
# 12982                     10.000                   16.000
# 12992                     64.000                   83.000
# 13029                    129.000                  100.000
# 13061                    192.000                  165.000
# 13076                     33.000                   75.000
# 13127                      3.000                    3.000
# 13158                     69.000                   76.000
# 13184                    203.000                  207.000
# 13198                     87.000                  120.000
# 13204                    208.000                  253.000
# 13230                    193.000                  230.000
# 13232                     91.000                   67.000
# 13241                    303.000                  302.000
# 13244                     99.000                  119.000
# 13256                    137.000                  155.000
# 13264                    242.000                  206.000
# 13277                    243.000                  249.000
# 13290                      0.000                    0.000
# 13296                     67.000                  125.000
# 13303                    281.000                  266.000
# 13342                    109.000                  136.000
# 13344                    272.000                  191.000
# 13360                     47.000                   57.000
# 13367                    180.000                  224.000
# 13377                    219.000                  225.000
# 13388                    300.000                  208.000
# 13422                    201.000                  231.000
# 13433                    162.000                   91.000
# 13459                    295.000                   92.000
# 13476                    213.000                  219.000
# 13485                     93.000                  130.000
# 13486                     59.000                   56.000
# 13487                    138.000                  168.000
# 13495                    110.000                  129.000
# 13502                    200.000                  121.000
# 13541                    307.000                  194.000
# 13577                    228.000                  213.000
# 13795                    240.000                  209.000
# 13796                    113.000                  138.000
# 13830                     22.000                   38.000
# 13851                     70.000                  160.000
# 13871                     82.000                  132.000
# 13873                     19.000                   14.000
# 13891                    136.000                  162.000
# 13930                    273.000                  270.000
# 13931                    186.000                  167.000
# 13933                    292.000                  245.000
# 13964                    309.000                  309.000
# 13970                      8.000                    7.000
# 14006                    261.000                  159.000
# 14025                    149.000                  161.000
# 14027                    266.000                  262.000
# 14057                     66.000                   86.000
# 14082                    225.000                  202.000
# 14098                     55.000                  103.000
# 14100                    195.000                  221.000
# 14107                    102.000                  114.000
# 14108                    244.000                  145.000
# 14109                    299.000                  308.000
# 14113                     36.000                   36.000
# 14122                     53.000                  151.000
# 14150                    249.000                  144.000
# 14193                     68.000                   87.000
# 14222                    304.000                   39.000
# 14252                    126.000                  185.000
# 14254                     86.000                  294.000
# 14256                     24.000                   61.000
# 14262                    265.000                  164.000
# 14307                     65.000                  166.000
# 14321                    256.000                  248.000
# 14457                    106.000                   90.000
# 14487                    257.000                  228.000
# 14489                    269.000                  220.000
# 14492                    161.000                  226.000
# 14520                    170.000                   63.000
# 14524                    246.000                  276.000
# 14543                     25.000                   43.000
# 14570                    151.000                  143.000
# 14574                    169.000                  146.000
# 14576                    140.000                  200.000
# 14588                    124.000                   59.000
# 14633                    159.000                  133.000
# 14635                    175.000                  198.000
# 14674                    306.000                  297.000
# 14679                     97.000                  111.000
# 14683                     83.000                  179.000
# 14685                    222.000                  178.000
# 14689                    286.000                  196.000
# 14696                    221.000                  274.000
# 14698                    238.000                  184.000
# 14709                      2.000                    5.000
# 14711                    250.000                  289.000
# 14730                    112.000                  118.000
# 14747                     72.000                   95.000
# 14771                    260.000                  303.000
# 14783                    177.000                  139.000
# 14794                     26.000                   51.000
# 14814                    223.000                  242.000
# 14828                     30.000                   32.000
# 14831                     96.000                   88.000
# 14842                    294.000                  246.000
# 14843                    155.000                  250.000
# 14869                     58.000                   62.000
# 14893                    117.000                  150.000
# 14905                    298.000                  301.000
# 14908                     74.000                   48.000
# 14952                    226.000                  218.000
# 14955                    274.000                    1.000
# 14960                    227.000                  275.000
# 14986                    232.000                  142.000
# 15016                    147.000                  135.000
# 15024                    160.000                  193.000
# 15027                    130.000                  217.000
# 15041                    251.000                  109.000
# 15070                    276.000                  306.000
# 15096                    220.000                  263.000
# 15249                     79.000                  115.000
# 15304                    144.000                  216.000
# 15323                    196.000                  190.000
# 15356                    270.000                  291.000
# 15370                     62.000                  163.000
# 15376                    123.000                  201.000
# 15380                    210.000                  251.000
# 15389                     54.000                   18.000
# 15401                    293.000                  299.000
# 15411                     11.000                   42.000
# 15412                    199.000                  273.000
# 15497                    291.000                  287.000
# 15607                    202.000                  243.000
# 15624                    133.000                  104.000
# 15841                     56.000                   45.000
# 15897                     27.000                   20.000
# 15919                    211.000                  237.000
# 15991                      5.000                   21.000
# 16218                     20.000                   15.000

# %%
file_path = 'sources/L_AIRPORT_ID.csv_'
df_airports = pd.read_csv(file_path, low_memory=False, index_col = 'Code')

df_origin_airport = test_set.groupby('ORIGIN_AIRPORT_ID').first()['origin_airport_id_ordered']
df_dest_airport = test_set.groupby('DEST_AIRPORT_ID').first()['dest_airport_id_ordered']
df_airports = df_airports.join(df_origin_airport).join(df_dest_airport).dropna()
df_airports.head(2)
df_airports.shape
df_airports.to_csv(ressources_folder+'df_airports.csv')
# Out:
#                                              Description  \
# Code
# 10135  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...
# 10136                      Abilene, TX: Abilene Regional
#
#        origin_airport_id_ordered  dest_airport_id_ordered
# Code
# 10135                    207.000                  238.000
# 10136                    288.000                  229.000
# (310, 3)

# %%
df_day = test_set.groupby('DAY').first()['day_ordered']
df_day.head(2)
df_day.shape
df_day.to_csv(ressources_folder+'df_days.csv')
# Out:
# DAY
# 1    103
# 2    149
# Name: day_ordered, dtype: int64
# (366,)

# %%
df_tail_num= test_set.groupby('TAIL_NUM').first()['tail_num_ordered']
df_tail_num.head(2)
df_tail_num.shape
df_tail_num.to_csv(ressources_folder+'df_tail_num.csv')
# Out:
# TAIL_NUM
# 7819A    1897
# 7820L    1501
# Name: tail_num_ordered, dtype: int64
# (5035,)

# %%
X_cols.to_csv(ressources_folder+'X_cols.csv', index=False)

# %% [markdown]
# ## Exporting Model

# %%
#s = pickle.dumps(ridge)
joblib.dump(ridge, ressources_folder+'ridge_model.joblib')
# Out:
# ['ridge_model.joblib']

# %%
ridge_model = joblib.load(ressources_folder+'ridge_model.joblib')

# %%
ridge_model.predict(X.iloc[[54224]])
# Out:
# array([17.62973918])
