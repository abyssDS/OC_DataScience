# %% [markdown]
# <h1> Cleaning the data</h1>
# We will :
# <br>    1 - Import the data
# <br>    2 - Filter out unrelated rows
# <br>    3 - Filter out unrelated columns
# <br>    4 - Treat anomalies
# <br>    5 - Export the clean data

# %% [markdown]
# <h2> 1 - Importing the data </h2>

# %% [markdown]
# <h3> 1.a - Import modules</3>

# %%
import pandas as pd
# Import `pyplot` and `numpy`
import matplotlib.pyplot  as plt
import matplotlib.pylab as plb
import numpy as np
import seaborn as sns
import datetime
import numexpr
import bottleneck
import feather


from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

pd.options.display.max_rows = 500
pd.options.display.max_columns = 200 
pd.set_option('display.float_format', lambda x: '%.6f' % x) #display numbers as decimals instead of scientific value

foodfacts_filepath = 'fr.openfoodfacts.org.products.csv'

# %% [markdown]
# <h3> 1.b - Import CSV</3>

# %%
#Import csv in a DataFrame (10 seconds)
df = pd.read_csv("fr.openfoodfacts.org.products.csv"
                       , header = 'infer'
                       , sep ="\t"
                        , low_memory=False)
print ('CSV Imported. Shape :')
df_save = df.copy() #keep a copy of original data
df.shape #(320772, 162)
# Out:
# CSV Imported. Shape :
# (320772, 162)

# %%
df = df_save.copy()

# %% [markdown]
# <h3> 1.c - Rename columns</3>

# %%
df.rename(columns=lambda x: x.replace('-', '_'), inplace=True)
df_stats = df.describe(include='all')
df_stats
# Out:
#                  code                                                url  \
# count          320749                                             320749
# unique         320749                                             320749
# top     0602652170508  http://world-fr.openfoodfacts.org/produit/0882...
# freq                1                                                  1
# mean              NaN                                                NaN
# std               NaN                                                NaN
# min               NaN                                                NaN
# 25%               NaN                                                NaN
# 50%               NaN                                                NaN
# 75%               NaN                                                NaN
# max               NaN                                                NaN
#
#                 creator   created_t      created_datetime last_modified_t  \
# count            320770      320769                320763          320772
# unique             3535      189567                189568          180495
# top     usda-ndb-import  1489077120  2017-03-09T16:32:00Z      1439141742
# freq             169868          20                    20              33
# mean                NaN         NaN                   NaN             NaN
# std                 NaN         NaN                   NaN             NaN
# min                 NaN         NaN                   NaN             NaN
# 25%                 NaN         NaN                   NaN             NaN
# 50%                 NaN         NaN                   NaN             NaN
# 75%                 NaN         NaN                   NaN             NaN
# max                 NaN         NaN                   NaN             NaN
#
#        last_modified_datetime product_name  \
# count                  320772       303010
# unique                 180495       221347
# top      2015-08-09T17:35:42Z    Ice Cream
# freq                       33          410
# mean                      NaN          NaN
# std                       NaN          NaN
# min                       NaN          NaN
# 25%                       NaN          NaN
# 50%                       NaN          NaN
# 75%                       NaN          NaN
# max                       NaN          NaN
#
#                                              generic_name quantity packaging  \
# count                                               52795   104819     78960
# unique                                              38584    13826     14547
# top     Pâtes alimentaires au blé dur de qualité supér...    500 g    Carton
# freq                                                  201     4669      2153
# mean                                                  NaN      NaN       NaN
# std                                                   NaN      NaN       NaN
# min                                                   NaN      NaN       NaN
# 25%                                                   NaN      NaN       NaN
# 50%                                                   NaN      NaN       NaN
# 75%                                                   NaN      NaN       NaN
# max                                                   NaN      NaN       NaN
#
#           packaging_tags     brands brands_tags  \
# count              78961     292360      292352
# unique             12064      58784       50253
# top     sachet,plastique  Carrefour   carrefour
# freq                3959       2978        3149
# mean                 NaN        NaN         NaN
# std                  NaN        NaN         NaN
# min                  NaN        NaN         NaN
# 25%                  NaN        NaN         NaN
# 50%                  NaN        NaN         NaN
# 75%                  NaN        NaN         NaN
# max                  NaN        NaN         NaN
#
#                                         categories  \
# count                                        84410
# unique                                       36982
# top     Snacks sucrés,Biscuits et gâteaux,Biscuits
# freq                                           301
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#                                           categories_tags  \
# count                                               84389
# unique                                              21142
# top     en:sugary-snacks,en:biscuits-and-cakes,en:bisc...
# freq                                                  802
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                      categories_fr origins origins_tags  \
# count                                        84411   22190        22153
# unique                                       21152    4840         4372
# top     Snacks sucrés,Biscuits et gâteaux,Biscuits  France       france
# freq                                           802    5171         5303
# mean                                           NaN     NaN          NaN
# std                                            NaN     NaN          NaN
# min                                            NaN     NaN          NaN
# 25%                                            NaN     NaN          NaN
# 50%                                            NaN     NaN          NaN
# 75%                                            NaN     NaN          NaN
# max                                            NaN     NaN          NaN
#
#        manufacturing_places manufacturing_places_tags  \
# count                 36501                     36495
# unique                 7308                      6736
# top                  France                    france
# freq                   9371                      9451
# mean                    NaN                       NaN
# std                     NaN                       NaN
# min                     NaN                       NaN
# 25%                     NaN                       NaN
# 50%                     NaN                       NaN
# 75%                     NaN                       NaN
# max                     NaN                       NaN
#
#                                                    labels  \
# count                                               46559
# unique                                              18114
# top     Organic, EU Organic, fr:AB Agriculture Biologique
# freq                                                 3223
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                               labels_tags  \
# count                                               46644
# unique                                              13653
# top     en:organic,en:eu-organic,fr:ab-agriculture-bio...
# freq                                                 5311
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                          labels_fr   emb_codes emb_codes_tags  \
# count                                        46666       29306          29303
# unique                                       13655        8462           8158
# top     Bio,Bio européen,AB Agriculture Biologique  EMB 56251E     emb-56251e
# freq                                          5311         218            218
# mean                                           NaN         NaN            NaN
# std                                            NaN         NaN            NaN
# min                                            NaN         NaN            NaN
# 25%                                            NaN         NaN            NaN
# 50%                                            NaN         NaN            NaN
# 75%                                            NaN         NaN            NaN
# max                                            NaN         NaN            NaN
#
#        first_packaging_code_geo cities            cities_tags purchase_places  \
# count                     18803     23                  20320           58193
# unique                     1602      3                   2572            5120
# top         47.633333,-2.666667      c  theix-morbihan-france          France
# freq                        279      9                    270           11762
# mean                        NaN    NaN                    NaN             NaN
# std                         NaN    NaN                    NaN             NaN
# min                         NaN    NaN                    NaN             NaN
# 25%                         NaN    NaN                    NaN             NaN
# 50%                         NaN    NaN                    NaN             NaN
# 75%                         NaN    NaN                    NaN             NaN
# max                         NaN    NaN                    NaN             NaN
#
#            stores countries    countries_tags countries_fr  \
# count       51722    320492            320492       320492
# unique       3259      1434               725          722
# top     Carrefour        US  en:united-states   États-Unis
# freq         6465    169928            172998       172998
# mean          NaN       NaN               NaN          NaN
# std           NaN       NaN               NaN          NaN
# min           NaN       NaN               NaN          NaN
# 25%           NaN       NaN               NaN          NaN
# 50%           NaN       NaN               NaN          NaN
# 75%           NaN       NaN               NaN          NaN
# max           NaN       NaN               NaN          NaN
#
#                          ingredients_text allergens  \
# count                              248962     28344
# unique                             205520     12939
# top     Carbonated water, natural flavor.       blé
# freq                                  222      1279
# mean                                  NaN       NaN
# std                                   NaN       NaN
# min                                   NaN       NaN
# 25%                                   NaN       NaN
# 50%                                   NaN       NaN
# 75%                                   NaN       NaN
# max                                   NaN       NaN
#
#                                              allergens_fr          traces  \
# count                                                  19           24353
# unique                                                 19            8378
# top     http://fr.openfoodfacts.org/images/products/30...  Fruits à coque
# freq                                                    1            1240
# mean                                                  NaN             NaN
# std                                                   NaN             NaN
# min                                                   NaN             NaN
# 25%                                                   NaN             NaN
# 50%                                                   NaN             NaN
# 75%                                                   NaN             NaN
# max                                                   NaN             NaN
#
#        traces_tags       traces_fr      serving_size  no_nutriments  \
# count        24329           24352            211331       0.000000
# unique        3578            3584             25423            nan
# top        en:nuts  Fruits à coque  240 ml (8 fl oz)            nan
# freq          2051            2051              5496            nan
# mean           NaN             NaN               NaN            nan
# std            NaN             NaN               NaN            nan
# min            NaN             NaN               NaN            nan
# 25%            NaN             NaN               NaN            nan
# 50%            NaN             NaN               NaN            nan
# 75%            NaN             NaN               NaN            nan
# max            NaN             NaN               NaN            nan
#
#          additives_n                                          additives  \
# count  248939.000000                                             248905
# unique           nan                                             196069
# top              nan   [ extra-virgin-olive-oil -> en:extra-virgin-o...
# freq             nan                                                397
# mean        1.936024                                                NaN
# std         2.502019                                                NaN
# min         0.000000                                                NaN
# 25%         0.000000                                                NaN
# 50%         1.000000                                                NaN
# 75%         3.000000                                                NaN
# max        31.000000                                                NaN
#
#        additives_tags       additives_fr  ingredients_from_palm_oil_n  \
# count          154680             154680                248939.000000
# unique          41537              41537                          nan
# top           en:e322  E322 - Lécithines                          nan
# freq             8264               8264                          nan
# mean              NaN                NaN                     0.019659
# std               NaN                NaN                     0.140524
# min               NaN                NaN                     0.000000
# 25%               NaN                NaN                     0.000000
# 50%               NaN                NaN                     0.000000
# 75%               NaN                NaN                     0.000000
# max               NaN                NaN                     2.000000
#
#         ingredients_from_palm_oil ingredients_from_palm_oil_tags  \
# count                    0.000000                           4835
# unique                        nan                             14
# top                           nan                 huile-de-palme
# freq                          nan                           4586
# mean                          nan                            NaN
# std                           nan                            NaN
# min                           nan                            NaN
# 25%                           nan                            NaN
# 50%                           nan                            NaN
# 75%                           nan                            NaN
# max                           nan                            NaN
#
#         ingredients_that_may_be_from_palm_oil_n  \
# count                             248939.000000
# unique                                      nan
# top                                         nan
# freq                                        nan
# mean                                   0.055246
# std                                    0.269207
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                    0.000000
# max                                    6.000000
#
#         ingredients_that_may_be_from_palm_oil  \
# count                                0.000000
# unique                                    nan
# top                                       nan
# freq                                      nan
# mean                                      nan
# std                                       nan
# min                                       nan
# 25%                                       nan
# 50%                                       nan
# 75%                                       nan
# max                                       nan
#
#        ingredients_that_may_be_from_palm_oil_tags  nutrition_grade_uk  \
# count                                       11696            0.000000
# unique                                        160                 nan
# top                           e160a-beta-carotene                 nan
# freq                                         2843                 nan
# mean                                          NaN                 nan
# std                                           NaN                 nan
# min                                           NaN                 nan
# 25%                                           NaN                 nan
# 50%                                           NaN                 nan
# 75%                                           NaN                 nan
# max                                           NaN                 nan
#
#        nutrition_grade_fr pnns_groups_1 pnns_groups_2  \
# count              221210         91513         94491
# unique                  5            14            42
# top                     d       unknown       unknown
# freq                62763         22624         22624
# mean                  NaN           NaN           NaN
# std                   NaN           NaN           NaN
# min                   NaN           NaN           NaN
# 25%                   NaN           NaN           NaN
# 50%                   NaN           NaN           NaN
# 75%                   NaN           NaN           NaN
# max                   NaN           NaN           NaN
#
#                                                    states  \
# count                                              320726
# unique                                               1021
# top     en:to-be-completed, en:nutrition-facts-complet...
# freq                                               168905
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                               states_tags  \
# count                                              320726
# unique                                               1021
# top     en:to-be-completed,en:nutrition-facts-complete...
# freq                                               168905
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                 states_fr main_category  \
# count                                              320726         84366
# unique                                               1021          3543
# top     A compléter,Informations nutritionnelles compl...  en:beverages
# freq                                               168905          6054
# mean                                                  NaN           NaN
# std                                                   NaN           NaN
# min                                                   NaN           NaN
# 25%                                                   NaN           NaN
# 50%                                                   NaN           NaN
# 75%                                                   NaN           NaN
# max                                                   NaN           NaN
#
#        main_category_fr                                          image_url  \
# count             84366                                              75836
# unique             3543                                              75836
# top            Boissons  http://fr.openfoodfacts.org/images/products/35...
# freq               6054                                                  1
# mean                NaN                                                NaN
# std                 NaN                                                NaN
# min                 NaN                                                NaN
# 25%                 NaN                                                NaN
# 50%                 NaN                                                NaN
# 75%                 NaN                                                NaN
# max                 NaN                                                NaN
#
#                                           image_small_url    energy_100g  \
# count                                               75836  261113.000000
# unique                                              75836            nan
# top     http://fr.openfoodfacts.org/images/products/32...            nan
# freq                                                    1            nan
# mean                                                  NaN    1141.914605
# std                                                   NaN    6447.154093
# min                                                   NaN       0.000000
# 25%                                                   NaN     377.000000
# 50%                                                   NaN    1100.000000
# 75%                                                   NaN    1674.000000
# max                                                   NaN 3251373.000000
#
#         energy_from_fat_100g      fat_100g  saturated_fat_100g  \
# count             857.000000 243891.000000       229554.000000
# unique                   nan           nan                 nan
# top                      nan           nan                 nan
# freq                     nan           nan                 nan
# mean              585.501214     12.730379            5.129932
# std               712.809943     17.578747            8.014238
# min                 0.000000      0.000000            0.000000
# 25%                49.400000      0.000000            0.000000
# 50%               300.000000      5.000000            1.790000
# 75%               898.000000     20.000000            7.140000
# max              3830.000000    714.290000          550.000000
#
#         butyric_acid_100g  caproic_acid_100g  caprylic_acid_100g  \
# count            0.000000           0.000000            1.000000
# unique                nan                nan                 nan
# top                   nan                nan                 nan
# freq                  nan                nan                 nan
# mean                  nan                nan            7.400000
# std                   nan                nan                 nan
# min                   nan                nan            7.400000
# 25%                   nan                nan            7.400000
# 50%                   nan                nan            7.400000
# 75%                   nan                nan            7.400000
# max                   nan                nan            7.400000
#
#         capric_acid_100g  lauric_acid_100g  myristic_acid_100g  \
# count           2.000000          4.000000            1.000000
# unique               nan               nan                 nan
# top                  nan               nan                 nan
# freq                 nan               nan                 nan
# mean            6.040000         36.136182           18.900000
# std             0.226274         24.101433                 nan
# min             5.880000          0.044730           18.900000
# 25%             5.960000         34.661183           18.900000
# 50%             6.040000         47.600000           18.900000
# 75%             6.120000         49.075000           18.900000
# max             6.200000         49.300000           18.900000
#
#         palmitic_acid_100g  stearic_acid_100g  arachidic_acid_100g  \
# count             1.000000           1.000000            24.000000
# unique                 nan                nan                  nan
# top                    nan                nan                  nan
# freq                   nan                nan                  nan
# mean              8.100000           3.000000            10.752667
# std                    nan                nan             4.019993
# min               8.100000           3.000000             0.064000
# 25%               8.100000           3.000000             7.275000
# 50%               8.100000           3.000000            12.850000
# 75%               8.100000           3.000000            13.375000
# max               8.100000           3.000000            15.400000
#
#         behenic_acid_100g  lignoceric_acid_100g  cerotic_acid_100g  \
# count           23.000000              0.000000           0.000000
# unique                nan                   nan                nan
# top                   nan                   nan                nan
# freq                  nan                   nan                nan
# mean            10.673913                   nan                nan
# std              3.379647                   nan                nan
# min              5.200000                   nan                nan
# 25%              7.100000                   nan                nan
# 50%             12.600000                   nan                nan
# 75%             13.050000                   nan                nan
# max             14.600000                   nan                nan
#
#         montanic_acid_100g  melissic_acid_100g  monounsaturated_fat_100g  \
# count             1.000000            0.000000              22823.000000
# unique                 nan                 nan                       nan
# top                    nan                 nan                       nan
# freq                   nan                 nan                       nan
# mean             61.000000                 nan                 10.425055
# std                    nan                 nan                 17.076167
# min              61.000000                 nan                  0.000000
# 25%              61.000000                 nan                  0.000000
# 50%              61.000000                 nan                  4.000000
# 75%              61.000000                 nan                 10.710000
# max              61.000000                 nan                557.140000
#
#         polyunsaturated_fat_100g  omega_3_fat_100g  alpha_linolenic_acid_100g  \
# count               22859.000000        841.000000                 186.000000
# unique                       nan               nan                        nan
# top                          nan               nan                        nan
# freq                         nan               nan                        nan
# mean                    6.312493          3.182103                   2.250285
# std                    10.832591          5.607988                   7.971418
# min                     0.000000          0.000000                   0.000000
# 25%                     0.000000          0.600000                   0.068750
# 50%                     2.220000          1.800000                   0.117500
# 75%                     7.140000          3.200000                   0.604000
# max                    98.000000         60.000000                  75.000000
#
#         eicosapentaenoic_acid_100g  docosahexaenoic_acid_100g  \
# count                    38.000000                  78.000000
# unique                         nan                        nan
# top                            nan                        nan
# freq                           nan                        nan
# mean                      3.186553                   1.635462
# std                      13.927752                   1.978192
# min                       0.050000                   0.041000
# 25%                       0.200000                   0.171500
# 50%                       0.500000                   0.800000
# 75%                       0.715750                   3.300000
# max                      85.000000                  12.000000
#
#         omega_6_fat_100g  linoleic_acid_100g  arachidonic_acid_100g  \
# count         188.000000          149.000000               8.000000
# unique               nan                 nan                    nan
# top                  nan                 nan                    nan
# freq                 nan                 nan                    nan
# mean           16.229144            3.823819               0.057000
# std            17.512632            6.494183               0.025534
# min             0.050000            0.090000               0.007000
# 25%             1.850000            0.437000               0.046250
# 50%            10.050000            0.647000               0.061000
# 75%            23.000000            3.600000               0.068500
# max            71.000000           25.000000               0.090000
#
#         gamma_linolenic_acid_100g  dihomo_gamma_linolenic_acid_100g  \
# count                   24.000000                         23.000000
# unique                        nan                               nan
# top                           nan                               nan
# freq                          nan                               nan
# mean                     0.153842                          0.061567
# std                      0.029160                          0.010597
# min                      0.095000                          0.043307
# 25%                      0.130000                          0.051181
# 50%                      0.155000                          0.062992
# 75%                      0.170000                          0.066929
# max                      0.203200                          0.080000
#
#         omega_9_fat_100g  oleic_acid_100g  elaidic_acid_100g  \
# count          21.000000        13.000000           0.000000
# unique               nan              nan                nan
# top                  nan              nan                nan
# freq                 nan              nan                nan
# mean           40.192857        25.123077                nan
# std            25.175674        26.010496                nan
# min             1.000000         1.080000                nan
# 25%            27.000000         6.900000                nan
# 50%            31.000000        11.000000                nan
# 75%            68.000000        40.500000                nan
# max            75.000000        76.000000                nan
#
#         gondoic_acid_100g  mead_acid_100g  erucic_acid_100g  \
# count           14.000000        0.000000          0.000000
# unique                nan             nan               nan
# top                   nan             nan               nan
# freq                  nan             nan               nan
# mean             0.000001             nan               nan
# std              0.000000             nan               nan
# min              0.000001             nan               nan
# 25%              0.000001             nan               nan
# 50%              0.000001             nan               nan
# 75%              0.000001             nan               nan
# max              0.000003             nan               nan
#
#         nervonic_acid_100g  trans_fat_100g  cholesterol_100g  \
# count             0.000000   143298.000000     144090.000000
# unique                 nan             nan               nan
# top                    nan             nan               nan
# freq                   nan             nan               nan
# mean                   nan        0.073476          0.020071
# std                    nan        1.540223          0.358062
# min                    nan       -3.570000          0.000000
# 25%                    nan        0.000000          0.000000
# 50%                    nan        0.000000          0.000000
# 75%                    nan        0.000000          0.020000
# max                    nan      369.000000         95.238000
#
#         carbohydrates_100g   sugars_100g  sucrose_100g  glucose_100g  \
# count        243588.000000 244971.000000     72.000000     26.000000
# unique                 nan           nan           nan           nan
# top                    nan           nan           nan           nan
# freq                   nan           nan           nan           nan
# mean             32.073981     16.003484     11.841667      2.878846
# std              29.731719     22.327284     13.993859      6.290341
# min               0.000000    -17.860000      0.000000      0.000000
# 25%               6.000000      1.300000      2.100000      0.200000
# 50%              20.600000      5.710000      8.100000      0.250000
# 75%              58.330000     24.000000     16.150000      1.400000
# max            2916.670000   3520.000000     92.800000     23.200000
#
#         fructose_100g  lactose_100g  maltose_100g  maltodextrins_100g  \
# count       38.000000    262.000000      4.000000           11.000000
# unique            nan           nan           nan                 nan
# top               nan           nan           nan                 nan
# freq              nan           nan           nan                 nan
# mean        25.897368      6.354084     24.325000           12.163636
# std         30.015451     14.386132     17.793515            8.372129
# min          0.000000      0.000000      0.100000            1.500000
# 25%          0.950000      0.000000     16.525000            5.400000
# 50%         13.000000      0.100000     29.000000           13.500000
# 75%         52.075000      4.175000     36.800000           16.950000
# max        101.000000     74.500000     39.200000           27.500000
#
#         starch_100g  polyols_100g    fiber_100g  proteins_100g  casein_100g  \
# count    266.000000    414.000000 200886.000000  259922.000000    27.000000
# unique          nan           nan           nan            nan          nan
# top             nan           nan           nan            nan          nan
# freq            nan           nan           nan            nan          nan
# mean      31.925000     49.790389      2.862111       7.075940     4.658148
# std       24.704434     33.212338     12.867578       8.409054     2.976340
# min        0.000000      0.000000     -6.700000    -800.000000     0.920000
# 25%        4.500000     18.350000      0.000000       0.700000     2.150000
# 50%       35.900000     59.750000      1.500000       4.760000     4.200000
# 75%       50.000000     70.000000      3.600000      10.000000     7.100000
# max       87.800000    100.000000   5380.000000     430.000000    10.700000
#
#         serum_proteins_100g  nucleotides_100g     salt_100g   sodium_100g  \
# count             16.000000          9.000000 255510.000000 255463.000000
# unique                  nan               nan           nan           nan
# top                     nan               nan           nan           nan
# freq                    nan               nan           nan           nan
# mean               2.506250          0.021678      2.028624      0.798815
# std                2.186769          0.003072    128.269454     50.504428
# min                0.300000          0.015500      0.000000      0.000000
# 25%                0.300000          0.021600      0.063500      0.025000
# 50%                1.950000          0.022000      0.581660      0.229000
# 75%                4.750000          0.024000      1.374140      0.541000
# max                5.800000          0.025000  64312.800000  25320.000000
#
#         alcohol_100g  vitamin_a_100g  beta_carotene_100g  vitamin_d_100g  \
# count    4133.000000   137554.000000           34.000000     7057.000000
# unique           nan             nan                 nan             nan
# top              nan             nan                 nan             nan
# freq             nan             nan                 nan             nan
# mean        7.838105        0.000397            0.518715        0.000008
# std        10.959671        0.073278            2.561144        0.000360
# min         0.000000       -0.000340            0.000000        0.000000
# 25%         0.000000        0.000000            0.001225        0.000001
# 50%         5.000000        0.000000            0.005261        0.000001
# 75%        12.000000        0.000107            0.140000        0.000003
# max        97.900000       26.700000           15.000000        0.030000
#
#         vitamin_e_100g  vitamin_k_100g  vitamin_c_100g  vitamin_b1_100g  \
# count      1340.000000      918.000000   140867.000000     11154.000000
# unique             nan             nan             nan              nan
# top                nan             nan             nan              nan
# freq               nan             nan             nan              nan
# mean          0.056705        0.034219        0.023367         0.325574
# std           0.694039        1.031398        2.236451         2.474306
# min           0.000000        0.000000       -0.002100         0.000000
# 25%           0.001800        0.000006        0.000000         0.004000
# 50%           0.005200        0.000025        0.000000         0.012000
# 75%           0.012000        0.000100        0.003700         0.402000
# max          15.100000       31.250000      716.981100       161.000000
#
#         vitamin_b2_100g  vitamin_pp_100g  vitamin_b6_100g  vitamin_b9_100g  \
# count      10815.000000     11729.000000      6784.000000      5240.000000
# unique              nan              nan              nan              nan
# top                 nan              nan              nan              nan
# freq                nan              nan              nan              nan
# mean           0.259007         0.020303         0.023378         0.006898
# std            1.277026         0.339262         1.206822         0.335163
# min            0.000000         0.000000         0.000000         0.000000
# 25%            0.002720         0.003077         0.000255         0.000030
# 50%            0.014167         0.005357         0.000700         0.000052
# 75%            0.300000         0.009091         0.001500         0.000070
# max           42.500000        21.428571        92.600000        23.076923
#
#         folates_100g  vitamin_b12_100g  biotin_100g  pantothenic_acid_100g  \
# count    3042.000000       5300.000000   330.000000            2483.000000
# unique           nan               nan          nan                    nan
# top              nan               nan          nan                    nan
# freq             nan               nan          nan                    nan
# mean        0.205856          0.000089     0.121290               0.072138
# std         5.132250          0.005515     0.737912               1.475120
# min         0.000000          0.000000    -2.000000              -2.000000
# 25%         0.000042          0.000001     0.000006               0.000417
# 50%         0.000114          0.000002     0.000014               0.001639
# 75%         0.000214          0.000005     0.000041               0.004167
# max       178.571429          0.400000     6.000000              60.000000
#
#         silica_100g  bicarbonate_100g  potassium_100g  chloride_100g  \
# count     38.000000         81.000000    24748.000000     158.000000
# unique          nan               nan             nan            nan
# top             nan               nan             nan            nan
# freq            nan               nan             nan            nan
# mean       0.013123          0.119052        0.424635       0.092638
# std        0.040660          0.189486       12.528768       0.149725
# min        0.000008          0.000006        0.000000       0.000002
# 25%        0.001500          0.017320        0.107000       0.001367
# 50%        0.003185          0.036000        0.180000       0.014600
# 75%        0.007100          0.143000        0.341000       0.071750
# max        0.250000          1.250000     1870.370000       0.589000
#
#         calcium_100g  phosphorus_100g     iron_100g  magnesium_100g  \
# count  141050.000000      5845.000000 140462.000000     6253.000000
# unique           nan              nan           nan             nan
# top              nan              nan           nan             nan
# freq             nan              nan           nan             nan
# mean        0.125163         0.617282      0.003652        0.534143
# std         3.318263        12.058090      0.214408       13.498653
# min         0.000000         0.000000     -0.000260        0.000000
# 25%         0.000000         0.094000      0.000000        0.021000
# 50%         0.035000         0.206000      0.001010        0.075000
# 75%         0.106000         0.357000      0.002400        0.141000
# max       694.737000       559.459000     50.000000      657.143000
#
#          zinc_100g  copper_100g  manganese_100g  fluoride_100g  selenium_100g  \
# count  3929.000000  2106.000000     1620.000000      79.000000    1168.000000
# unique         nan          nan             nan            nan            nan
# top            nan          nan             nan            nan            nan
# freq           nan          nan             nan            nan            nan
# mean      0.007950     0.025794        0.003014       0.012161       0.003126
# std       0.080953     0.914247        0.028036       0.067952       0.104503
# min       0.000000    -6.896552        0.000000       0.000000      -0.000002
# 25%       0.001150     0.000177        0.000000       0.000017       0.000005
# 50%       0.003700     0.000417        0.001000       0.000060       0.000022
# 75%       0.007500     0.001000        0.002000       0.000450       0.000061
# max       4.000000    37.600000        0.700000       0.560000       3.571429
#
#         chromium_100g  molybdenum_100g  iodine_100g  caffeine_100g  \
# count       20.000000        11.000000   259.000000      78.000000
# unique            nan              nan          nan            nan
# top               nan              nan          nan            nan
# freq              nan              nan          nan            nan
# mean         0.001690         0.000401     0.000427       1.594563
# std          0.006697         0.001118     0.001285       6.475588
# min          0.000007         0.000005     0.000000       0.000000
# 25%          0.000011         0.000020     0.000015       0.015500
# 50%          0.000024         0.000039     0.000034       0.021000
# 75%          0.000068         0.000075     0.000103       0.043000
# max          0.030000         0.003760     0.014700      42.280000
#
#         taurine_100g   ph_100g  fruits_vegetables_nuts_100g  \
# count      29.000000 49.000000                  3036.000000
# unique           nan       nan                          nan
# top              nan       nan                          nan
# freq             nan       nan                          nan
# mean        0.145762  6.425698                    31.458587
# std         0.172312  2.047841                    31.967918
# min         0.001800  0.000000                     0.000000
# 25%         0.035000  6.300000                     0.000000
# 50%         0.039000  7.200000                    23.000000
# 75%         0.400000  7.400000                    51.000000
# max         0.423000  8.400000                   100.000000
#
#         collagen_meat_protein_ratio_100g  cocoa_100g  chlorophyl_100g  \
# count                         165.000000  948.000000         0.000000
# unique                               nan         nan              nan
# top                                  nan         nan              nan
# freq                                 nan         nan              nan
# mean                           15.412121   49.547785              nan
# std                             3.753028   18.757932              nan
# min                             8.000000    6.000000              nan
# 25%                            12.000000   32.000000              nan
# 50%                            15.000000   50.000000              nan
# 75%                            15.000000   64.250000              nan
# max                            25.000000  100.000000              nan
#
#         carbon_footprint_100g  nutrition_score_fr_100g  \
# count              268.000000            221210.000000
# unique                    nan                      nan
# top                       nan                      nan
# freq                      nan                      nan
# mean               341.700764                 9.165535
# std                425.211439                 9.055903
# min                  0.000000               -15.000000
# 25%                 98.750000                 1.000000
# 50%                195.750000                10.000000
# 75%                383.200000                16.000000
# max               2842.000000                40.000000
#
#         nutrition_score_uk_100g  glycemic_index_100g  water_hardness_100g
# count             221210.000000             0.000000             0.000000
# unique                      nan                  nan                  nan
# top                         nan                  nan                  nan
# freq                        nan                  nan                  nan
# mean                   9.058049                  nan                  nan
# std                    9.183589                  nan                  nan
# min                  -15.000000                  nan                  nan
# 25%                    1.000000                  nan                  nan
# 50%                    9.000000                  nan                  nan
# 75%                   16.000000                  nan                  nan
# max                   40.000000                  nan                  nan

# %% [markdown]
# <h2> 2 - Filter out unrelated rows </h2>

# %% [markdown]
# <h3> 2.a - Drop rows without enough data</3>

# %% [markdown]
# Dropping rows with no product name

# %%
#Removing rows with no product_name (filled at 95%)
#Around 18K products
list_to_drop = df[df['product_name'].isna()]
list_to_drop.sample()
print(list_to_drop.count().max() , 'products dropped')
df.drop(list_to_drop.index, inplace=True)
# Out:
#                  code                                                url  \
# 302218  8002270716522  http://world-fr.openfoodfacts.org/produit/8002...
#
#        creator   created_t      created_datetime last_modified_t  \
# 302218    kyzh  1438259301  2015-07-30T12:28:21Z      1438259343
#
#        last_modified_datetime product_name generic_name quantity packaging  \
# 302218   2015-07-30T12:29:03Z          NaN          NaN      NaN       NaN
#
#        packaging_tags brands brands_tags categories categories_tags  \
# 302218            NaN    NaN         NaN        NaN             NaN
#
#        categories_fr origins origins_tags manufacturing_places  \
# 302218           NaN     NaN          NaN                  NaN
#
#        manufacturing_places_tags labels labels_tags labels_fr emb_codes  \
# 302218                       NaN    NaN         NaN       NaN       NaN
#
#        emb_codes_tags first_packaging_code_geo cities cities_tags  \
# 302218            NaN                      NaN    NaN         NaN
#
#        purchase_places stores countries     countries_tags countries_fr  \
# 302218             NaN    NaN     en:GB  en:united-kingdom  Royaume-Uni
#
#        ingredients_text allergens allergens_fr traces traces_tags traces_fr  \
# 302218              NaN       NaN          NaN    NaN         NaN       NaN
#
#        serving_size  no_nutriments  additives_n additives additives_tags  \
# 302218          NaN            nan          nan       NaN            NaN
#
#        additives_fr  ingredients_from_palm_oil_n  ingredients_from_palm_oil  \
# 302218          NaN                          nan                        nan
#
#        ingredients_from_palm_oil_tags  \
# 302218                            NaN
#
#         ingredients_that_may_be_from_palm_oil_n  \
# 302218                                      nan
#
#         ingredients_that_may_be_from_palm_oil  \
# 302218                                    nan
#
#        ingredients_that_may_be_from_palm_oil_tags  nutrition_grade_uk  \
# 302218                                        NaN                 nan
#
#        nutrition_grade_fr pnns_groups_1 pnns_groups_2  \
# 302218                NaN           NaN           NaN
#
#                                                    states  \
# 302218  en:to-be-completed, en:nutrition-facts-to-be-c...
#
#                                               states_tags  \
# 302218  en:to-be-completed,en:nutrition-facts-to-be-co...
#
#                                                 states_fr main_category  \
# 302218  A compléter,Informations nutritionnelles à com...           NaN
#
#        main_category_fr                                          image_url  \
# 302218              NaN  http://fr.openfoodfacts.org/images/products/80...
#
#                                           image_small_url  energy_100g  \
# 302218  http://fr.openfoodfacts.org/images/products/80...          nan
#
#         energy_from_fat_100g  fat_100g  saturated_fat_100g  butyric_acid_100g  \
# 302218                   nan       nan                 nan                nan
#
#         caproic_acid_100g  caprylic_acid_100g  capric_acid_100g  \
# 302218                nan                 nan               nan
#
#         lauric_acid_100g  myristic_acid_100g  palmitic_acid_100g  \
# 302218               nan                 nan                 nan
#
#         stearic_acid_100g  arachidic_acid_100g  behenic_acid_100g  \
# 302218                nan                  nan                nan
#
#         lignoceric_acid_100g  cerotic_acid_100g  montanic_acid_100g  \
# 302218                   nan                nan                 nan
#
#         melissic_acid_100g  monounsaturated_fat_100g  \
# 302218                 nan                       nan
#
#         polyunsaturated_fat_100g  omega_3_fat_100g  alpha_linolenic_acid_100g  \
# 302218                       nan               nan                        nan
#
#         eicosapentaenoic_acid_100g  docosahexaenoic_acid_100g  \
# 302218                         nan                        nan
#
#         omega_6_fat_100g  linoleic_acid_100g  arachidonic_acid_100g  \
# 302218               nan                 nan                    nan
#
#         gamma_linolenic_acid_100g  dihomo_gamma_linolenic_acid_100g  \
# 302218                        nan                               nan
#
#         omega_9_fat_100g  oleic_acid_100g  elaidic_acid_100g  \
# 302218               nan              nan                nan
#
#         gondoic_acid_100g  mead_acid_100g  erucic_acid_100g  \
# 302218                nan             nan               nan
#
#         nervonic_acid_100g  trans_fat_100g  cholesterol_100g  \
# 302218                 nan             nan               nan
#
#         carbohydrates_100g  sugars_100g  sucrose_100g  glucose_100g  \
# 302218                 nan          nan           nan           nan
#
#         fructose_100g  lactose_100g  maltose_100g  maltodextrins_100g  \
# 302218            nan           nan           nan                 nan
#
#         starch_100g  polyols_100g  fiber_100g  proteins_100g  casein_100g  \
# 302218          nan           nan         nan            nan          nan
#
#         serum_proteins_100g  nucleotides_100g  salt_100g  sodium_100g  \
# 302218                  nan               nan        nan          nan
#
#         alcohol_100g  vitamin_a_100g  beta_carotene_100g  vitamin_d_100g  \
# 302218           nan             nan                 nan             nan
#
#         vitamin_e_100g  vitamin_k_100g  vitamin_c_100g  vitamin_b1_100g  \
# 302218             nan             nan             nan              nan
#
#         vitamin_b2_100g  vitamin_pp_100g  vitamin_b6_100g  vitamin_b9_100g  \
# 302218              nan              nan              nan              nan
#
#         folates_100g  vitamin_b12_100g  biotin_100g  pantothenic_acid_100g  \
# 302218           nan               nan          nan                    nan
#
#         silica_100g  bicarbonate_100g  potassium_100g  chloride_100g  \
# 302218          nan               nan             nan            nan
#
#         calcium_100g  phosphorus_100g  iron_100g  magnesium_100g  zinc_100g  \
# 302218           nan              nan        nan             nan        nan
#
#         copper_100g  manganese_100g  fluoride_100g  selenium_100g  \
# 302218          nan             nan            nan            nan
#
#         chromium_100g  molybdenum_100g  iodine_100g  caffeine_100g  \
# 302218            nan              nan          nan            nan
#
#         taurine_100g  ph_100g  fruits_vegetables_nuts_100g  \
# 302218           nan      nan                          nan
#
#         collagen_meat_protein_ratio_100g  cocoa_100g  chlorophyl_100g  \
# 302218                               nan         nan              nan
#
#         carbon_footprint_100g  nutrition_score_fr_100g  \
# 302218                    nan                      nan
#
#         nutrition_score_uk_100g  glycemic_index_100g  water_hardness_100g
# 302218                      nan                  nan                  nan
# 17762 products dropped

# %% [markdown]
# Not enough composition columns filled

# %%
list_to_drop = df[pd.isnull(df[['sugars_100g', 'fat_100g', 'energy_100g', 'proteins_100g', 'salt_100g']]).all(axis=1)]
list_to_drop.sample()
print(list_to_drop.count().max() , 'products dropped')
df.drop(list_to_drop.index, inplace=True)
# Out:
#                  code                                                url  \
# 111037  0099999146448  http://world-fr.openfoodfacts.org/produit/0099...
#
#          creator   created_t      created_datetime last_modified_t  \
# 111037  stephane  1441368188  2015-09-04T12:03:08Z      1441388014
#
#        last_modified_datetime                   product_name generic_name  \
# 111037   2015-09-04T17:33:34Z  Creamy Icing for Raisin Bread          NaN
#
#        quantity packaging packaging_tags        brands   brands_tags  \
# 111037      NaN       NaN            NaN  Hershey Farm  hershey-farm
#
#        categories categories_tags categories_fr origins origins_tags  \
# 111037        NaN             NaN           NaN     NaN          NaN
#
#        manufacturing_places manufacturing_places_tags labels labels_tags  \
# 111037                  NaN                       NaN    NaN         NaN
#
#        labels_fr emb_codes emb_codes_tags first_packaging_code_geo cities  \
# 111037       NaN       NaN            NaN                      NaN    NaN
#
#        cities_tags purchase_places stores      countries    countries_tags  \
# 111037         NaN    Pennsylvania    NaN  United States  en:united-states
#
#        countries_fr ingredients_text allergens allergens_fr traces  \
# 111037   États-Unis              NaN       NaN          NaN    NaN
#
#        traces_tags traces_fr serving_size  no_nutriments  additives_n  \
# 111037         NaN       NaN          NaN            nan          nan
#
#        additives additives_tags additives_fr  ingredients_from_palm_oil_n  \
# 111037       NaN            NaN          NaN                          nan
#
#         ingredients_from_palm_oil ingredients_from_palm_oil_tags  \
# 111037                        nan                            NaN
#
#         ingredients_that_may_be_from_palm_oil_n  \
# 111037                                      nan
#
#         ingredients_that_may_be_from_palm_oil  \
# 111037                                    nan
#
#        ingredients_that_may_be_from_palm_oil_tags  nutrition_grade_uk  \
# 111037                                        NaN                 nan
#
#        nutrition_grade_fr pnns_groups_1 pnns_groups_2  \
# 111037                NaN       unknown       unknown
#
#                                                    states  \
# 111037  en:to-be-completed, en:nutrition-facts-to-be-c...
#
#                                               states_tags  \
# 111037  en:to-be-completed,en:nutrition-facts-to-be-co...
#
#                                                 states_fr main_category  \
# 111037  A compléter,Informations nutritionnelles à com...           NaN
#
#        main_category_fr                                          image_url  \
# 111037              NaN  http://fr.openfoodfacts.org/images/products/00...
#
#                                           image_small_url  energy_100g  \
# 111037  http://fr.openfoodfacts.org/images/products/00...          nan
#
#         energy_from_fat_100g  fat_100g  saturated_fat_100g  butyric_acid_100g  \
# 111037                   nan       nan                 nan                nan
#
#         caproic_acid_100g  caprylic_acid_100g  capric_acid_100g  \
# 111037                nan                 nan               nan
#
#         lauric_acid_100g  myristic_acid_100g  palmitic_acid_100g  \
# 111037               nan                 nan                 nan
#
#         stearic_acid_100g  arachidic_acid_100g  behenic_acid_100g  \
# 111037                nan                  nan                nan
#
#         lignoceric_acid_100g  cerotic_acid_100g  montanic_acid_100g  \
# 111037                   nan                nan                 nan
#
#         melissic_acid_100g  monounsaturated_fat_100g  \
# 111037                 nan                       nan
#
#         polyunsaturated_fat_100g  omega_3_fat_100g  alpha_linolenic_acid_100g  \
# 111037                       nan               nan                        nan
#
#         eicosapentaenoic_acid_100g  docosahexaenoic_acid_100g  \
# 111037                         nan                        nan
#
#         omega_6_fat_100g  linoleic_acid_100g  arachidonic_acid_100g  \
# 111037               nan                 nan                    nan
#
#         gamma_linolenic_acid_100g  dihomo_gamma_linolenic_acid_100g  \
# 111037                        nan                               nan
#
#         omega_9_fat_100g  oleic_acid_100g  elaidic_acid_100g  \
# 111037               nan              nan                nan
#
#         gondoic_acid_100g  mead_acid_100g  erucic_acid_100g  \
# 111037                nan             nan               nan
#
#         nervonic_acid_100g  trans_fat_100g  cholesterol_100g  \
# 111037                 nan             nan               nan
#
#         carbohydrates_100g  sugars_100g  sucrose_100g  glucose_100g  \
# 111037                 nan          nan           nan           nan
#
#         fructose_100g  lactose_100g  maltose_100g  maltodextrins_100g  \
# 111037            nan           nan           nan                 nan
#
#         starch_100g  polyols_100g  fiber_100g  proteins_100g  casein_100g  \
# 111037          nan           nan         nan            nan          nan
#
#         serum_proteins_100g  nucleotides_100g  salt_100g  sodium_100g  \
# 111037                  nan               nan        nan          nan
#
#         alcohol_100g  vitamin_a_100g  beta_carotene_100g  vitamin_d_100g  \
# 111037           nan             nan                 nan             nan
#
#         vitamin_e_100g  vitamin_k_100g  vitamin_c_100g  vitamin_b1_100g  \
# 111037             nan             nan             nan              nan
#
#         vitamin_b2_100g  vitamin_pp_100g  vitamin_b6_100g  vitamin_b9_100g  \
# 111037              nan              nan              nan              nan
#
#         folates_100g  vitamin_b12_100g  biotin_100g  pantothenic_acid_100g  \
# 111037           nan               nan          nan                    nan
#
#         silica_100g  bicarbonate_100g  potassium_100g  chloride_100g  \
# 111037          nan               nan             nan            nan
#
#         calcium_100g  phosphorus_100g  iron_100g  magnesium_100g  zinc_100g  \
# 111037           nan              nan        nan             nan        nan
#
#         copper_100g  manganese_100g  fluoride_100g  selenium_100g  \
# 111037          nan             nan            nan            nan
#
#         chromium_100g  molybdenum_100g  iodine_100g  caffeine_100g  \
# 111037            nan              nan          nan            nan
#
#         taurine_100g  ph_100g  fruits_vegetables_nuts_100g  \
# 111037           nan      nan                          nan
#
#         collagen_meat_protein_ratio_100g  cocoa_100g  chlorophyl_100g  \
# 111037                               nan         nan              nan
#
#         carbon_footprint_100g  nutrition_score_fr_100g  \
# 111037                    nan                      nan
#
#         nutrition_score_uk_100g  glycemic_index_100g  water_hardness_100g
# 111037                      nan                  nan                  nan
# 43809 products dropped

# %% [markdown]
# <h3> 2.b - Drop rows which are not food </3>

# %% [markdown]
# Dropping some non-food products

# %%
list_to_drop = df[df['categories_tags'].fillna('').str.contains('en:non-food-products')]
list_to_drop[['product_name', 'categories', 'categories_tags']].sample()
print(list_to_drop.count().max(), 'products dropped')
df.drop(list_to_drop.index,  inplace=True)
# Out:
#                                              product_name         categories  \
# 222741  Lingettes pocket pour visage et mains, biodégr...  Open Beauty Facts
#
#                                   categories_tags
# 222741  en:non-food-products,en:open-beauty-facts
# 5 products dropped

# %% [markdown]
# Dropping categories :  bodybuilding-supplements, dietary-supplements, baby-foods

# %%
list_to_drop = df[df['categories_tags'].fillna('').str.contains('en:dietary-supplements|en:bodybuilding-supplements|en:baby-foods')]
list_to_drop.sample()
print(list_to_drop.count().max(), 'products dropped')
df.drop(list_to_drop.index,  inplace=True)
# Out:
#                  code                                                url  \
# 292010  7613034129543  http://world-fr.openfoodfacts.org/produit/7613...
#
#          creator   created_t      created_datetime last_modified_t  \
# 292010  loverock  1477668027  2016-10-28T15:20:27Z      1481898091
#
#        last_modified_datetime                                product_name  \
# 292010   2016-12-16T14:21:31Z  NaturNes Carottes Lentilles Touche de Thym
#
#               generic_name       quantity              packaging  \
# 292010  Aliment pour bébés  400g (2x200g)  carton,pots,plastique
#
#                packaging_tags  brands brands_tags  \
# 292010  carton,pots,plastique  Nestlé      nestle
#
#                                                categories  \
# 292010  Aliments pour bébé,Dès 6 mois,Plats principaux...
#
#                                           categories_tags  \
# 292010  en:baby-foods,en:from-6-months,en:main-meals-f...
#
#                                             categories_fr origins  \
# 292010  Aliments pour bébé,Dès 6 mois,Plats principaux...     NaN
#
#        origins_tags manufacturing_places manufacturing_places_tags  \
# 292010          NaN                  NaN                       NaN
#
#                                                    labels  \
# 292010  Peu ou pas de sel,100% naturel,Sans sel ajouté...
#
#                                               labels_tags  \
# 292010  en:low-or-no-salt,en:no-colorings,en:no-preser...
#
#                                                 labels_fr emb_codes  \
# 292010  Peu ou pas de sel,Sans colorants,Sans conserva...       NaN
#
#        emb_codes_tags first_packaging_code_geo cities cities_tags  \
# 292010            NaN                      NaN    NaN         NaN
#
#                            purchase_places stores countries countries_tags  \
# 292010  chalon-sur-saône,france,courrières    Noz    France      en:france
#
#        countries_fr                                   ingredients_text  \
# 292010       France  Légumes 52% (carottes 25%, lentilles cuites 21...
#
#        allergens allergens_fr  traces traces_tags traces_fr serving_size  \
# 292010       NaN          NaN  Gluten   en:gluten    Gluten         200g
#
#         no_nutriments  additives_n  \
# 292010            nan     1.000000
#
#                                                 additives additives_tags  \
# 292010   [ legumes-52 -> fr:legumes-52  ]  [ legumes -...        en:e300
#
#                    additives_fr  ingredients_from_palm_oil_n  \
# 292010  E300 - Acide ascorbique                     0.000000
#
#         ingredients_from_palm_oil ingredients_from_palm_oil_tags  \
# 292010                        nan                            NaN
#
#         ingredients_that_may_be_from_palm_oil_n  \
# 292010                                 1.000000
#
#         ingredients_that_may_be_from_palm_oil  \
# 292010                                    nan
#
#        ingredients_that_may_be_from_palm_oil_tags  nutrition_grade_uk  \
# 292010                             huile-vegetale                 nan
#
#        nutrition_grade_fr pnns_groups_1 pnns_groups_2  \
# 292010                  a       unknown       unknown
#
#                                                    states  \
# 292010  en:to-be-checked, en:complete, en:nutrition-fa...
#
#                                               states_tags  \
# 292010  en:to-be-checked,en:complete,en:nutrition-fact...
#
#                                                 states_fr  main_category  \
# 292010  A vérifier,Complet,Informations nutritionnelle...  en:baby-foods
#
#           main_category_fr image_url image_small_url  energy_100g  \
# 292010  Aliments pour bébé       NaN             NaN   185.000000
#
#         energy_from_fat_100g  fat_100g  saturated_fat_100g  butyric_acid_100g  \
# 292010                   nan  0.800000            0.100000                nan
#
#         caproic_acid_100g  caprylic_acid_100g  capric_acid_100g  \
# 292010                nan                 nan               nan
#
#         lauric_acid_100g  myristic_acid_100g  palmitic_acid_100g  \
# 292010               nan                 nan                 nan
#
#         stearic_acid_100g  arachidic_acid_100g  behenic_acid_100g  \
# 292010                nan                  nan                nan
#
#         lignoceric_acid_100g  cerotic_acid_100g  montanic_acid_100g  \
# 292010                   nan                nan                 nan
#
#         melissic_acid_100g  monounsaturated_fat_100g  \
# 292010                 nan                       nan
#
#         polyunsaturated_fat_100g  omega_3_fat_100g  alpha_linolenic_acid_100g  \
# 292010                       nan               nan                        nan
#
#         eicosapentaenoic_acid_100g  docosahexaenoic_acid_100g  \
# 292010                         nan                        nan
#
#         omega_6_fat_100g  linoleic_acid_100g  arachidonic_acid_100g  \
# 292010               nan                 nan                    nan
#
#         gamma_linolenic_acid_100g  dihomo_gamma_linolenic_acid_100g  \
# 292010                        nan                               nan
#
#         omega_9_fat_100g  oleic_acid_100g  elaidic_acid_100g  \
# 292010               nan              nan                nan
#
#         gondoic_acid_100g  mead_acid_100g  erucic_acid_100g  \
# 292010                nan             nan               nan
#
#         nervonic_acid_100g  trans_fat_100g  cholesterol_100g  \
# 292010                 nan             nan               nan
#
#         carbohydrates_100g  sugars_100g  sucrose_100g  glucose_100g  \
# 292010            6.200000     1.700000           nan           nan
#
#         fructose_100g  lactose_100g  maltose_100g  maltodextrins_100g  \
# 292010            nan           nan           nan                 nan
#
#         starch_100g  polyols_100g  fiber_100g  proteins_100g  casein_100g  \
# 292010          nan           nan    2.000000       2.000000          nan
#
#         serum_proteins_100g  nucleotides_100g  salt_100g  sodium_100g  \
# 292010                  nan               nan   0.040000     0.015748
#
#         alcohol_100g  vitamin_a_100g  beta_carotene_100g  vitamin_d_100g  \
# 292010           nan             nan                 nan             nan
#
#         vitamin_e_100g  vitamin_k_100g  vitamin_c_100g  vitamin_b1_100g  \
# 292010             nan             nan             nan              nan
#
#         vitamin_b2_100g  vitamin_pp_100g  vitamin_b6_100g  vitamin_b9_100g  \
# 292010              nan              nan              nan              nan
#
#         folates_100g  vitamin_b12_100g  biotin_100g  pantothenic_acid_100g  \
# 292010           nan               nan          nan                    nan
#
#         silica_100g  bicarbonate_100g  potassium_100g  chloride_100g  \
# 292010          nan               nan             nan            nan
#
#         calcium_100g  phosphorus_100g  iron_100g  magnesium_100g  zinc_100g  \
# 292010           nan              nan        nan             nan        nan
#
#         copper_100g  manganese_100g  fluoride_100g  selenium_100g  \
# 292010          nan             nan            nan            nan
#
#         chromium_100g  molybdenum_100g  iodine_100g  caffeine_100g  \
# 292010            nan              nan          nan            nan
#
#         taurine_100g  ph_100g  fruits_vegetables_nuts_100g  \
# 292010           nan      nan                    52.000000
#
#         collagen_meat_protein_ratio_100g  cocoa_100g  chlorophyl_100g  \
# 292010                               nan         nan              nan
#
#         carbon_footprint_100g  nutrition_score_fr_100g  \
# 292010                    nan                -4.000000
#
#         nutrition_score_uk_100g  glycemic_index_100g  water_hardness_100g
# 292010                -4.000000                  nan                  nan
# 793 products dropped

# %% [markdown]
# <h2> 3 - Filter out unrelated columns </h2>

# %% [markdown]
# <h3> 3.a - Drop columns always empty </h3>

# %%
print(df_stats.T[df_stats.T['count'] ==0].count().max(), 'empty columns deleted')
df = df.drop(df_stats.T[df_stats.T['count'] ==0].index, axis=1)
print(df.shape[1] ,'columns left')
# Out:
# 16 empty columns deleted
# 146 columns left

# %% [markdown]
# <h3> 3.b - Keep usefull columns & fill null values </h3>

# %% [markdown]
# We'll keep specific text columns but all numeric ones

# %%
print(df.shape[1] ,'columns before')
keep_text_columns =['code',  'product_name', 'brands', 'categories', 'last_modified_datetime',
       'categories_tags',
       'labels_fr', 'countries_fr',
       'ingredients_text', 'allergens', 'additives_n', 'additives_tags',
       'additives_fr', 'nutrition_grade_fr','main_category',
       'main_category_fr']

numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
keep_number_columns = df.select_dtypes(include=numerics).columns.tolist()
keep_columns = keep_number_columns+keep_text_columns
keep_columns = list(dict.fromkeys(keep_columns))
df_keep = df[keep_columns].copy()
# Out:
# 146 columns before

# %% [markdown]
# Drop other columns

# %%
df = df_keep.copy()
print(df.shape[1] ,'columns left')
# Out:
# 105 columns left

# %% [markdown]
# Fill null / NaN values

# %%
keep_number_columns.remove('nutrition_score_fr_100g')
keep_number_columns.remove('nutrition_score_uk_100g')

keep_text_columns.remove('last_modified_datetime')
keep_text_columns.remove('nutrition_grade_fr')
df[keep_number_columns]= df[keep_number_columns].fillna(0)
df[keep_text_columns]= df[keep_text_columns].fillna('')
print('Null values filled')
# Out:
# Null values filled

# %% [markdown]
# <h2> 4 - Treat anomalies </h2>

# %% [markdown]
# <h3> 4.a - Drop products which have negative percent columns or above 100

# %% [markdown]
# Selecting all rows that are supposed to be percents

# %%
percent_columns = df.filter(like = '100g').drop([
'carbon_footprint_100g'
,'energy_100g'
,'energy_from_fat_100g'  
,'nutrition_score_fr_100g'
,'nutrition_score_uk_100g'
]
,axis = 1
).columns

# %%
negative_rows = df[df[percent_columns].lt(0).any(axis=1)]
negative_rows.sample()
print('Dropping',negative_rows.count().max(),'values < 0')
df = df.drop(negative_rows.index, axis = 0)

above100_rows = df[df[percent_columns].gt(100).any(axis=1)]
above100_rows.sample()
print('Dropping',above100_rows.count().max(),'values > 100')
df = df.drop(above100_rows.index, axis = 0)

print('Given the low number of anomalies, I chose to discard the items instead of fixing the values')
# Out:
#        additives_n  ingredients_from_palm_oil_n  \
# 80440     4.000000                     0.000000
#
#        ingredients_that_may_be_from_palm_oil_n  energy_100g  \
# 80440                                 0.000000     0.000000
#
#        energy_from_fat_100g  fat_100g  saturated_fat_100g  caprylic_acid_100g  \
# 80440              0.000000  0.000000            0.000000            0.000000
#
#        capric_acid_100g  lauric_acid_100g  myristic_acid_100g  \
# 80440          0.000000          0.000000            0.000000
#
#        palmitic_acid_100g  stearic_acid_100g  arachidic_acid_100g  \
# 80440            0.000000           0.000000             0.000000
#
#        behenic_acid_100g  montanic_acid_100g  monounsaturated_fat_100g  \
# 80440           0.000000            0.000000                  0.000000
#
#        polyunsaturated_fat_100g  omega_3_fat_100g  alpha_linolenic_acid_100g  \
# 80440                  0.000000          0.000000                   0.000000
#
#        eicosapentaenoic_acid_100g  docosahexaenoic_acid_100g  \
# 80440                    0.000000                   0.000000
#
#        omega_6_fat_100g  linoleic_acid_100g  arachidonic_acid_100g  \
# 80440          0.000000            0.000000               0.000000
#
#        gamma_linolenic_acid_100g  dihomo_gamma_linolenic_acid_100g  \
# 80440                   0.000000                          0.000000
#
#        omega_9_fat_100g  oleic_acid_100g  gondoic_acid_100g  trans_fat_100g  \
# 80440          0.000000         0.000000           0.000000        0.000000
#
#        cholesterol_100g  carbohydrates_100g  sugars_100g  sucrose_100g  \
# 80440          0.000000            0.000000     0.000000      0.000000
#
#        glucose_100g  fructose_100g  lactose_100g  maltose_100g  \
# 80440      0.000000       0.000000      0.000000      0.000000
#
#        maltodextrins_100g  starch_100g  polyols_100g  fiber_100g  \
# 80440            0.000000     0.000000      0.000000    0.000000
#
#        proteins_100g  casein_100g  serum_proteins_100g  nucleotides_100g  \
# 80440       0.000000     0.000000             0.000000          0.000000
#
#        salt_100g  sodium_100g  alcohol_100g  vitamin_a_100g  \
# 80440   0.000000     0.000000      0.000000       -0.000340
#
#        beta_carotene_100g  vitamin_d_100g  vitamin_e_100g  vitamin_k_100g  \
# 80440            0.000000        0.000000        0.000000        0.000000
#
#        vitamin_c_100g  vitamin_b1_100g  vitamin_b2_100g  vitamin_pp_100g  \
# 80440        1.132100         0.000000         0.000000         0.000000
#
#        vitamin_b6_100g  vitamin_b9_100g  folates_100g  vitamin_b12_100g  \
# 80440         0.000000         0.000000      0.000000          0.000000
#
#        biotin_100g  pantothenic_acid_100g  silica_100g  bicarbonate_100g  \
# 80440     0.000000               0.000000     0.000000          0.000000
#
#        potassium_100g  chloride_100g  calcium_100g  phosphorus_100g  \
# 80440        0.000000       0.000000      0.000000         0.000000
#
#        iron_100g  magnesium_100g  zinc_100g  copper_100g  manganese_100g  \
# 80440   0.000000        0.000000   0.000000     0.000000        0.000000
#
#        fluoride_100g  selenium_100g  chromium_100g  molybdenum_100g  \
# 80440       0.000000       0.000000       0.000000         0.000000
#
#        iodine_100g  caffeine_100g  taurine_100g  ph_100g  \
# 80440     0.000000       0.000000      0.000000 0.000000
#
#        fruits_vegetables_nuts_100g  collagen_meat_protein_ratio_100g  \
# 80440                     0.000000                          0.000000
#
#        cocoa_100g  carbon_footprint_100g  nutrition_score_fr_100g  \
# 80440    0.000000               0.000000                      nan
#
#        nutrition_score_uk_100g           code  \
# 80440                      nan  0072392312726
#
#                             product_name             brands categories  \
# 80440  Flavor Aid, Soft Drink Mix, Lemon  The Jel Sert Co.
#
#       last_modified_datetime categories_tags labels_fr countries_fr  \
# 80440   2017-03-09T10:01:05Z                             États-Unis
#
#                                         ingredients_text allergens  \
# 80440  Citric and/or fumaric acid, dextrose, lemon ju...
#
#                            additives_tags  \
# 80440  en:e297,en:e341iii,en:e300,en:e102
#
#                                             additives_fr nutrition_grade_fr  \
# 80440  E297 - Acide fumarique,E341iii - Phosphate de ...                NaN
#
#       main_category main_category_fr
# 80440
# Dropping 28 values < 0
#        additives_n  ingredients_from_palm_oil_n  \
# 18848     0.000000                     0.000000
#
#        ingredients_that_may_be_from_palm_oil_n  energy_100g  \
# 18848                                 0.000000     0.000000
#
#        energy_from_fat_100g  fat_100g  saturated_fat_100g  caprylic_acid_100g  \
# 18848              0.000000  0.000000            0.000000            0.000000
#
#        capric_acid_100g  lauric_acid_100g  myristic_acid_100g  \
# 18848          0.000000          0.000000            0.000000
#
#        palmitic_acid_100g  stearic_acid_100g  arachidic_acid_100g  \
# 18848            0.000000           0.000000             0.000000
#
#        behenic_acid_100g  montanic_acid_100g  monounsaturated_fat_100g  \
# 18848           0.000000            0.000000                  0.000000
#
#        polyunsaturated_fat_100g  omega_3_fat_100g  alpha_linolenic_acid_100g  \
# 18848                  0.000000          0.000000                   0.000000
#
#        eicosapentaenoic_acid_100g  docosahexaenoic_acid_100g  \
# 18848                    0.000000                   0.000000
#
#        omega_6_fat_100g  linoleic_acid_100g  arachidonic_acid_100g  \
# 18848          0.000000            0.000000               0.000000
#
#        gamma_linolenic_acid_100g  dihomo_gamma_linolenic_acid_100g  \
# 18848                   0.000000                          0.000000
#
#        omega_9_fat_100g  oleic_acid_100g  gondoic_acid_100g  trans_fat_100g  \
# 18848          0.000000         0.000000           0.000000        0.000000
#
#        cholesterol_100g  carbohydrates_100g  sugars_100g  sucrose_100g  \
# 18848          0.000000            0.000000     0.000000      0.000000
#
#        glucose_100g  fructose_100g  lactose_100g  maltose_100g  \
# 18848      0.000000       0.000000      0.000000      0.000000
#
#        maltodextrins_100g  starch_100g  polyols_100g  fiber_100g  \
# 18848            0.000000     0.000000      0.000000    0.000000
#
#        proteins_100g  casein_100g  serum_proteins_100g  nucleotides_100g  \
# 18848       0.000000     0.000000             0.000000          0.000000
#
#        salt_100g  sodium_100g  alcohol_100g  vitamin_a_100g  \
# 18848 106.680000    42.000000      0.000000        0.000000
#
#        beta_carotene_100g  vitamin_d_100g  vitamin_e_100g  vitamin_k_100g  \
# 18848            0.000000        0.000000        0.000000        0.000000
#
#        vitamin_c_100g  vitamin_b1_100g  vitamin_b2_100g  vitamin_pp_100g  \
# 18848        0.000000         0.000000         0.000000         0.000000
#
#        vitamin_b6_100g  vitamin_b9_100g  folates_100g  vitamin_b12_100g  \
# 18848         0.000000         0.000000      0.000000          0.000000
#
#        biotin_100g  pantothenic_acid_100g  silica_100g  bicarbonate_100g  \
# 18848     0.000000               0.000000     0.000000          0.000000
#
#        potassium_100g  chloride_100g  calcium_100g  phosphorus_100g  \
# 18848        0.000000       0.000000      0.000000         0.000000
#
#        iron_100g  magnesium_100g  zinc_100g  copper_100g  manganese_100g  \
# 18848   0.000000        0.000000   0.000000     0.000000        0.000000
#
#        fluoride_100g  selenium_100g  chromium_100g  molybdenum_100g  \
# 18848       0.000000       0.000000       0.000000         0.000000
#
#        iodine_100g  caffeine_100g  taurine_100g  ph_100g  \
# 18848     0.000000       0.000000      0.000000 0.000000
#
#        fruits_vegetables_nuts_100g  collagen_meat_protein_ratio_100g  \
# 18848                     0.000000                          0.000000
#
#        cocoa_100g  carbon_footprint_100g  nutrition_score_fr_100g  \
# 18848    0.000000               0.000000                      nan
#
#        nutrition_score_uk_100g           code         product_name  \
# 18848                      nan  0021248102585  Himalayan Pink Salt
#
#               brands categories last_modified_datetime categories_tags  \
# 18848  Olde Thompson              2017-03-09T12:08:34Z
#
#       labels_fr countries_fr     ingredients_text allergens additives_tags  \
# 18848             États-Unis  Himalayan pink salt
#
#       additives_fr nutrition_grade_fr main_category main_category_fr
# 18848                             NaN
# Dropping 215 values > 100
# Given the low number of anomalies, I chose to discard the items instead of fixing the values

# %% [markdown]
# <h3> 4.b - Drop some products with unreal components

# %%
list_to_drop = df[(df['trans_fat_100g']>=28) & (df['fat_100g']<28)]
print('These organic raisins contain0% fats but 40% trans fats?')
list_to_drop[list_to_drop['code']=='0032601050108']
print(list_to_drop.count().max() , 'products dropped')
df.drop(list_to_drop.index, inplace=True)
# Out:
# These organic raisins contain0% fats but 40% trans fats?
#        additives_n  ingredients_from_palm_oil_n  \
# 28172     0.000000                     0.000000
#
#        ingredients_that_may_be_from_palm_oil_n  energy_100g  \
# 28172                                 0.000000  1255.000000
#
#        energy_from_fat_100g  fat_100g  saturated_fat_100g  caprylic_acid_100g  \
# 28172              0.000000  0.000000            0.000000            0.000000
#
#        capric_acid_100g  lauric_acid_100g  myristic_acid_100g  \
# 28172          0.000000          0.000000            0.000000
#
#        palmitic_acid_100g  stearic_acid_100g  arachidic_acid_100g  \
# 28172            0.000000           0.000000             0.000000
#
#        behenic_acid_100g  montanic_acid_100g  monounsaturated_fat_100g  \
# 28172           0.000000            0.000000                  0.000000
#
#        polyunsaturated_fat_100g  omega_3_fat_100g  alpha_linolenic_acid_100g  \
# 28172                  0.000000          0.000000                   0.000000
#
#        eicosapentaenoic_acid_100g  docosahexaenoic_acid_100g  \
# 28172                    0.000000                   0.000000
#
#        omega_6_fat_100g  linoleic_acid_100g  arachidonic_acid_100g  \
# 28172          0.000000            0.000000               0.000000
#
#        gamma_linolenic_acid_100g  dihomo_gamma_linolenic_acid_100g  \
# 28172                   0.000000                          0.000000
#
#        omega_9_fat_100g  oleic_acid_100g  gondoic_acid_100g  trans_fat_100g  \
# 28172          0.000000         0.000000           0.000000       40.000000
#
#        cholesterol_100g  carbohydrates_100g  sugars_100g  sucrose_100g  \
# 28172          0.000000           80.000000    75.000000      0.000000
#
#        glucose_100g  fructose_100g  lactose_100g  maltose_100g  \
# 28172      0.000000       0.000000      0.000000      0.000000
#
#        maltodextrins_100g  starch_100g  polyols_100g  fiber_100g  \
# 28172            0.000000     0.000000      0.000000    5.000000
#
#        proteins_100g  casein_100g  serum_proteins_100g  nucleotides_100g  \
# 28172       2.500000     0.000000             0.000000          0.000000
#
#        salt_100g  sodium_100g  alcohol_100g  vitamin_a_100g  \
# 28172   0.000000     0.000000      0.000000        0.000000
#
#        beta_carotene_100g  vitamin_d_100g  vitamin_e_100g  vitamin_k_100g  \
# 28172            0.000000        0.000000        0.000000        0.000000
#
#        vitamin_c_100g  vitamin_b1_100g  vitamin_b2_100g  vitamin_pp_100g  \
# 28172        0.003000         0.000000         0.000000         0.000000
#
#        vitamin_b6_100g  vitamin_b9_100g  folates_100g  vitamin_b12_100g  \
# 28172         0.000000         0.000000      0.000000          0.000000
#
#        biotin_100g  pantothenic_acid_100g  silica_100g  bicarbonate_100g  \
# 28172     0.000000               0.000000     0.000000          0.000000
#
#        potassium_100g  chloride_100g  calcium_100g  phosphorus_100g  \
# 28172        0.000000       0.000000      0.050000         0.000000
#
#        iron_100g  magnesium_100g  zinc_100g  copper_100g  manganese_100g  \
# 28172   0.002700        0.000000   0.000000     0.000000        0.000000
#
#        fluoride_100g  selenium_100g  chromium_100g  molybdenum_100g  \
# 28172       0.000000       0.000000       0.000000         0.000000
#
#        iodine_100g  caffeine_100g  taurine_100g  ph_100g  \
# 28172     0.000000       0.000000      0.000000 0.000000
#
#        fruits_vegetables_nuts_100g  collagen_meat_protein_ratio_100g  \
# 28172                     0.000000                          0.000000
#
#        cocoa_100g  carbon_footprint_100g  nutrition_score_fr_100g  \
# 28172    0.000000               0.000000                 8.000000
#
#        nutrition_score_uk_100g           code product_name  \
# 28172                 8.000000  0032601050108      Raisins
#
#                         brands categories last_modified_datetime  \
# 28172  Earthbound Farm Organic              2017-03-09T14:08:39Z
#
#       categories_tags labels_fr countries_fr  \
# 28172                             États-Unis
#
#                                         ingredients_text allergens  \
# 28172  Organic raisins, less than 1% organic sunflowe...
#
#       additives_tags additives_fr nutrition_grade_fr main_category  \
# 28172                                              c
#
#       main_category_fr
# 28172
# 25 products dropped

# %% [markdown]
# <h3> 4.c - Drop duplicated products

# %%
df_no_duplicates = df.drop_duplicates(['product_name', 'brands'])

print('Dropping',df.shape[0]-df_no_duplicates.shape[0],'duplicates.')

df = df_no_duplicates
df = df.dropna(how='all')
# Out:
# Dropping 18234 duplicates.

# %%
df.shape
df.describe(include='all')
# Out:
# (239901, 105)
#          additives_n  ingredients_from_palm_oil_n  \
# count  239901.000000                239901.000000
# unique           nan                          nan
# top              nan                          nan
# freq             nan                          nan
# mean        1.785908                     0.017340
# std         2.463023                     0.132155
# min         0.000000                     0.000000
# 25%         0.000000                     0.000000
# 50%         1.000000                     0.000000
# 75%         3.000000                     0.000000
# max        31.000000                     2.000000
#
#         ingredients_that_may_be_from_palm_oil_n    energy_100g  \
# count                             239901.000000  239901.000000
# unique                                      nan            nan
# top                                         nan            nan
# freq                                        nan            nan
# mean                                   0.049487    1137.401792
# std                                    0.255400    6697.506348
# min                                    0.000000       0.000000
# 25%                                    0.000000     380.000000
# 50%                                    0.000000    1100.000000
# 75%                                    0.000000    1674.000000
# max                                    6.000000 3251373.000000
#
#         energy_from_fat_100g      fat_100g  saturated_fat_100g  \
# count          239901.000000 239901.000000       239901.000000
# unique                   nan           nan                 nan
# top                      nan           nan                 nan
# freq                     nan           nan                 nan
# mean                1.874542     11.744871            4.510029
# std                51.670182     16.984616            7.644648
# min                 0.000000      0.000000            0.000000
# 25%                 0.000000      0.000000            0.000000
# 50%                 0.000000      3.570000            1.000000
# 75%                 0.000000     18.750000            6.360000
# max              3830.000000    100.000000          100.000000
#
#         caprylic_acid_100g  capric_acid_100g  lauric_acid_100g  \
# count        239901.000000     239901.000000     239901.000000
# unique                 nan               nan               nan
# top                    nan               nan               nan
# freq                   nan               nan               nan
# mean              0.000031          0.000050          0.000603
# std               0.015108          0.017446          0.170401
# min               0.000000          0.000000          0.000000
# 25%               0.000000          0.000000          0.000000
# 50%               0.000000          0.000000          0.000000
# 75%               0.000000          0.000000          0.000000
# max               7.400000          6.200000         49.300000
#
#         myristic_acid_100g  palmitic_acid_100g  stearic_acid_100g  \
# count        239901.000000       239901.000000      239901.000000
# unique                 nan                 nan                nan
# top                    nan                 nan                nan
# freq                   nan                 nan                nan
# mean              0.000079            0.000034           0.000013
# std               0.038587            0.016537           0.006125
# min               0.000000            0.000000           0.000000
# 25%               0.000000            0.000000           0.000000
# 50%               0.000000            0.000000           0.000000
# 75%               0.000000            0.000000           0.000000
# max              18.900000            8.100000           3.000000
#
#         arachidic_acid_100g  behenic_acid_100g  montanic_acid_100g  \
# count         239901.000000      239901.000000       239901.000000
# unique                  nan                nan                 nan
# top                     nan                nan                 nan
# freq                    nan                nan                 nan
# mean               0.000055           0.000054            0.000254
# std                0.026746           0.026337            0.124541
# min                0.000000           0.000000            0.000000
# 25%                0.000000           0.000000            0.000000
# 50%                0.000000           0.000000            0.000000
# 75%                0.000000           0.000000            0.000000
# max               13.100000          12.900000           61.000000
#
#         monounsaturated_fat_100g  polyunsaturated_fat_100g  omega_3_fat_100g  \
# count              239901.000000             239901.000000     239901.000000
# unique                       nan                       nan               nan
# top                          nan                       nan               nan
# freq                         nan                       nan               nan
# mean                    0.847974                  0.512382          0.010153
# std                     5.480138                  3.476243          0.343096
# min                     0.000000                  0.000000          0.000000
# 25%                     0.000000                  0.000000          0.000000
# 50%                     0.000000                  0.000000          0.000000
# 75%                     0.000000                  0.000000          0.000000
# max                   100.000000                 98.000000         58.000000
#
#         alpha_linolenic_acid_100g  eicosapentaenoic_acid_100g  \
# count               239901.000000               239901.000000
# unique                        nan                         nan
# top                           nan                         nan
# freq                          nan                         nan
# mean                     0.001278                    0.000421
# std                      0.170758                    0.173697
# min                      0.000000                    0.000000
# 25%                      0.000000                    0.000000
# 50%                      0.000000                    0.000000
# 75%                      0.000000                    0.000000
# max                     53.000000                   85.000000
#
#         docosahexaenoic_acid_100g  omega_6_fat_100g  linoleic_acid_100g  \
# count               239901.000000     239901.000000       239901.000000
# unique                        nan               nan                 nan
# top                           nan               nan                 nan
# freq                          nan               nan                 nan
# mean                     0.000130          0.011810            0.001431
# std                      0.013541          0.656716            0.160406
# min                      0.000000          0.000000            0.000000
# 25%                      0.000000          0.000000            0.000000
# 50%                      0.000000          0.000000            0.000000
# 75%                      0.000000          0.000000            0.000000
# max                      3.600000         71.000000           25.000000
#
#         arachidonic_acid_100g  gamma_linolenic_acid_100g  \
# count           239901.000000              239901.000000
# unique                    nan                        nan
# top                       nan                        nan
# freq                      nan                        nan
# mean                 0.000000                   0.000001
# std                  0.000000                   0.000324
# min                  0.000000                   0.000000
# 25%                  0.000000                   0.000000
# 50%                  0.000000                   0.000000
# 75%                  0.000000                   0.000000
# max                  0.000000                   0.127000
#
#         dihomo_gamma_linolenic_acid_100g  omega_9_fat_100g  oleic_acid_100g  \
# count                      239901.000000     239901.000000    239901.000000
# unique                               nan               nan              nan
# top                                  nan               nan              nan
# freq                                 nan               nan              nan
# mean                            0.000000          0.003479         0.001297
# std                             0.000102          0.440391         0.259897
# min                             0.000000          0.000000         0.000000
# 25%                             0.000000          0.000000         0.000000
# 50%                             0.000000          0.000000         0.000000
# 75%                             0.000000          0.000000         0.000000
# max                             0.050000         75.000000        76.000000
#
#         gondoic_acid_100g  trans_fat_100g  cholesterol_100g  \
# count       239901.000000   239901.000000     239901.000000
# unique                nan             nan               nan
# top                   nan             nan               nan
# freq                  nan             nan               nan
# mean             0.000000        0.032817          0.010547
# std              0.000000        0.525910          0.199988
# min              0.000000        0.000000          0.000000
# 25%              0.000000        0.000000          0.000000
# 50%              0.000000        0.000000          0.000000
# 75%              0.000000        0.000000          0.000000
# max              0.000001       38.460000         95.238000
#
#         carbohydrates_100g   sugars_100g  sucrose_100g  glucose_100g  \
# count        239901.000000 239901.000000 239901.000000 239901.000000
# unique                 nan           nan           nan           nan
# top                    nan           nan           nan           nan
# freq                   nan           nan           nan           nan
# mean             29.767060     14.846683      0.003167      0.000158
# std              29.293189     20.737395      0.307056      0.050140
# min               0.000000      0.000000      0.000000      0.000000
# 25%               3.570000      0.600000      0.000000      0.000000
# 50%              17.000000      4.600000      0.000000      0.000000
# 75%              56.670000     21.740000      0.000000      0.000000
# max             100.000000    100.000000     92.800000     23.000000
#
#         fructose_100g  lactose_100g  maltose_100g  maltodextrins_100g  \
# count   239901.000000 239901.000000 239901.000000       239901.000000
# unique            nan           nan           nan                 nan
# top               nan           nan           nan                 nan
# freq              nan           nan           nan                 nan
# mean         0.003386      0.001427      0.000256            0.000000
# std          0.435401      0.145185      0.091776            0.000000
# min          0.000000      0.000000      0.000000            0.000000
# 25%          0.000000      0.000000      0.000000            0.000000
# 50%          0.000000      0.000000      0.000000            0.000000
# 75%          0.000000      0.000000      0.000000            0.000000
# max        100.000000     54.000000     39.200000            0.000000
#
#          starch_100g  polyols_100g    fiber_100g  proteins_100g   casein_100g  \
# count  239901.000000 239901.000000 239901.000000  239901.000000 239901.000000
# unique           nan           nan           nan            nan           nan
# top              nan           nan           nan            nan           nan
# freq             nan           nan           nan            nan           nan
# mean        0.030768      0.080323      2.185625       7.037373      0.000004
# std         1.241462      2.405938      4.212307       8.061952      0.001878
# min         0.000000      0.000000      0.000000       0.000000      0.000000
# 25%         0.000000      0.000000      0.000000       0.600000      0.000000
# 50%         0.000000      0.000000      0.100000       4.760000      0.000000
# 75%         0.000000      0.000000      3.000000      10.000000      0.000000
# max        87.800000    100.000000    100.000000     100.000000      0.920000
#
#         serum_proteins_100g  nucleotides_100g     salt_100g   sodium_100g  \
# count         239901.000000     239901.000000 239901.000000 239901.000000
# unique                  nan               nan           nan           nan
# top                     nan               nan           nan           nan
# freq                    nan               nan           nan           nan
# mean               0.000008          0.000000      1.565160      0.616203
# std                0.004083          0.000047      6.191148      2.437452
# min                0.000000          0.000000      0.000000      0.000000
# 25%                0.000000          0.000000      0.045720      0.018000
# 50%                0.000000          0.000000      0.546100      0.215000
# 75%                0.000000          0.000000      1.353820      0.533000
# max                2.000000          0.023000    100.000000     39.370079
#
#         alcohol_100g  vitamin_a_100g  beta_carotene_100g  vitamin_d_100g  \
# count  239901.000000   239901.000000       239901.000000   239901.000000
# unique           nan             nan                 nan             nan
# top              nan             nan                 nan             nan
# freq             nan             nan                 nan             nan
# mean        0.008868        0.000220            0.000006        0.000000
# std         0.525199        0.055488            0.001274        0.000061
# min         0.000000        0.000000            0.000000        0.000000
# 25%         0.000000        0.000000            0.000000        0.000000
# 50%         0.000000        0.000000            0.000000        0.000000
# 75%         0.000000        0.000000            0.000000        0.000000
# max        97.900000       26.700000            0.380000        0.030000
#
#         vitamin_e_100g  vitamin_k_100g  vitamin_c_100g  vitamin_b1_100g  \
# count    239901.000000   239901.000000   239901.000000    239901.000000
# unique             nan             nan             nan              nan
# top                nan             nan             nan              nan
# freq               nan             nan             nan              nan
# mean          0.000244        0.000131        0.006880         0.013529
# std           0.046579        0.063802        0.226547         0.425018
# min           0.000000        0.000000        0.000000         0.000000
# 25%           0.000000        0.000000        0.000000         0.000000
# 50%           0.000000        0.000000        0.000000         0.000000
# 75%           0.000000        0.000000        0.000000         0.000000
# max          15.100000       31.250000       50.000000        92.600000
#
#         vitamin_b2_100g  vitamin_pp_100g  vitamin_b6_100g  vitamin_b9_100g  \
# count     239901.000000    239901.000000    239901.000000    239901.000000
# unique              nan              nan              nan              nan
# top                 nan              nan              nan              nan
# freq                nan              nan              nan              nan
# mean           0.010783         0.000655         0.000472         0.000150
# std            0.274993         0.060170         0.189207         0.049540
# min            0.000000         0.000000         0.000000         0.000000
# 25%            0.000000         0.000000         0.000000         0.000000
# 50%            0.000000         0.000000         0.000000         0.000000
# 75%            0.000000         0.000000         0.000000         0.000000
# max           42.500000        21.428571        92.600000        23.076923
#
#         folates_100g  vitamin_b12_100g   biotin_100g  pantothenic_acid_100g  \
# count  239901.000000     239901.000000 239901.000000          239901.000000
# unique           nan               nan           nan                    nan
# top              nan               nan           nan                    nan
# freq             nan               nan           nan                    nan
# mean        0.000559          0.000002      0.000008               0.000596
# std         0.158484          0.000820      0.004083               0.148171
# min         0.000000          0.000000      0.000000               0.000000
# 25%         0.000000          0.000000      0.000000               0.000000
# 50%         0.000000          0.000000      0.000000               0.000000
# 75%         0.000000          0.000000      0.000000               0.000000
# max        57.142857          0.400000      2.000000              60.000000
#
#          silica_100g  bicarbonate_100g  potassium_100g  chloride_100g  \
# count  239901.000000     239901.000000   239901.000000  239901.000000
# unique           nan               nan             nan            nan
# top              nan               nan             nan            nan
# freq             nan               nan             nan            nan
# mean        0.000001          0.000038        0.029134       0.000010
# std         0.000108          0.004016        0.343951       0.001282
# min         0.000000          0.000000        0.000000       0.000000
# 25%         0.000000          0.000000        0.000000       0.000000
# 50%         0.000000          0.000000        0.000000       0.000000
# 75%         0.000000          0.000000        0.000000       0.000000
# max         0.036200          1.250000       66.667000       0.379000
#
#         calcium_100g  phosphorus_100g     iron_100g  magnesium_100g  \
# count  239901.000000    239901.000000 239901.000000   239901.000000
# unique           nan              nan           nan             nan
# top              nan              nan           nan             nan
# freq             nan              nan           nan             nan
# mean        0.054311         0.005521      0.001765        0.002849
# std         0.434530         0.057382      0.126602        0.104722
# min         0.000000         0.000000      0.000000        0.000000
# 25%         0.000000         0.000000      0.000000        0.000000
# 50%         0.000000         0.000000      0.000000        0.000000
# 75%         0.043000         0.000000      0.001200        0.000000
# max        99.006000         8.000000     47.058820       37.500000
#
#            zinc_100g   copper_100g  manganese_100g  fluoride_100g  \
# count  239901.000000 239901.000000   239901.000000  239901.000000
# unique           nan           nan             nan            nan
# top              nan           nan             nan            nan
# freq             nan           nan             nan            nan
# mean        0.000111      0.000075        0.000018       0.000003
# std         0.010143      0.033661        0.002267       0.001149
# min         0.000000      0.000000        0.000000       0.000000
# 25%         0.000000      0.000000        0.000000       0.000000
# 50%         0.000000      0.000000        0.000000       0.000000
# 75%         0.000000      0.000000        0.000000       0.000000
# max         4.000000     16.483516        0.700000       0.560000
#
#         selenium_100g  chromium_100g  molybdenum_100g   iodine_100g  \
# count   239901.000000  239901.000000    239901.000000 239901.000000
# unique            nan            nan              nan           nan
# top               nan            nan              nan           nan
# freq              nan            nan              nan           nan
# mean         0.000015       0.000000         0.000000      0.000000
# std          0.007292       0.000061         0.000000      0.000041
# min          0.000000       0.000000         0.000000      0.000000
# 25%          0.000000       0.000000         0.000000      0.000000
# 50%          0.000000       0.000000         0.000000      0.000000
# 75%          0.000000       0.000000         0.000000      0.000000
# max          3.571429       0.030000         0.000045      0.014700
#
#         caffeine_100g  taurine_100g       ph_100g  \
# count   239901.000000 239901.000000 239901.000000
# unique            nan           nan           nan
# top               nan           nan           nan
# freq              nan           nan           nan
# mean         0.000513      0.000015      0.000411
# std          0.119495      0.002438      0.054179
# min          0.000000      0.000000      0.000000
# 25%          0.000000      0.000000      0.000000
# 50%          0.000000      0.000000      0.000000
# 75%          0.000000      0.000000      0.000000
# max         42.280000      0.423000      8.200000
#
#         fruits_vegetables_nuts_100g  collagen_meat_protein_ratio_100g  \
# count                 239901.000000                     239901.000000
# unique                          nan                               nan
# top                             nan                               nan
# freq                            nan                               nan
# mean                       0.360076                          0.010100
# std                        4.786320                          0.406689
# min                        0.000000                          0.000000
# 25%                        0.000000                          0.000000
# 50%                        0.000000                          0.000000
# 75%                        0.000000                          0.000000
# max                      100.000000                         25.000000
#
#           cocoa_100g  carbon_footprint_100g  nutrition_score_fr_100g  \
# count  239901.000000          239901.000000            202920.000000
# unique           nan                    nan                      nan
# top              nan                    nan                      nan
# freq             nan                    nan                      nan
# mean        0.176241               0.330797                 9.180786
# std         3.149348              17.162291                 9.055117
# min         0.000000               0.000000               -15.000000
# 25%         0.000000               0.000000                 1.000000
# 50%         0.000000               0.000000                10.000000
# 75%         0.000000               0.000000                16.000000
# max       100.000000            2842.000000                40.000000
#
#         nutrition_score_uk_100g           code            product_name  \
# count             202920.000000         239901                  239901
# unique                      nan         239901                  186415
# top                         nan  0602652170508  Extra Virgin Olive Oil
# freq                        nan              1                     197
# mean                   9.076414            NaN                     NaN
# std                    9.187130            NaN                     NaN
# min                  -15.000000            NaN                     NaN
# 25%                    1.000000            NaN                     NaN
# 50%                    9.000000            NaN                     NaN
# 75%                   16.000000            NaN                     NaN
# max                   40.000000            NaN                     NaN
#
#         brands categories last_modified_datetime categories_tags labels_fr  \
# count   239901     239901                 239901          239901    239901
# unique   46089      27611                 118995           16002     11065
# top                         2015-08-09T17:35:48Z
# freq      3142     179276                     23          179277    203649
# mean       NaN        NaN                    NaN             NaN       NaN
# std        NaN        NaN                    NaN             NaN       NaN
# min        NaN        NaN                    NaN             NaN       NaN
# 25%        NaN        NaN                    NaN             NaN       NaN
# 50%        NaN        NaN                    NaN             NaN       NaN
# 75%        NaN        NaN                    NaN             NaN       NaN
# max        NaN        NaN                    NaN             NaN       NaN
#
#        countries_fr ingredients_text allergens additives_tags additives_fr  \
# count        239901           239901    239901         239901       239901
# unique          505           182278     11612          38339        38339
# top      États-Unis
# freq         155996            24636    215695         102535       102535
# mean            NaN              NaN       NaN            NaN          NaN
# std             NaN              NaN       NaN            NaN          NaN
# min             NaN              NaN       NaN            NaN          NaN
# 25%             NaN              NaN       NaN            NaN          NaN
# 50%             NaN              NaN       NaN            NaN          NaN
# 75%             NaN              NaN       NaN            NaN          NaN
# max             NaN              NaN       NaN            NaN          NaN
#
#        nutrition_grade_fr main_category main_category_fr
# count              202920        239901           239901
# unique                  5          2305             2305
# top                     d
# freq                57648        179277           179277
# mean                  NaN           NaN              NaN
# std                   NaN           NaN              NaN
# min                   NaN           NaN              NaN
# 25%                   NaN           NaN              NaN
# 50%                   NaN           NaN              NaN
# 75%                   NaN           NaN              NaN
# max                   NaN           NaN              NaN

# %%
df_plt_results = pd.DataFrame({'Products count': [df.shape[0], df_save.shape[0]-df.shape[0]]},
                  index=['Produits restants', 'Produits écartés'])
plot = df_plt_results.plot.pie(y='Products count'
                               , figsize=(5, 5)
                               , autopct='%1.1f%%'
                                , title = 'Nettoyage'
                               , fontsize=15 
                               , legend = False)
plot = plt.ylabel('')

# %% [markdown]
# <h2> 5 - Export the clean data </h2>

# %% [markdown]
# Export using Feather module

# %%
feather.write_dataframe(df, 'openfoodfacts_cleaned_v1.feather')
